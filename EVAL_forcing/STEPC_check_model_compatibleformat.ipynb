# %%
import glob
import os
import numpy as np

# %%
w = 'walrusruby'
q = w.replace('walrus', 'dog')
print(q)
# Out:
# dogruby

# %% [markdown]
# # Experiment 1H - DONE

# %%
dir_1H = 'hist/u-bc370_hist/'
# dir_1FA
dir_1FB = 'ssp370/u-ce417_ssp370/'
# dir_2H
# dir_2FA
# dir_2FB
dir_3H = 'hist/u-cj200_hist_1990start1990ozone/'
dir_3FA = 'ssp126/u-cj484_ssp126_1990start1990ozone/'
# dir_3FB

basedir = '/gpfs/home/mep22dku/scratch/MET_soft/'

# %%
tdir = dir_3FA
yr = 2020
total = f'{basedir}{tdir}*{yr}*daily*.nc'
ttot = glob.glob(total)
print(ttot)
print(len(ttot))
# Out:
# ['/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/precip.met.2020.daily.nc', '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/snow.met.2020.daily.nc', '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/air.met.2020.daily.nc', '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/rlds.met.2020.daily.nc', '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/uflx.met.2020.daily.nc', '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/rsds.met.2020.daily.nc', '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/vflx.met.2020.daily.nc', '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/shum.met.2020.daily.nc']
# 8

# %%
yr = 1950
dstdir = '/gpfs/home/mep22dku/scratch/MET_soft/hist/u-bc370_hist/'

yrs = np.arange(1950,2015,1)

for y in range(0,len(yrs)):
    yr = yrs[y]
    w = glob.glob(f'{dstdir}*{yr}*daily*.nc')
    q = (len(w))
    if q < int(17):
        print(yr)
    # for i in range(0,len(w)):
    #     if i%10 == 0:
    #         print(i)
    #     tfil = w[i]
    #     newfil = tfil.replace(orgdir,'')
    #     newfil = newfil.replace(expname,'met')
    #     src = tfil
    #     dst = f'{dstdir}{newfil}'
    #     os.symlink(src, dst)
    

#dstdir = 'bc370_wind_y1950m12.nc'


#find
# Out:
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014

# %% [markdown]
# ## Experiment 1FB - DONE

# %%
orgdir = '/gpfs/data/greenocean/software/resources/MetOffice/fixed_ozone/ssp370/u-ce417_ssp370/'
dstdir = '/gpfs/home/mep22dku/scratch/MET_soft/ssp370/u-ce417_ssp370/'
expname = 'ce417'


yrs = np.arange(2015,2101,1)

for y in range(0,len(yrs)):
    yr = yrs[y]
    print(yr)
    w = glob.glob(f'{orgdir}*{yr}*.nc')
           
    for i in range(0,len(w)):
        if i%10 == 0:
            print(i)
        tfil = w[i]
        newfil = tfil.replace(orgdir,'')
        newfil = newfil.replace(expname,'met')
        src = tfil
        dst = f'{dstdir}{newfil}'
        os.symlink(src, dst)
    

#dstdir = 'bc370_wind_y1950m12.nc'


#find
# Out:
# 2015
# 0
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_30246/2964102395.py in <module>
#      19         src = tfil
#      20         dst = f'{dstdir}{newfil}'
# ---> 21         os.symlink(src, dst)
#      22
#      23
#
# FileExistsError: [Errno 17] File exists: '/gpfs/data/greenocean/software/resources/MetOffice/fixed_ozone/ssp370/u-ce417_ssp370/ce417_bulk_y2015m07.nc' -> '/gpfs/home/mep22dku/scratch/MET_soft/ssp370/u-ce417_ssp370/met_bulk_y2015m07.nc'

# %% [markdown]
# ## experiment 3H

# %%
## from 1950-1990 it should be same as 1H


yr = 1950
orgdir = '/gpfs/data/greenocean/software/resources/MetOffice/fixed_ozone/hist/u-bc370_hist/'
dstdir = '/gpfs/home/mep22dku/scratch/MET_soft/hist/u-cj200_hist_1990start1990ozone//'
expname = 'bc370'


yrs = np.arange(1950,1990,1)

for y in range(0,len(yrs)):
    yr = yrs[y]
    print(yr)
    w = glob.glob(f'{orgdir}*{yr}*.nc')
           
    for i in range(0,len(w)):
        if i%10 == 0:
            print(i)
        tfil = w[i]
        newfil = tfil.replace(orgdir,'')
        newfil = newfil.replace(expname,'met')
        src = tfil
        dst = f'{dstdir}{newfil}'
        os.symlink(src, dst)
    
orgdir = '/gpfs/data/greenocean/software/resources/MetOffice/fixed_ozone/hist/u-cj200_hist_1990start1990ozone/'
dstdir = '/gpfs/home/mep22dku/scratch/MET_soft/hist/u-cj200_hist_1990start1990ozone//'
expname = 'cj200'

yrs = np.arange(1990,2015,1)

for y in range(0,len(yrs)):
    yr = yrs[y]
    print(yr)
    w = glob.glob(f'{orgdir}*{yr}*.nc')
           
    for i in range(0,len(w)):
        if i%10 == 0:
            print(i)
        tfil = w[i]
        newfil = tfil.replace(orgdir,'')
        newfil = newfil.replace(expname,'met')
        src = tfil
        dst = f'{dstdir}{newfil}'
        os.symlink(src, dst)
#dstdir = 'bc370_wind_y1950m12.nc'


#find
# Out:
# 1950
# 0
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_30246/3074766467.py in <module>
#      23         src = tfil
#      24         dst = f'{dstdir}{newfil}'
# ---> 25         os.symlink(src, dst)
#      26
#      27 orgdir = '/gpfs/data/greenocean/software/resources/MetOffice/fixed_ozone/hist/u-cj200_hist_1990start1990ozone/'
#
# FileExistsError: [Errno 17] File exists: '/gpfs/data/greenocean/software/resources/MetOffice/fixed_ozone/hist/u-bc370_hist/bc370_bulk_y1950m08.nc' -> '/gpfs/home/mep22dku/scratch/MET_soft/hist/u-cj200_hist_1990start1990ozone//met_bulk_y1950m08.nc'

# %% [markdown]
# # Experiment 3FA

# %%
orgdir = '/gpfs/data/greenocean/software/resources/MetOffice/fixed_ozone/ssp126/u-cj484_ssp126_1990start1990ozone/'
dstdir = '/gpfs/home/mep22dku/scratch/MET_soft/ssp126/u-cj484_ssp126_1990start1990ozone/'
expname = 'cj484'


yrs = np.arange(2015,2101,1)

for y in range(0,len(yrs)):
    yr = yrs[y]
    print(yr)
    w = glob.glob(f'{orgdir}*{yr}*.nc')
           
    for i in range(0,len(w)):
        if i%10 == 0:
            print(i)
        tfil = w[i]
        newfil = tfil.replace(orgdir,'')
        newfil = newfil.replace(expname,'met')
        src = tfil
        dst = f'{dstdir}{newfil}'
        os.symlink(src, dst)
    

#dstdir = 'bc370_wind_y1950m12.nc'


#find
# Out:
# 2015
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2016
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2017
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2018
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2019
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2020
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2021
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2022
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2023
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2024
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2025
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2026
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2027
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2028
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2029
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2030
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2031
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2032
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2033
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2034
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2035
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2036
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2037
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2038
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 2039
# 0
# 10
# ...
