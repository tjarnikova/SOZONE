# %% [markdown]
# from IPython.display import HTML
#
# HTML('''<script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')

# %%
import scendict as sc
import netCDF4 as nc
import xarray as xr
import numpy as np
import warnings
import cartopy as cp
import cartopy.crs as ccrs
import cmocean as cm
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %% [markdown]
# ## simple sketch of average windspeeds, summer, winter, whole globe and Southern Latitudes (south of -30)

# %%
tmesh = nc.Dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')

yrs = np.arange(1940,2101,1)

ys = 0; ye = 50
scens = ['1A','1B','2A','2B','3A','3B']
var = 'mean_wspd'; varstr = 'monthly_wspd';
adj = 0

fact = 0.6
fig, axs = plt.subplots(2,2, figsize=(20*fact, 16*fact), \
                        facecolor='w', edgecolor='k')
axs = axs.ravel()
#summer, whole world
for s in range(0,6):
    scen = scens[s]
    w = nc.Dataset(f'./EXTRACT/ncs/scen_{scen}_{varstr}.nc')
    
    tair = w[var][:,12,:,:]+adj
    tair_mean = np.nanmean(np.nanmean(tair, axis = 2),axis = 1)
    axs[0].plot(yrs,tair_mean, color = sc.scen[scen]['color'], \
               label =  sc.scen[scen]['name'])

    tair = w[var][:,12,ys:ye,:]+adj
    tair_mean = np.nanmean(np.nanmean(tair, axis = 2),axis = 1)
    axs[1].plot(yrs,tair_mean, color = sc.scen[scen]['color'])


    tair = w[var][:,13,:,:]+adj
    tair_mean = np.nanmean(np.nanmean(tair, axis = 2),axis = 1)
    axs[2].plot(yrs,tair_mean, color = sc.scen[scen]['color'])

    tair = w[var][:,13,ys:ye,:]+adj
    tair_mean = np.nanmean(np.nanmean(tair, axis = 2),axis = 1)
    axs[3].plot(yrs,tair_mean, color = sc.scen[scen]['color'])    

tits = ['Austral summer (mon 12-2) \n global surface wspd',\
        'Austral summer (mon 12-2) \n Southern Ocean (<-30$^\circ$S ) surface wspd',\
        'Austral winter (mon 6-8) \n global surface air wspd',\
        'Austral winter (mon 6-8) \n SO (<-30$^\circ$S ) surface wspd',]
for i in range(0,4):
    axs[i].set_xlim([1940,2100])
    axs[i].grid()
    axs[i].set_title(tits[i])
    axs[i].set_ylabel('m/s')
    
axs[0].legend(loc = 'best')
plt.tight_layout()

# %% [markdown]
# ## Spatial maps of trends in surface temperature

# %%
scens = ['1A','1B','2A','2B','3A','3B']
var = 'mean_wspd'; varstr = 'monthly_wspd';
var = 'mean_wspd'; sind = 12 #seasonal indicator! 12 or 13
fnam = './PICTURES/summer_global_wspd_anom.jpg'
stit = 'By-scenario global windspeed (m/s) from historic baseline (1940-1960) \n years 2020-2100, austral summer (months 12-2)'
ys = 0; ye = 149
## O mask:
tmesh = nc.Dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')
tmask = ((tmesh['tmask'][0,0,ys:ye,:]))

#get baseline
w = nc.Dataset(f'./EXTRACT/ncs/scen_1A_{varstr}.nc')
tair = w[var][:]
base_mean = np.nanmean(tair[1940-1940:1960-1940,sind,ys:ye,:],axis = 0)
base_mean[tmask == 0] = np.nan
tvmin = -3; tvmax = 3

fact = 0.6
fig, axs = plt.subplots(6,6, figsize=(20*fact, 22*fact), \
                        facecolor='w', edgecolor='k')
axs = axs.ravel()


startrow = [0,6,12,18,24,30]
for s in range(0,6):
    si = startrow[s]
    w = nc.Dataset(f'./EXTRACT/ncs/scen_{scens[s]}_{varstr}.nc')
    tair = w[var][:]
    w = axs[si].pcolormesh(base_mean, cmap = cm.cm.tempo, vmin = 0, vmax = 15)
    tn = sc.scen[scens[0]]['name']
    axs[si].set_title(f'{tn} \n 1940-1960')
    axs[si].set_yticks([]); axs[si].set_xticks([]);
    fig.colorbar(w, ax=axs[si], orientation = 'horizontal')
    
    for i in range(1,6):
        start = 2000+i*20; end = start+20
        per_mean = np.nanmean(tair[start-1940:end-1940,sind,ys:ye,:],axis = 0)
        per_anom =  per_mean- base_mean
        w = axs[si+i].pcolormesh(per_anom, cmap = cm.cm.balance, vmin = tvmin, vmax = tvmax)
        tn = sc.scen[scens[s]]['name']
        axs[si+i].set_title(f'{tn} \n {start}-{end}')
        fig.colorbar(w, ax=axs[si+i], orientation = 'horizontal')
        axs[si+i].set_yticks([]); axs[si+i].set_xticks([]);

plt.suptitle(stit, fontsize = 16)
             
plt.tight_layout()
fig.savefig(fnam, dpi = 300)

# %%
scens = ['1A','1B','2A','2B','3A','3B']
sind = 12 #seasonal indicator! 12 or 13
fnam = './PICTURES/summer_SO_wspd_anom.jpg'
var = 'mean_wspd'; varstr = 'monthly_wspd';
stit = 'By-scenario Southern Ocean (south of -30$^\circ$S) windspeed anomalies (m/s) from historic baseline (1940-1960) \n years 2020-2100, austral summer (months 12-2)'
ys = 0; ye = 50
## O mask:

tmesh = nc.Dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')
tmask = ((tmesh['tmask'][0,0,ys:ye,:]))

#get baseline
w = nc.Dataset(f'./EXTRACT/ncs/scen_1A_{varstr}.nc')
tair = w[var][:]
base_mean = np.nanmean(tair[1940-1940:1960-1940,sind,ys:ye,:],axis = 0)
base_mean[tmask == 0] = np.nan


fact = 0.6
fig, axs = plt.subplots(6,6, figsize=(20*fact, 22*fact), \
                        facecolor='w', edgecolor='k')
axs = axs.ravel()


startrow = [0,6,12,18,24,30]
for s in range(0,6):
    si = startrow[s]
    w = nc.Dataset(f'./EXTRACT/ncs/scen_{scens[s]}_{varstr}.nc')
    tair = w[var][:]
    w = axs[si].pcolormesh(base_mean, cmap = cm.cm.tempo, vmin = 0, vmax = 15)
    tn = sc.scen[scens[0]]['name']
    axs[si].set_title(f'{tn} \n 1940-1960')
    axs[si].set_yticks([]); axs[si].set_xticks([]);
    fig.colorbar(w, ax=axs[si], orientation = 'horizontal')
    
    for i in range(1,6):
        start = 2000+i*20; end = start+20
        per_mean = np.nanmean(tair[start-1940:end-1940,sind,ys:ye,:],axis = 0)
        per_anom =  per_mean- base_mean
        w = axs[si+i].pcolormesh(per_anom, cmap = cm.cm.balance, vmin = -4, vmax = 4)
        tn = sc.scen[scens[s]]['name']
        axs[si+i].set_title(f'{tn} \n {start}-{end}')
        fig.colorbar(w, ax=axs[si+i], orientation = 'horizontal')
        axs[si+i].set_yticks([]); axs[si+i].set_xticks([]);

plt.suptitle(stit, fontsize = 16)
             
plt.tight_layout()
fig.savefig(fnam, dpi = 300)

# %% [markdown]
# ## Winter air temperature - whole globe

# %%
sind = 13 #seasonal indicator! 12 or 13
fnam = './PICTURES/winter_global_wspd_anom.jpg'
stit = 'By-scenario global windspeed anomalies (m/s) from historic baseline (1940-1960) \n years 2020-2100, austral winter (months 6-8)'
ys = 0; ye = 149
## O mask:
tmesh = nc.Dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')
tmask = ((tmesh['tmask'][0,0,ys:ye,:]))

#get baseline
w = nc.Dataset(f'./EXTRACT/ncs/scen_1A_{varstr}.nc')
tair = w[var][:]
base_mean = np.nanmean(tair[1940-1940:1960-1940,sind,ys:ye,:],axis = 0)
base_mean[tmask == 0] = np.nan


fact = 0.6
fig, axs = plt.subplots(6,6, figsize=(20*fact, 22*fact), \
                        facecolor='w', edgecolor='k')
axs = axs.ravel()
axs[0].pcolormesh(base_mean, cmap = cm.cm.thermal, vmin = -10, vmax = 20)

startrow = [0,6,12,18,24,30]
for s in range(0,6):
    si = startrow[s]
    w = nc.Dataset(f'./EXTRACT/ncs/scen_{scens[s]}_{varstr}.nc')
    tair = w[var][:]
    w = axs[si].pcolormesh(base_mean, cmap = cm.cm.tempo, vmin = 0, vmax = 15)
    tn = sc.scen[scens[0]]['name']
    axs[si].set_title(f'{tn} \n 1940-1960')
    axs[si].set_yticks([]); axs[si].set_xticks([]);
    fig.colorbar(w, ax=axs[si], orientation = 'horizontal')
    
    for i in range(1,6):
        start = 2000+i*20; end = start+20
        per_mean = np.nanmean(tair[start-1940:end-1940,sind,ys:ye,:],axis = 0)
        per_anom =  per_mean- base_mean
        w = axs[si+i].pcolormesh(per_anom, cmap = cm.cm.balance, vmin = -4, vmax = 4)
        tn = sc.scen[scens[s]]['name']
        axs[si+i].set_title(f'{tn} \n {start}-{end}')
        fig.colorbar(w, ax=axs[si+i], orientation = 'horizontal')
        axs[si+i].set_yticks([]); axs[si+i].set_xticks([]);

plt.suptitle(stit, fontsize = 16)
             
plt.tight_layout()
fig.savefig(fnam, dpi = 300)

# %%
scens = ['1A','1B','2A','2B','3A','3B']
sind = 13 #seasonal indicator! 12 or 13
fnam = './PICTURES/winter_SO_wspd_anom.jpg'
stit = 'By-scenario Southern Ocean (south of -30$^\circ$S) windspeed anomalies (m/s) from historic baseline (1940-1960) \n years 2020-2100, austral winter (months 6-8)'
ys = 0; ye = 50
## O mask:
tmesh = nc.Dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')
tmask = ((tmesh['tmask'][0,0,ys:ye,:]))
tvmin = -8; tvmax = 8
#get baseline
w = nc.Dataset(f'./EXTRACT/ncs/scen_1A_{varstr}.nc')
tair = w[var][:]
base_mean = np.nanmean(tair[1940-1940:1960-1940,sind,ys:ye,:],axis = 0)
base_mean[tmask == 0] = np.nan


fact = 0.6
fig, axs = plt.subplots(6,6, figsize=(20*fact, 22*fact), \
                        facecolor='w', edgecolor='k')
axs = axs.ravel()

startrow = [0,6,12,18,24,30]
for s in range(0,6):
    si = startrow[s]
    w = nc.Dataset(f'./EXTRACT/ncs/scen_{scens[s]}_{varstr}.nc')
    tair = w[var][:]
    w = axs[si].pcolormesh(base_mean, cmap = cm.cm.tempo, vmin = 0, vmax = 15)
    tn = sc.scen[scens[0]]['name']
    axs[si].set_title(f'{tn} \n 1940-1960')
    axs[si].set_yticks([]); axs[si].set_xticks([]);
    fig.colorbar(w, ax=axs[si], orientation = 'horizontal')
    
    for i in range(1,6):
        start = 2000+i*20; end = start+20
        per_mean = np.nanmean(tair[start-1940:end-1940,sind,ys:ye,:],axis = 0)
        per_anom =  per_mean- base_mean
        w = axs[si+i].pcolormesh(per_anom, cmap = cm.cm.balance, vmin = -4, vmax = 4)
        tn = sc.scen[scens[s]]['name']
        axs[si+i].set_title(f'{tn} \n {start}-{end}')
        fig.colorbar(w, ax=axs[si+i], orientation = 'horizontal')
        axs[si+i].set_yticks([]); axs[si+i].set_xticks([]);

plt.suptitle(stit, fontsize = 16)
             
plt.tight_layout()
fig.savefig(fnam, dpi = 300)

# %% [markdown]
# ## full year windspeed

# %%
sind = 14 #seasonal indicator! 12 or 13
fnam = './PICTURES/fullyear_global_wspd_anom.jpg'
stit = 'By-scenario global windspeed anomalies (m/s) from historic baseline (1940-1960) \n years 2020-2100, full year'
ys = 0; ye = 149
## O mask:
tmesh = nc.Dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')
tmask = ((tmesh['tmask'][0,0,ys:ye,:]))

#get baseline
w = nc.Dataset(f'./EXTRACT/ncs/scen_1A_{varstr}.nc')
tair = w[var][:]
base_mean = np.nanmean(tair[1940-1940:1960-1940,sind,ys:ye,:],axis = 0)
base_mean[tmask == 0] = np.nan


fact = 0.6
fig, axs = plt.subplots(6,6, figsize=(20*fact, 22*fact), \
                        facecolor='w', edgecolor='k')
axs = axs.ravel()
axs[0].pcolormesh(base_mean, cmap = cm.cm.thermal, vmin = -10, vmax = 20)

startrow = [0,6,12,18,24,30]
for s in range(0,6):
    si = startrow[s]
    w = nc.Dataset(f'./EXTRACT/ncs/scen_{scens[s]}_{varstr}.nc')
    tair = w[var][:]
    w = axs[si].pcolormesh(base_mean, cmap = cm.cm.tempo, vmin = 0, vmax = 15)
    tn = sc.scen[scens[0]]['name']
    axs[si].set_title(f'{tn} \n 1940-1960')
    axs[si].set_yticks([]); axs[si].set_xticks([]);
    fig.colorbar(w, ax=axs[si], orientation = 'horizontal')
    
    for i in range(1,6):
        start = 2000+i*20; end = start+20
        per_mean = np.nanmean(tair[start-1940:end-1940,sind,ys:ye,:],axis = 0)
        per_anom =  per_mean- base_mean
        w = axs[si+i].pcolormesh(per_anom, cmap = cm.cm.balance, vmin = -4, vmax = 4)
        tn = sc.scen[scens[s]]['name']
        axs[si+i].set_title(f'{tn} \n {start}-{end}')
        fig.colorbar(w, ax=axs[si+i], orientation = 'horizontal')
        axs[si+i].set_yticks([]); axs[si+i].set_xticks([]);

plt.suptitle(stit, fontsize = 16)
             
plt.tight_layout()
fig.savefig(fnam, dpi = 300)

# %%
scens = ['1A','1B','2A','2B','3A','3B']
sind = 14 #seasonal indicator! 12 or 13
fnam = './PICTURES/fullyear_SO_wspd_anom.jpg'
stit = 'By-scenario Southern Ocean (south of -30$^\circ$S) windspeed anomalies (m/s) from historic baseline (1940-1960) \n years 2020-2100, full year'
ys = 0; ye = 50
## O mask:
tmesh = nc.Dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')
tmask = ((tmesh['tmask'][0,0,ys:ye,:]))
tvmin = -8; tvmax = 8
#get baseline
w = nc.Dataset(f'./EXTRACT/ncs/scen_1A_{varstr}.nc')
tair = w[var][:]
base_mean = np.nanmean(tair[1940-1940:1960-1940,sind,ys:ye,:],axis = 0)
base_mean[tmask == 0] = np.nan


fact = 0.6
fig, axs = plt.subplots(6,6, figsize=(20*fact, 22*fact), \
                        facecolor='w', edgecolor='k')
axs = axs.ravel()

startrow = [0,6,12,18,24,30]
for s in range(0,6):
    si = startrow[s]
    w = nc.Dataset(f'./EXTRACT/ncs/scen_{scens[s]}_{varstr}.nc')
    tair = w[var][:]
    w = axs[si].pcolormesh(base_mean, cmap = cm.cm.tempo, vmin = 0, vmax = 15)
    tn = sc.scen[scens[0]]['name']
    axs[si].set_title(f'{tn} \n 1940-1960')
    axs[si].set_yticks([]); axs[si].set_xticks([]);
    fig.colorbar(w, ax=axs[si], orientation = 'horizontal')
    
    for i in range(1,6):
        start = 2000+i*20; end = start+20
        per_mean = np.nanmean(tair[start-1940:end-1940,sind,ys:ye,:],axis = 0)
        per_anom =  per_mean- base_mean
        w = axs[si+i].pcolormesh(per_anom, cmap = cm.cm.balance, vmin = -4, vmax = 4)
        tn = sc.scen[scens[s]]['name']
        axs[si+i].set_title(f'{tn} \n {start}-{end}')
        fig.colorbar(w, ax=axs[si+i], orientation = 'horizontal')
        axs[si+i].set_yticks([]); axs[si+i].set_xticks([]);

plt.suptitle(stit, fontsize = 16)
             
plt.tight_layout()
fig.savefig(fnam, dpi = 300)
