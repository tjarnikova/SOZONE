# %%
import glob
import os
import numpy as np
import scendict as sc
from os.path import exists
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams.update({'font.size': 14})
font = {'family' : 'normal',
'weight' : 'bold',
'size'   : 14}

runhorse = False

# %%
# src = '/gpfs/home/mep22dku/scratch/MET_soft/hist/u-bc370_hist//bulk_1981_16_met_daily.nc'
# dst = '/gpfs/home/mep22dku/scratch/MET_forcing/scen_1A/MetOffice_tair10m1981.nc'

# os.symlink(src,dst)

# %%
def make_symlink_if_exists(src,dst,yr,var):
    if exists(src) == False:
        print(f'year {yr}, {var} original file doesnt exist')
    if exists(src):
        try:
            # print(src)
            # print(dst)
            os.symlink(src, dst)
        except:
             print(f'year {yr}, {var} original file exists but symlink not made')
                
edir = '/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/'
bdir = '/gpfs/data/greenocean/software/resources/MetProcessed/MET_soft/'

scenlist = ['1A','1B','2A','2B','3A','3B']
if runhorse:
    for s in range(0,6):
        tscen = scenlist[s]
        print(f'making symlinks for scenario {tscen}')
        for yr in range(1940,2101):
            if yr < 2015:
                ldir = sc.scen[tscen]['hist_dir']
            else:
                ldir = sc.scen[tscen]['fut_dir']
            tdir = f'{bdir}{ldir}' 
            edir = '/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/'

            #tair
            src = f'{tdir}/bulk_{yr}_16_met_daily.nc'; var = 'tair'
            dst = f'{edir}/scen_{tscen}/MetOffice_tair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_17_met_daily.nc'; var = 'qair'
            dst = f'{edir}/scen_{tscen}/MetOffice_qair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_18_met_daily.nc'; var = 'sw_down'
            dst = f'{edir}/scen_{tscen}/MetOffice_sw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_19_met_daily.nc'; var = 'lw_down'
            dst = f'{edir}/scen_{tscen}/MetOffice_lw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_20_met_daily.nc'; var = 'precip'
            dst = f'{edir}/scen_{tscen}/MetOffice_precip_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_21_met_daily.nc'; var = 'snow'
            dst = f'{edir}/scen_{tscen}/MetOffice_snow_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/taux_1d_{yr}_daily.nc'; var = 'taux'
            dst = f'{edir}/scen_{tscen}/MetOffice_taux_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/tauy_1d_{yr}_daily.nc'; var = 'tauy'
            dst = f'{edir}/scen_{tscen}/MetOffice_tauy_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

# %%
def make_symlink_if_exists(src,dst,yr,var):
    if exists(src) == False:
        print(f'year {yr}, {var} original file doesnt exist')
    if exists(src):
        try:
            # print(src)
            # print(dst)
            os.symlink(src, dst)
        except:
             print(f'year {yr}, {var} original file exists but symlink not made')

bdir = '/gpfs/home/mep22dku/scratch/MET_soft/'

scenlist = ['1A','1B','2A','2B','3A','3B']
if runhorse:
    for s in range(0,6):
        tscen = scenlist[s]
        print(f'making symlinks for scenario {tscen}')
        for yr in range(1940,2101):
            if yr < 2015:
                ldir = sc.scen[tscen]['hist_dir']
            else:
                ldir = sc.scen[tscen]['fut_dir']
            tdir = f'{bdir}{ldir}' 

            #tair
            src = f'{tdir}/bulk_{yr}_16_met_daily.nc'; var = 'tair'
            dst = f'{edir}/scen_{tscen}/MetOffice_tair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_17_met_daily.nc'; var = 'qair'
            dst = f'{edir}/scen_{tscen}/MetOffice_qair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_18_met_daily.nc'; var = 'sw_down'
            dst = f'{edir}/scen_{tscen}/MetOffice_sw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_19_met_daily.nc'; var = 'lw_down'
            dst = f'{edir}/scen_{tscen}/MetOffice_lw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_20_met_daily.nc'; var = 'precip'
            dst = f'{edir}/scen_{tscen}/MetOffice_precip_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr}_21_met_daily.nc'; var = 'snow'
            dst = f'{edir}/scen_{tscen}/MetOffice_snow_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/taux_1d_{yr}_daily.nc'; var = 'taux'
            dst = f'{edir}/scen_{tscen}/MetOffice_taux_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/tauy_1d_{yr}_daily.nc'; var = 'tauy'
            dst = f'{edir}/scen_{tscen}/MetOffice_tauy_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)
# Out:
# making symlinks for scenario 1A
# year 1940, tair original file exists but symlink not made
# year 1940, qair original file exists but symlink not made
# year 1940, sw_down original file exists but symlink not made
# year 1940, lw_down original file exists but symlink not made
# year 1940, precip original file exists but symlink not made
# year 1940, snow original file exists but symlink not made
# year 1940, taux original file exists but symlink not made
# year 1940, tauy original file exists but symlink not made
# year 1941, tair original file exists but symlink not made
# year 1941, qair original file exists but symlink not made
# year 1941, sw_down original file exists but symlink not made
# year 1941, lw_down original file exists but symlink not made
# year 1941, precip original file exists but symlink not made
# year 1941, snow original file exists but symlink not made
# year 1941, taux original file exists but symlink not made
# ...

# %% [markdown]
# ### make symlinks for historical
#
# 2A,2B 1940-1950: 1A
# 3A,3B 1940-1990: 1A

# %%
scenlist = ['2A','2B']
if runhorse:
    for s in range(0,2):
        tscen = scenlist[s]
        for yr in range(1940,1950):

                    #tair
                    fnam = f'/MetOffice_tair10m_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_qair10m_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_sw_down_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_lw_down_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_precip_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)
                    fnam = f'MetOffice_snow_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)
                    fnam = f'MetOffice_taux_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)
                    fnam = f'MetOffice_tauy_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

# %%
scenlist = ['3A','3B']
if runhorse:
    for s in range(0,2):
        tscen = scenlist[s]
        for yr in range(1940,1990):

                    #tair
                    fnam = f'/MetOffice_tair10m_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_qair10m_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_sw_down_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_lw_down_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

                    fnam = f'MetOffice_precip_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)
                    fnam = f'MetOffice_snow_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)
                    fnam = f'MetOffice_taux_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)
                    fnam = f'MetOffice_tauy_y{yr}.nc'
                    src = f'{edir}/scen_1A/{fnam}'
                    dst = f'{edir}/scen_{tscen}/{fnam}'
                    make_symlink_if_exists(src,dst,yr,var)

# %%
scenlist = ['1A','1B','2A','2B','3A','3B']
arange = np.arange(1940,2101,1)

dst = f'/gpfs/home/mep22dku/scratch/MET_forcing/scen_{tscen}/MetOffice_tair10m{yr}.nc'

fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes

ind = np.array([1,2,3,4,5,6])
for s in range(0,6):
    tind = ind[s]
    tscen = scenlist[s]
    t_show = np.zeros_like(arange); 
    for yr in range(1940,2101):
        if exists(f'{edir}/scen_{tscen}/MetOffice_tair10m_y{yr}.nc'):
            t_show[yr-1940] = tind
    plt.plot(arange,t_show,marker='o',linestyle = '', color = sc.scen[tscen]['color'],label = sc.scen[tscen]['name'])
    print(tscen)
    print(arange[t_show == 0])
# plt.plot(arange,ind_1A,marker = 'o',linestyle = '', color = col_1A, label = name_1FA)
# plt.plot(arange,ind_1B,marker = 'o',linestyle = '',  color = col_1B, label = name_1FB)
# plt.plot(arange,ind_2A,marker = 'o',linestyle = '', color = col_2A, label = name_2FA)
# plt.plot(arange,ind_2B,marker = 'o',linestyle = '',  color = col_2B, label = name_2FB)
# plt.plot(arange,ind_3A,marker = 'o',linestyle = '', color = col_3A, label = name_3FA)
# plt.plot(arange,ind_3B,marker = 'o',linestyle = '',  color = col_3B, label = name_3FB)
ax.set_yticklabels([])
ax.grid()
ax.set_xlim([1940,2100])
ax.set_ylim([0.5,6.5])
# ax.set_xlim([1940,2100])
plt.legend(bbox_to_anchor = [1.5,1])
plt.title(f'Availability of met office processed wind forcing \n for 6 scenarios')
# Out:
# 1A
# []
# 1B
# []
# 2A
# []
# 2B
# []
# 3A
# []
# 3B
# []
# Text(0.5, 1.0, 'Availability of met office processed wind forcing \n for 6 scenarios')

# %%
print(sc.scen['2B'])
# Out:
# {'hist_dir': 'hist/u-cj198_hist_1950start1950ozone/', 'fut_dir': 'ssp370/u-cj881_ssp370_1950start1950ozone/', 'name': 'FIXED OZONE \n HIGH TEMP.', 'name2': '2B: Ozone1950-SSP370', 'color': '#18765C', 'color2': 'green'}

# %% [markdown]
# ## PRODUCE LOOPING SYMLINKS FOR year 1990

# %%
def make_symlink_if_exists(src,dst,yr,var):
    if exists(src) == False:
        print(f'year {yr}, {var} original file doesnt exist')
    if exists(src):
        try:
            # print(src)
            # print(dst)
            os.symlink(src, dst)
        except:
             print(f'year {yr}, {var} original file exists but symlink not made')

bdir = '/gpfs/home/mep22dku/scratch/MET_soft/'

scenlist = ['1','2','3']
if runhorse:
    for s in range(0,3):
        tscen = scenlist[s]
        print(f'making symlinks for scenario {tscen}')
        for yr in range(1750,2101):

            #tair
            src = f'{edir}/scen_{tscen}A/MetOffice_tair10m_y1990.nc'; var = 'tair'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_tair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}A/MetOffice_qair10m_y1990.nc'; var = 'qair'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_qair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}A/MetOffice_sw_down_y1990.nc'; var = 'sw_down'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_sw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}A/MetOffice_lw_down_y1990.nc'; var = 'lw_down'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_lw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}A/MetOffice_precip_y1990.nc'; var = 'precip'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_precip_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}A/MetOffice_snow_y1990.nc'; var = 'snow'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_snow_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}A/MetOffice_taux_y1990.nc'; var = 'taux'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_taux_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}A/MetOffice_tauy_y1990.nc'; var = 'tauy'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_tauy_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)
# Out:
# making symlinks for scenario 1
# making symlinks for scenario 2
# making symlinks for scenario 3

# %%
edir
# Out:
# '/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/'

# %%
def make_symlink_if_exists(src,dst,yr,var):
    if exists(src) == False:
        print(f'year {yr}, {var} original file doesnt exist')
    if exists(src):
        try:
            # print(src)
            # print(dst)
            os.symlink(src, dst)
        except:
             print(f'year {yr}, {var} original file exists but symlink not made')

bdir = '/gpfs/home/mep22dku/scratch/MET_soft/'

scenlist = ['PI']
runhorse = True
if runhorse:
    for s in range(0,1):
        tscen = scenlist[s]
        print(f'making symlinks for scenario {tscen}')
        for yr in range(1950,2101):
            tdir = '/gpfs/data/greenocean/software/products/MetOffice/u-aw310_pictrl/'
            edir = '/gpfs/data/greenocean/software/products/MetOffice/u-aw310_pictrl/'

            #tair
            src = f'{tdir}/bulk_{yr+270}_16_met_daily.nc'; var = 'tair'
            dst = f'{edir}/scen_{tscen}/MetOffice_tair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr+270}_17_met_daily.nc'; var = 'qair'
            dst = f'{edir}/scen_{tscen}/MetOffice_qair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr+270}_18_met_daily.nc'; var = 'sw_down'
            dst = f'{edir}/scen_{tscen}/MetOffice_sw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr+270}_19_met_daily.nc'; var = 'lw_down'
            dst = f'{edir}/scen_{tscen}/MetOffice_lw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr+270}_20_met_daily.nc'; var = 'precip'
            dst = f'{edir}/scen_{tscen}/MetOffice_precip_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/bulk_{yr+270}_21_met_daily.nc'; var = 'snow'
            dst = f'{edir}/scen_{tscen}/MetOffice_snow_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/taux_1d_{yr+270}_daily.nc'; var = 'taux'
            dst = f'{edir}/scen_{tscen}/MetOffice_taux_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{tdir}/tauy_1d_{yr+270}_daily.nc'; var = 'tauy'
            dst = f'{edir}/scen_{tscen}/MetOffice_tauy_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)
# Out:
# making symlinks for scenario PI

# %%
def make_symlink_if_exists(src,dst,yr,var):
    if exists(src) == False:
        print(f'year {yr}, {var} original file doesnt exist')
    if exists(src):
        try:
            # print(src)
            # print(dst)
            os.symlink(src, dst)
        except:
             print(f'year {yr}, {var} original file exists but symlink not made')

edir = '/gpfs/data/greenocean/software/products/MetOffice/u-aw310_pictrl/'

scenlist = ['PI']
if runhorse:
    for s in range(0,1):
        tscen = scenlist[s]
        print(f'making symlinks for scenario {tscen}')
        for yr in range(1750,2101):

            #tair
            src = f'{edir}/scen_{tscen}/MetOffice_tair10m_y1990.nc'; var = 'tair'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_tair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}/MetOffice_qair10m_y1990.nc'; var = 'qair'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_qair10m_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}/MetOffice_sw_down_y1990.nc'; var = 'sw_down'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_sw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}/MetOffice_lw_down_y1990.nc'; var = 'lw_down'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_lw_down_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}/MetOffice_precip_y1990.nc'; var = 'precip'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_precip_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}/MetOffice_snow_y1990.nc'; var = 'snow'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_snow_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}/MetOffice_taux_y1990.nc'; var = 'taux'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_taux_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)

            src = f'{edir}/scen_{tscen}/MetOffice_tauy_y1990.nc'; var = 'tauy'
            dst = f'{edir}/scen_{tscen}_LOOP/MetOffice_tauy_y{yr}.nc'
            make_symlink_if_exists(src,dst,yr,var)
# Out:
# making symlinks for scenario PI
