# %% [markdown]
# ## problem in 1950 or 1951 forcing?

# %%
import netCDF4 as nc
import glob
import xarray as xr
import numpy as np

# %%
tf = '/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_2B/MetOffice_snow_y1951.nc'

# %% [markdown]
# ## big checker of every variable in every scenario <#

# %%
# MetOffice_tair10m_y1951.nc 
# MetOffice_qair10m_y1951.nc
# MetOffice_sw_down_y1951.nc
# MetOffice_lw_down_y1951.nc 
# MetOffice_precip_y1951.nc 
# MetOffice_snow_y1951.nc 
# MetOffice_taux_y1951.nc 
# MetOffice_tauy_y1951.nc 

scens = ['1A','1B', '2A','2B', '3A','3B']



w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 0

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['air']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 air(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 air(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
# ...

# %%
#MetOffice_tair10m_y1951

# %%
w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 1

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['shum']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 shum(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 shum(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
# ...

# %%
w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 2

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['rsds']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 rsds(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 rsds(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
# ...

# %%
w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 3

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['rlds']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 rlds(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 rlds(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
# ...

# %%
w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 4

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['prra']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 prra(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 prra(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
# ...

# %%
w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 5

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['prsn']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 prsn(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 prsn(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
# ...

# %%
w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 6

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['uflx']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 time_counter(time_counter), float32 uflx(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 time_counter(time_counter), float32 uflx(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 time_counter(time_counter), float32 uflx(time_counter,y,x)
#     groups:
# 2B
# <class 'netCDF4._netCDF4.Dataset'>
# ...

# %%
w = ['tair10m','qair10m','sw_down','lw_down','precip','snow','taux','tauy']

ind = 7

for s in scens:
    print(s)
    td =  f'/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_{s}/'
    
    for yr in range(1940,2094):
        q = glob.glob(f'{td}MetOffice_{w[ind]}_y{yr}.nc')

        ds = nc.Dataset(q[0])
        if yr == 1940:
            print(ds)
        ts = (np.size(ds['vflx']))
        if ts < 9898070:
            print(q[0])
# Out:
# 1A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 time_counter(time_counter), float32 vflx(time_counter,y,x)
#     groups:
# 1B
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 time_counter(time_counter), float32 vflx(time_counter,y,x)
#     groups:
# 2A
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 time_counter(time_counter), float32 vflx(time_counter,y,x)
#     groups:
# 2B
# <class 'netCDF4._netCDF4.Dataset'>
# ...

# %% [markdown]
# ## oh ok so the RAW DATA FROM THE MET OFFICE is of size 0 AGAIN

# %%
w = '/gpfs/data/greenocean/software/resources/MetProcessed/MET_soft/hist/u-cj198_hist_1950start1950ozone/'
tm = '01'
for i in range(0,12):
    tm = i+1
    if tm < 10:
        tms = f'0{tm}'
    else:
        tms = tm

    q = f'met_bulk_y1995m{tms}.nc'
    t = nc.Dataset(f'{w}{q}')
    #print(t['qair10m'])
    print(t['qair10m'].shape)
    
print(nc.Dataset('/gpfs/data/greenocean/software/resources/MetProcessed/MET_forcing/scen_2B/MetOffice_qair10m_y1995.nc'))
# Out:
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# (240, 144, 192)
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): x(182), y(149), deptht(1), time_counter(365)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 deptht(y,x), float32 time_counter(time_counter), float32 shum(time_counter,y,x)
#     groups:

# %%
w = nc.Dataset('/gpfs/data/greenocean/software/resources/MetProcessed/MET_soft/hist/u-cj198_hist_1950start1950ozone/shum.met.1995.daily.nc')
print(w)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     dimensions(sizes): lat(144), lon(192), time(365)
#     variables(dimensions): float32 lat(lat), float32 lon(lon), float32 time(time), float32 shum(time,lat,lon)
#     groups:
