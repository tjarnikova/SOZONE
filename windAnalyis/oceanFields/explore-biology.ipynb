# %% [markdown]
# ### aim:
#
# ### date:

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %%
w = xr.open_dataset('/gpfs/afm/greenocean/software/runs/TOM12_TJ_3AA6/ORCA2_1m_20980101_20981231_ptrc_T.nc')

# %%
mm_tom = xr.open_dataset('/gpfs/data/greenocean/software/resources/regrid/mesh_mask3_6.nc')
mm_tom['area'] = mm_tom.tmask[0,0,:,:] * mm_tom.e1t[0,:,:] * mm_tom.e2t[0,:,:]
m

# %% [markdown]
# ### depth integrated phytoplankton - does the assemblage change in time?

# %%
tob = list(w.keys())

for i in range(0,len(tob)):
    
    print([tob[i]])
    try:
        print(w[tob[i]].long_name)
    except:
        print('no long name found!')
        
    print()
# Out:
# ['deptht_bounds']
# no long name found!
#
# ['Alkalini']
# Total Alkalinity Concentration
#
# ['time_centered_bounds']
# no long name found!
#
# ['time_counter_bounds']
# no long name found!
#
# ['O2']
# Oxygen Concentration
#
# ['DIC']
# Dissolved inorganic Concentration
#
# ['PIIC']
# Preindustrial dissolved inorganic Carbon
#
# ['NO3']
# Nitrate Concentration
#
# ['Si']
# Silicate Concentration
#
# ['PO4']
# Phosphate Concentration
#
# ['Fer']
# Dissolved Iron Concentration
#
# ['DOC']
# Dissolved organic Concentration
#
# ['CaCO3']
# Calcite Concentration
#
# ['ARA']
# Aragonite Concentration
#
# ['POC']
# small Particulate organic carbon Concent
#
# ['GOC']
# big Particulate organic carbon Concentr.
#
# ['BAC']
# Bacteria Concentration
#
# ['PRO']
# MicroZooplankton Concentration
#
# ['PTE']
# Pteropod Concentration
#
# ['MES']
# MesoZooplankton Concentration
#
# ['GEL']
# Jellyfish Concentration
#
# ['MAC']
# MacroZooplankton Concentration
#
# ['DIA']
# Diatom Concentration
#
# ...

# %%
w.DIC
# Out:
# <xarray.DataArray 'DIC' (time_counter: 12, deptht: 31, y: 149, x: 182)>
# [10087896 values with dtype=float32]
# Coordinates:
#     nav_lat        (y, x) float32 -78.19058 -78.19058 ... 50.516075 49.978893
#     nav_lon        (y, x) float32 78.00004 80.0 81.99996 ... 80.22104 80.0
#   * deptht         (deptht) float32 4.999938 15.000288 ... 4749.913 5250.2266
#     time_centered  (time_counter) object 2098-01-16 12:00:00 ... 2098-12-16 1...
#   * time_counter   (time_counter) object 2098-01-16 12:00:00 ... 2098-12-16 1...
# Dimensions without coordinates: y, x
# Attributes:
#     long_name:           Dissolved inorganic Concentration
#     units:               mol/L
#     online_operation:    average
#     interval_operation:  5760 s
#     interval_write:      1 month
#     cell_methods:        time: mean (interval: 5760 s)
