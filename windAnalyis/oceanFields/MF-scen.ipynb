# %% [markdown]
# ### aim:
#
# ### date:

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %%
ssp3 = pd.read_csv('/gpfs/data/greenocean/software/resources/SOZONE_atmo/atmco2_ssp3-70.dat', \
                sep='\t', names =['lev1', 'lev', 'Column3'] )
ssp1 = pd.read_csv('/gpfs/data/greenocean/software/resources/SOZONE_atmo/atmco2_ssp1-26.dat', \
                sep='\t', names =['lev1', 'lev', 'Column3'] )

# %%
plt.plot(ssp1.lev1, color = 'silver', label = 'SSP1 - 2.6')
plt.plot(ssp3.lev1, color = 'dimgrey', label = 'SSP3 -7.0')

plt.xlim([1950,2100])
plt.ylim([300,900])
# Out:
# (300.0, 900.0)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image
img = mpimg.imread('./figs/scendesc.remini-enhanced.jpg')

# Create a figure to hold the subplots
fact = 0.9
fig, axs = plt.subplots(2, 1, figsize=(6*fact, 8*fact))

date = np.arange(1950,2101,1)
fixed = np.copy(date)
fixed[:] = 1
axs[0].plot(date,fixed, color = '#2DC18E')
fixed[:] = 2
axs[0].plot(date,fixed, color = '#E8D215')
fixed[:] = 3
axs[0].plot(date,fixed, color = '#FF462B')



axs[1].plot(ssp1.lev1, color = 'silver', label = 'SSP1 - 2.6')
axs[1].plot(ssp3.lev1, color = 'dimgrey', label = 'SSP3 -7.0')

axs[0].set_xlim([1950,2100])
axs[1].set_xlim([1950,2100])
axs[1].set_ylim([300,900])


plt.subplots_adjust(hspace=0.4)
# Show the plot
plt.tight_layout()
plt.show()
plt.savefig('test.jpg',dpi=1200)

# %%
date = np.arange(1950,2101,1)
fixed = np.copy(date)
fixed[:] = 1
hist = np.copy(fixed)
o1990 = np.copy(date)
