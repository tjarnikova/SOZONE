# %%
rg = False
if rg:
    import xarray as xr
    import numpy as np
    import pandas as pd


    tdir = '/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/'

    mons = ['01','02','03','04','05','06','07','08','09','10','11','12']
    scens = ['1A','1B','2A','2B','3A','3B'] 


    for s in scens:
        print(s)
        if s == 'PI':
            yst = 1950
        else:
            yst = 1950
        for y in range(yst,2100):

            savenam = f'{tdir}nemo_scen_{s}_1m_{y}_fy_grid-T-rg.nc'
            print(savenam)

            Jan = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0101-{y}0201_grid-T-rg.nc')
            Feb = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0201-{y}0301_grid-T-rg.nc')
            Mar = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0301-{y}0401_grid-T-rg.nc')
            Apr = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0401-{y}0501_grid-T-rg.nc')  
            May = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0501-{y}0601_grid-T-rg.nc')
            Jun = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0601-{y}0701_grid-T-rg.nc')
            Jul = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0701-{y}0801_grid-T-rg.nc')
            Aug = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0801-{y}0901_grid-T-rg.nc')
            Sep = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0901-{y}1001_grid-T-rg.nc')
            Oct = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1001-{y}1101_grid-T-rg.nc')  
            Nov = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1101-{y}1201_grid-T-rg.nc')
            Dec = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1201-{y+1}0101_grid-T-rg.nc')

            seasns = np.zeros([12,180,360])
            seasns[0,:,:] = np.nanmean(Jan.somxl010.values, axis = 0)
            seasns[1,:,:] = np.nanmean(Feb.somxl010.values, axis = 0)
            seasns[2,:,:] = np.nanmean(Mar.somxl010.values, axis = 0)
            seasns[3,:,:] = np.nanmean(Apr.somxl010.values, axis = 0)
            seasns[4,:,:] = np.nanmean(May.somxl010.values, axis = 0)
            seasns[5,:,:] = np.nanmean(Jun.somxl010.values, axis = 0)
            seasns[6,:,:] = np.nanmean(Jul.somxl010.values, axis = 0)
            seasns[7,:,:] = np.nanmean(Aug.somxl010.values, axis = 0)
            seasns[8,:,:] = np.nanmean(Sep.somxl010.values, axis = 0)
            seasns[9,:,:] = np.nanmean(Oct.somxl010.values, axis = 0)
            seasns[10,:,:] = np.nanmean(Nov.somxl010.values, axis = 0)
            seasns[11,:,:] = np.nanmean(Dec.somxl010.values, axis = 0)    


            times = pd.to_datetime([f"{y}-01-15", f"{y}-02-15",f"{y}-03-15",
                                    f"{y}-04-15", f"{y}-05-15",f"{y}-06-15", 
                                    f"{y}-07-15", f"{y}-08-15",f"{y}-09-15", 
                                    f"{y}-10-15", f"{y}-11-15",f"{y}-12-15",])


            data_vars = {'somxl010':(['time_counter', 'lat', 'lon'], seasns,
            {'units': 'm',
            'long_name':'Mixed Layer Depth (dsigma = 0.01 wrt 10m)'}),
            }
            # define coordinates
            coords = {'time_counter': (['time_counter'], times),

            'lon': (['lon'], Jan.lon.values),
            'lat': (['lat'], Jan.lat.values),
            }
            # define global attributes
            attrs = {'made in':'/gpfs/home/mep22dku/scratch/SOZONE/windAnalyis/wspdComponents/yearly_regridded_files_medusa.ipynb',

            }
            ds = xr.Dataset(data_vars=data_vars,
            coords=coords,
            attrs=attrs)

            ds.to_netcdf(savenam)

# %%
rg = False
if rg:
    
    import xarray as xr
    import numpy as np
    import pandas as pd


    tdir = '/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/'

    mons = ['01','02','03','04','05','06','07','08','09','10','11','12']
    scens = ['1A','1B','2A','2B','3A','3B'] 


    for s in scens:
        print(s)
        if s == 'PI':
            yst = 1950
        else:
            yst = 1950
        for y in range(yst,2100):

            savenam = f'{tdir}nemo_scen_{s}_1m_{y}_fy_grid-T.nc'
            print(savenam)

            Jan = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0101-{y}0201_grid-T.nc')
            Feb = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0201-{y}0301_grid-T.nc')
            Mar = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0301-{y}0401_grid-T.nc')
            Apr = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0401-{y}0501_grid-T.nc')  
            May = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0501-{y}0601_grid-T.nc')
            Jun = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0601-{y}0701_grid-T.nc')
            Jul = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0701-{y}0801_grid-T.nc')
            Aug = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0801-{y}0901_grid-T.nc')
            Sep = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0901-{y}1001_grid-T.nc')
            Oct = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1001-{y}1101_grid-T.nc')  
            Nov = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1101-{y}1201_grid-T.nc')
            Dec = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1201-{y+1}0101_grid-T.nc')

            seasns = np.zeros([12,332,362])
            seasns[0,:,:] = np.nanmean(Jan.somxl010.values, axis = 0)
            seasns[1,:,:] = np.nanmean(Feb.somxl010.values, axis = 0)
            seasns[2,:,:] = np.nanmean(Mar.somxl010.values, axis = 0)
            seasns[3,:,:] = np.nanmean(Apr.somxl010.values, axis = 0)
            seasns[4,:,:] = np.nanmean(May.somxl010.values, axis = 0)
            seasns[5,:,:] = np.nanmean(Jun.somxl010.values, axis = 0)
            seasns[6,:,:] = np.nanmean(Jul.somxl010.values, axis = 0)
            seasns[7,:,:] = np.nanmean(Aug.somxl010.values, axis = 0)
            seasns[8,:,:] = np.nanmean(Sep.somxl010.values, axis = 0)
            seasns[9,:,:] = np.nanmean(Oct.somxl010.values, axis = 0)
            seasns[10,:,:] = np.nanmean(Nov.somxl010.values, axis = 0)
            seasns[11,:,:] = np.nanmean(Dec.somxl010.values, axis = 0)    


            times = pd.to_datetime([f"{y}-01-15", f"{y}-02-15",f"{y}-03-15",
                                    f"{y}-04-15", f"{y}-05-15",f"{y}-06-15", 
                                    f"{y}-07-15", f"{y}-08-15",f"{y}-09-15", 
                                    f"{y}-10-15", f"{y}-11-15",f"{y}-12-15",])


            data_vars = {'somxl010':(['time_counter', 'y', 'x'], seasns,
            {'units': 'm',
            'long_name':'Mixed Layer Depth (dsigma = 0.01 wrt 10m)'}),
            }
            # define coordinates
            coords = {'time_counter': (['time_counter'], times),

            'nav_lon': (['y','x'], Jan.nav_lon.values),
            'nav_lat': (['y','x'], Jan.nav_lat.values),
            }
            # define global attributes
            attrs = {'made in':'/gpfs/home/mep22dku/scratch/SOZONE/windAnalyis/wspdComponents/yearly_regridded_files_medusa.ipynb',

            }
            ds = xr.Dataset(data_vars=data_vars,
            coords=coords,
            attrs=attrs)

            ds.to_netcdf(savenam)

# %%
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_38620/2179288947.py in <module>
# ----> 1 import xarray as xr
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/__init__.py in <module>
#       1 import pkg_resources
#       2
# ----> 3 from . import testing, tutorial, ufuncs
#       4 from .backends.api import (
#       5     load_dataarray,
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/testing.py in <module>
#       4
#       5 import numpy as np
# ----> 6 import pandas as pd
#       7
#       8 from xarray.core import duck_array_ops, formatting, utils
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/pandas/__init__.py in <module>
#     177
#     178 from pandas.util._tester import test
# --> 179 import pandas.testing
#     180 import pandas.arrays
#     181
#
# ...

# %%
import matplotlib.pyplot as plt
import xarray as xr
# import sys
# sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
# #list of models
# sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
# import utils as ut

# %matplotlib inline
import warnings
# from datetime import datetime
warnings.filterwarnings('ignore')

rg = True
if rg:
    import xarray as xr
    import numpy as np
    import pandas as pd


    tdir = '/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/'

    mons = ['01','02','03','04','05','06','07','08','09','10','11','12']
    scens = ['2B','3A','3B'] 


    for s in scens:
        print(s)
        if s == '2B':
            yst = 1994
        else:
            yst = 1950
        for y in range(yst,2100):

            savenam = f'{tdir}nemo_scen_{s}_1m_{y}_fy_grid-T.nc'
            print(savenam)

            Jan = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0101-{y}0201_grid-T.nc')
            Feb = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0201-{y}0301_grid-T.nc')
            Mar = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0301-{y}0401_grid-T.nc')
            Apr = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0401-{y}0501_grid-T.nc')  
            May = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0501-{y}0601_grid-T.nc')
            Jun = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0601-{y}0701_grid-T.nc')
            Jul = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0701-{y}0801_grid-T.nc')
            Aug = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0801-{y}0901_grid-T.nc')
            Sep = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0901-{y}1001_grid-T.nc')
            Oct = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1001-{y}1101_grid-T.nc')  
            Nov = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1101-{y}1201_grid-T.nc')
            Dec = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1201-{y+1}0101_grid-T.nc')

            seasns = np.zeros([12,75,332,362])
            seasns[0,:,:,:] = np.nanmean(Jan.thetao.values, axis = 0)
            seasns[1,:,:,:] = np.nanmean(Feb.thetao.values, axis = 0)
            seasns[2,:,:,:] = np.nanmean(Mar.thetao.values, axis = 0)
            seasns[3,:,:,:] = np.nanmean(Apr.thetao.values, axis = 0)
            seasns[4,:,:,:] = np.nanmean(May.thetao.values, axis = 0)
            seasns[5,:,:,:] = np.nanmean(Jun.thetao.values, axis = 0)
            seasns[6,:,:,:] = np.nanmean(Jul.thetao.values, axis = 0)
            seasns[7,:,:,:] = np.nanmean(Aug.thetao.values, axis = 0)
            seasns[8,:,:,:] = np.nanmean(Sep.thetao.values, axis = 0)
            seasns[9,:,:,:] = np.nanmean(Oct.thetao.values, axis = 0)
            seasns[10,:,:,:] = np.nanmean(Nov.thetao.values, axis = 0)
            seasns[11,:,:,:] = np.nanmean(Dec.thetao.values, axis = 0)    

            salt = np.zeros([12,75,332,362])
            salt[0,:,:,:] = np.nanmean(Jan.so.values, axis = 0)
            salt[1,:,:,:] = np.nanmean(Feb.so.values, axis = 0)
            salt[2,:,:,:] = np.nanmean(Mar.so.values, axis = 0)
            salt[3,:,:,:] = np.nanmean(Apr.so.values, axis = 0)
            salt[4,:,:,:] = np.nanmean(May.so.values, axis = 0)
            salt[5,:,:,:] = np.nanmean(Jun.so.values, axis = 0)
            salt[6,:,:,:] = np.nanmean(Jul.so.values, axis = 0)
            salt[7,:,:,:] = np.nanmean(Aug.so.values, axis = 0)
            salt[8,:,:,:] = np.nanmean(Sep.so.values, axis = 0)
            salt[9,:,:,:] = np.nanmean(Oct.so.values, axis = 0)
            salt[10,:,:,:] = np.nanmean(Nov.so.values, axis = 0)
            salt[11,:,:,:] = np.nanmean(Dec.so.values, axis = 0)    
            

            times = pd.to_datetime([f"{y}-01-15", f"{y}-02-15",f"{y}-03-15",
                                    f"{y}-04-15", f"{y}-05-15",f"{y}-06-15", 
                                    f"{y}-07-15", f"{y}-08-15",f"{y}-09-15", 
                                    f"{y}-10-15", f"{y}-11-15",f"{y}-12-15",])


            data_vars = {
                'thetao':(['time_counter', 'deptht', 'y', 'x'], seasns,
            {'units': 'degC',
            'long_name':'Sea Water Potential Temperature'}),
                'so':(['time_counter', 'deptht', 'y', 'x'], salt,
            {'units': '0.001',
            'long_name':'Sea Water Salinity'}),
            }
            # define coordinates
            coords = {'time_counter': (['time_counter'], times),
            'deptht': (['deptht'], Jan.deptht.values),
            'nav_lon': (['y','x'], Jan.nav_lon.values),
            'nav_lat': (['y','x'], Jan.nav_lat.values),
            }
            # define global attributes
            attrs = {'made in':'/gpfs/home/mep22dku/scratch/SOZONE/windAnalyis/oceanFields/yearly_regridded_files_medusa.ipynb',

            }
            ds = xr.Dataset(data_vars=data_vars,
            coords=coords,
            attrs=attrs)

            ds.to_netcdf(savenam)
# Out:
# 2B
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_1994_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_1995_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_1996_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_1997_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_1998_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_1999_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_2000_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_2001_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_2B_1m_2002_fy_grid-T.nc
# ...

# %%
w = xr.open_dataset('/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_scen_1A_1m_1950_fy_grid-T.nc')

# %%
import matplotlib.pyplot as plt
import xarray as xr
# import sys
# sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
# #list of models
# sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
# import utils as ut

# %matplotlib inline
import warnings
# from datetime import datetime
warnings.filterwarnings('ignore')

plt.pcolormesh(w.so[7,24,:,:])
