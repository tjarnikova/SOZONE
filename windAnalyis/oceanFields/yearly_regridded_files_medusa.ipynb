# %%
rg = False
if rg:
    import xarray as xr
    import numpy as np
    import pandas as pd


    tdir = '/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/'

    mons = ['01','02','03','04','05','06','07','08','09','10','11','12']
    scens = ['1A','1B','2A','2B','3A','3B'] 


    for s in scens:
        print(s)
        if s == 'PI':
            yst = 1950
        else:
            yst = 1950
        for y in range(yst,2100):

            savenam = f'{tdir}nemo_scen_{s}_1m_{y}_fy_grid-T-rg.nc'
            print(savenam)

            Jan = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0101-{y}0201_grid-T-rg.nc')
            Feb = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0201-{y}0301_grid-T-rg.nc')
            Mar = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0301-{y}0401_grid-T-rg.nc')
            Apr = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0401-{y}0501_grid-T-rg.nc')  
            May = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0501-{y}0601_grid-T-rg.nc')
            Jun = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0601-{y}0701_grid-T-rg.nc')
            Jul = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0701-{y}0801_grid-T-rg.nc')
            Aug = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0801-{y}0901_grid-T-rg.nc')
            Sep = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0901-{y}1001_grid-T-rg.nc')
            Oct = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1001-{y}1101_grid-T-rg.nc')  
            Nov = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1101-{y}1201_grid-T-rg.nc')
            Dec = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1201-{y+1}0101_grid-T-rg.nc')

            seasns = np.zeros([12,180,360])
            seasns[0,:,:] = np.nanmean(Jan.somxl010.values, axis = 0)
            seasns[1,:,:] = np.nanmean(Feb.somxl010.values, axis = 0)
            seasns[2,:,:] = np.nanmean(Mar.somxl010.values, axis = 0)
            seasns[3,:,:] = np.nanmean(Apr.somxl010.values, axis = 0)
            seasns[4,:,:] = np.nanmean(May.somxl010.values, axis = 0)
            seasns[5,:,:] = np.nanmean(Jun.somxl010.values, axis = 0)
            seasns[6,:,:] = np.nanmean(Jul.somxl010.values, axis = 0)
            seasns[7,:,:] = np.nanmean(Aug.somxl010.values, axis = 0)
            seasns[8,:,:] = np.nanmean(Sep.somxl010.values, axis = 0)
            seasns[9,:,:] = np.nanmean(Oct.somxl010.values, axis = 0)
            seasns[10,:,:] = np.nanmean(Nov.somxl010.values, axis = 0)
            seasns[11,:,:] = np.nanmean(Dec.somxl010.values, axis = 0)    


            times = pd.to_datetime([f"{y}-01-15", f"{y}-02-15",f"{y}-03-15",
                                    f"{y}-04-15", f"{y}-05-15",f"{y}-06-15", 
                                    f"{y}-07-15", f"{y}-08-15",f"{y}-09-15", 
                                    f"{y}-10-15", f"{y}-11-15",f"{y}-12-15",])


            data_vars = {'somxl010':(['time_counter', 'lat', 'lon'], seasns,
            {'units': 'm',
            'long_name':'Mixed Layer Depth (dsigma = 0.01 wrt 10m)'}),
            }
            # define coordinates
            coords = {'time_counter': (['time_counter'], times),

            'lon': (['lon'], Jan.lon.values),
            'lat': (['lat'], Jan.lat.values),
            }
            # define global attributes
            attrs = {'made in':'/gpfs/home/mep22dku/scratch/SOZONE/windAnalyis/wspdComponents/yearly_regridded_files_medusa.ipynb',

            }
            ds = xr.Dataset(data_vars=data_vars,
            coords=coords,
            attrs=attrs)

            ds.to_netcdf(savenam)

# %%
rg = False
if rg:
    import xarray as xr
    import numpy as np
    import pandas as pd


    tdir = '/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/'

    mons = ['01','02','03','04','05','06','07','08','09','10','11','12']
    scens = ['1A','1B','2A','2B','3A','3B'] 


    for s in scens:
        print(s)
        if s == 'PI':
            yst = 1950
        else:
            yst = 1950
        for y in range(yst,2100):

            savenam = f'{tdir}nemo_scen_{s}_1m_{y}_fy_grid-T.nc'
            print(savenam)

            Jan = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0101-{y}0201_grid-T.nc')
            Feb = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0201-{y}0301_grid-T.nc')
            Mar = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0301-{y}0401_grid-T.nc')
            Apr = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0401-{y}0501_grid-T.nc')  
            May = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0501-{y}0601_grid-T.nc')
            Jun = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0601-{y}0701_grid-T.nc')
            Jul = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0701-{y}0801_grid-T.nc')
            Aug = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0801-{y}0901_grid-T.nc')
            Sep = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}0901-{y}1001_grid-T.nc')
            Oct = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1001-{y}1101_grid-T.nc')  
            Nov = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1101-{y}1201_grid-T.nc')
            Dec = xr.open_dataset(f'{tdir}nemo_scen_{s}_1m_{y}1201-{y+1}0101_grid-T.nc')

            seasns = np.zeros([12,332,362])
            seasns[0,:,:] = np.nanmean(Jan.somxl010.values, axis = 0)
            seasns[1,:,:] = np.nanmean(Feb.somxl010.values, axis = 0)
            seasns[2,:,:] = np.nanmean(Mar.somxl010.values, axis = 0)
            seasns[3,:,:] = np.nanmean(Apr.somxl010.values, axis = 0)
            seasns[4,:,:] = np.nanmean(May.somxl010.values, axis = 0)
            seasns[5,:,:] = np.nanmean(Jun.somxl010.values, axis = 0)
            seasns[6,:,:] = np.nanmean(Jul.somxl010.values, axis = 0)
            seasns[7,:,:] = np.nanmean(Aug.somxl010.values, axis = 0)
            seasns[8,:,:] = np.nanmean(Sep.somxl010.values, axis = 0)
            seasns[9,:,:] = np.nanmean(Oct.somxl010.values, axis = 0)
            seasns[10,:,:] = np.nanmean(Nov.somxl010.values, axis = 0)
            seasns[11,:,:] = np.nanmean(Dec.somxl010.values, axis = 0)    


            times = pd.to_datetime([f"{y}-01-15", f"{y}-02-15",f"{y}-03-15",
                                    f"{y}-04-15", f"{y}-05-15",f"{y}-06-15", 
                                    f"{y}-07-15", f"{y}-08-15",f"{y}-09-15", 
                                    f"{y}-10-15", f"{y}-11-15",f"{y}-12-15",])


            data_vars = {'somxl010':(['time_counter', 'y', 'x'], seasns,
            {'units': 'm',
            'long_name':'Mixed Layer Depth (dsigma = 0.01 wrt 10m)'}),
            }
            # define coordinates
            coords = {'time_counter': (['time_counter'], times),

            'nav_lon': (['y','x'], Jan.nav_lon.values),
            'nav_lat': (['y','x'], Jan.nav_lat.values),
            }
            # define global attributes
            attrs = {'made in':'/gpfs/home/mep22dku/scratch/SOZONE/windAnalyis/wspdComponents/yearly_regridded_files_medusa.ipynb',

            }
            ds = xr.Dataset(data_vars=data_vars,
            coords=coords,
            attrs=attrs)

            ds.to_netcdf(savenam)
# Out:
# 1A
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_1A_1m_1950_fy_grid-T.nc
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:38: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:40: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:41: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:42: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:43: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:45: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:47: RuntimeWarning: Mean of empty slice
# /gpfs/home/mep22dku/.conda/envs/swamp2/lib/python3.7/site-packages/ipykernel_launcher.py:48: RuntimeWarning: Mean of empty slice
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_1A_1m_1951_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_1A_1m_1952_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_1A_1m_1953_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_1A_1m_
fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2020_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2021_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2022_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2023_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2024_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2025_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2026_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2027_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2028_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2029_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2030_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2031_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2032_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2033_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2034_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2035_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2036_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2037_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2038_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2039_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2040_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2041_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2042_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2043_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2044_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2045_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2046_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2047_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2048_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2049_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2050_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2051_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2052_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2053_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2054_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2055_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2056_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2057_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2058_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2059_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2060_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2061_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2062_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2063_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2064_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2065_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2066_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2067_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2068_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2069_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2070_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2071_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2072_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2073_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2074_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2075_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2076_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2077_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2078_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2079_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2080_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2081_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2082_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2083_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2084_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2085_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2086_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_2A_1m_2087_fy_grid-T.nc
# ...
# 3B
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1950_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1951_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1952_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1953_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1954_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1955_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1956_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1957_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1958_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1959_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1960_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1961_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1962_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1963_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1964_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1965_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1966_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1967_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1968_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1969_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1970_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1971_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1972_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1973_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1974_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1975_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1976_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1977_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1978_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1979_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1980_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1981_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1982_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1983_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1984_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1985_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1986_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1987_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1988_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1989_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1990_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1991_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1992_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1993_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1994_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1995_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1996_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1997_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1998_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_1999_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2000_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2001_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2002_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2003_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2004_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2005_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2006_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2007_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2008_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2009_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2010_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2011_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2012_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2013_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2014_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2015_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2016_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2017_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2018_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2019_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2020_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2021_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2022_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2023_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2024_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2025_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2026_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2027_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2028_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2029_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2030_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2031_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2032_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2033_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2034_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2035_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2036_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2037_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2038_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2039_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2040_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2041_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2042_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2043_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2044_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2045_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2046_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2047_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2048_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2049_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2050_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2051_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2052_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2053_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2054_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2055_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2056_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2057_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2058_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2059_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2060_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2061_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2062_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2063_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2064_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2065_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2066_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2067_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2068_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2069_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2070_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2071_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2072_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2073_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2074_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2075_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2076_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2077_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2078_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2079_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2080_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2081_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2082_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2083_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2084_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2085_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2086_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2087_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2088_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2089_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2090_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2091_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2092_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2093_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2094_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2095_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2096_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2097_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2098_fy_grid-T.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_scen_3B_1m_2099_fy_grid-T.nc

# %%
# Out:
# <xarray.Dataset>
# Dimensions:        (time_counter: 1, x: 362, y: 332)
# Coordinates:
#     nav_lat        (y, x) float32 ...
#     nav_lon        (y, x) float32 ...
#     time_centered  (time_counter) object ...
#   * time_counter   (time_counter) float64 0.0
# Dimensions without coordinates: x, y
# Data variables:
#     somxl010       (time_counter, y, x) float32 nan nan nan nan ... nan nan nan
# Attributes:
#     name:         bc370o_1m_19500101_19500330
#     description:  ocean T grid variables
#     title:        ocean T grid variables
#     Conventions:  CF-1.5
#     production:   An IPSL model
#     timeStamp:    2018-Nov-29 07:12:47 UTC
#     ibegin:       0
#     ni:           362
#     jbegin:       0
#     nj:           56
#     file_name:    nemo_bc370o_1m_19500101-19500201_grid-T.nc
#     TimeStamp:    29/11/2018 08:33:20 +0000
#     history:      Thu Feb  9 20:50:50 2023: /opt/moose/moose-netcdf/bin/ncks ...
#     NCO:          4.4.5

# %%
import matplotlmib.pyplot as plt
for i in range(0,12):
    plt.figure()
    plt.pcolormesh(ds.somxl010[i,:,:])

# %%
Dec.somxl010
