# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle

#import mapfxn as mf
#reload(mf)

plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %% [markdown]
# # check we have all the files

# %%
runhorse = True
if runhorse:
    now = datetime.now()


    rdir = '/gpfs/data/greenocean/software/runs/'
    trun = 'TOM12_TJ_M001'

    #ORCA2_1m_19750101_19751231_ptrc_T.nc
    yr = 1948
    yrs = np.arange(1948,2021,1)

    
    for i in range(0,len(yrs)):
        yr = yrs[i]
        if yr%10==0:
            print(yr)
        #open ptrc_T and grid_T
        w = glob.glob(f'{rdir}{trun}/ORCA*{yr}*ptrc_T.nc')
        tnam = (w[0])
        t_ptrc = nc.Dataset(tnam)
        w = glob.glob(f'{rdir}{trun}/ORCA*{yr}*grid_T.nc')
        tnam = (w[0])
        t_grid = nc.Dataset(tnam)
        print(tnam)
        # sal = t_grid['vosaline'][:,0,0:topend,:]
        # temp = t_grid['votemper'][:,0,0:topend,:]
# Out:
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19480101_19481231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19490101_19491231_grid_T.nc
# 1950
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19500101_19501231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19510101_19511231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19520101_19521231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19530101_19531231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19540101_19541231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19550101_19551231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19560101_19561231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19570101_19571231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19580101_19581231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19590101_19591231_grid_T.nc
# 1960
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19600101_19601231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19610101_19611231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19620101_19621231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19630101_19631231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19640101_19641231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19650101_19651231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19660101_19661231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19670101_19671231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19680101_19681231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19690101_19691231_grid_T.nc
# 1970
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19700101_19701231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19710101_19711231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19720101_19721231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19730101_19731231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19740101_19741231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19750101_19751231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19760101_19761231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19770101_19771231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19780101_19781231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19790101_19791231_grid_T.nc
# 1980
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19800101_19801231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19810101_19811231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19820101_19821231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19830101_19831231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19840101_19841231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19850101_19851231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19860101_19861231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19870101_19871231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19880101_19881231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19890101_19891231_grid_T.nc
# 1990
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19900101_19901231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19910101_19911231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19920101_19921231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19930101_19931231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19940101_19941231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19950101_19951231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19960101_19961231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19970101_19971231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19980101_19981231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_19990101_19991231_grid_T.nc
# 2000
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_20000101_20001231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_20010101_20011231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_20020101_20021231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_20030101_20031231_grid_T.nc
# /gpfs/data/greenocean/software/runs/TOM12_TJ_M001/ORCA2_1m_20040101_20041231_grid_T.nc
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_21036/3772469644.py in <module>
#      18         #open ptrc_T and grid_T
#      19         w = glob.glob(f'{rdir}{trun}/ORCA*{yr}*ptrc_T.nc')
# ---> 20         tnam = (w[0])
#      21         t_ptrc = nc.Dataset(tnam)
#      22         w = glob.glob(f'{rdir}{trun}/ORCA*{yr}*grid_T.nc')
#
# IndexError: list index out of range
