# %% [markdown]
# ### aim: Visualize all GCB outputs, check for holes and compare with last year's
#
# Here is a list of all things requested, first column is variableID (added by TJ to have a clear sequential catalog of the demands)
#
# https://docs.google.com/spreadsheets/d/186mFWSIaPWu7X_RldiGPrPzIuqyNupUR7XwoCBkMaIk/edit#gid=0
#
# Dave's directory, last year's submission: `/gpfs/data/greenocean/GCB/GCB_RECCAP/2022submission`
#
# My directory, this year's submission:
# `/gpfs/data/greenocean/GCB/GCB2023/submissionData2023`

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %%
import xarray as xr
w = xr.open_dataset('/gpfs/data/greenocean/GCB/GCB_universal/GCBstyleOutput/TOM12_TJ_CNA1/sfco2_PlankTOM_1_gr_1990-2020_v20230721.nc')
import matplotlib.pyplot as plt
w = plt.pcolormesh(w.sfco2[100,:,:], vmin = 300, vmax = 500)
plt.colorbar(w)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
DWdir = '/gpfs/data/greenocean/GCB/GCB2023/submissionData2023/RIV12/'
TJdir = '/gpfs/data/greenocean/GCB/GCB2023/submissionData2023/SI52/'

# %%
TJ_tfil_A = xr.open_dataset(glob.glob(f'{TJdir}/integrated_timelines_PlankTOM_A_*1959-2022*.nc')[0])

# %% [markdown]
# ### VarID 1-6 (key flag -1)
#
#     1	fgco2_glob
#     2	fgco2_reg
#     3	intDIC_1994_glob
#     4	intDIC_1994_reg
#     5	intDIC_2007_glob
#     6	intDIC_2007_reg

# %%
TJ_tfil_A = xr.open_dataset(glob.glob(f'{TJdir}/integrated_timelines_PlankTOM_A_*1959-2022*.nc')[0])
# TJ_tfil_B = xr.open_dataset(glob.glob(f'{TJdir}/integrated_timelines_PlankTOM_B_*1959-2022*.nc')[0])
# TJ_tfil_C = xr.open_dataset(glob.glob(f'{TJdir}/integrated_timelines_PlankTOM_C_*1959-2022*.nc')[0])
# TJ_tfil_D = xr.open_dataset(glob.glob(f'{TJdir}/integrated_timelines_PlankTOM_D_*1959-2022*.nc')[0])

DW_tfil_A = xr.open_dataset(glob.glob(f'{DWdir}/integrated_timelines_PlankTOM_A_*1959-2022*.nc')[0])
DW_tfil_B = xr.open_dataset(glob.glob(f'{DWdir}/integrated_timelines_PlankTOM_B_*1959-2022*.nc')[0])
DW_tfil_C = xr.open_dataset(glob.glob(f'{DWdir}/integrated_timelines_PlankTOM_C_*1959-2022*.nc')[0])
DW_tfil_D = xr.open_dataset(glob.glob(f'{DWdir}/integrated_timelines_PlankTOM_D_*1959-2022*.nc')[0])

fact = 1.6
fig, axs = plt.subplots(2,2, figsize=(12*fact, 8*fact), facecolor='w', edgecolor='k')
axs = axs.ravel()

axs[0].plot(TJ_tfil_A.TIME, TJ_tfil_A.fgco2_glob, color = 'r', label = '2023 GEA0 A', linestyle = '-')
# axs[0].plot(TJ_tfil_B.TIME, TJ_tfil_B.fgco2_glob, color = 'y', label = '2023 GEB0 B', linestyle = '-')
# axs[0].plot(TJ_tfil_C.TIME, TJ_tfil_C.fgco2_glob, color = 'b', label = '2023 GEC0 C', linestyle = '-')
# axs[0].plot(TJ_tfil_D.TIME, TJ_tfil_D.fgco2_glob, color = 'g', label = '2023 GED0 D', linestyle = '-')
axs[0].plot(DW_tfil_A.TIME, DW_tfil_A.fgco2_glob, color = 'r', label = '2022 A', linestyle = ':')
axs[0].plot(DW_tfil_B.TIME, DW_tfil_B.fgco2_glob, color = 'y', label = '2022 B', linestyle = ':')
axs[0].plot(DW_tfil_C.TIME, DW_tfil_C.fgco2_glob, color = 'b', label = '2022 C', linestyle = ':')
axs[0].plot(DW_tfil_D.TIME, DW_tfil_D.fgco2_glob, color = 'g', label = '2022 D', linestyle = ':')
axs[0].set_title('full globe, pG/yr')

# axs[1].plot(TJ_tfil_A.TIME, TJ_tfil_A.fgco2_reg[:,0], color = 'r', label = '2023 GEA0 A', linestyle = '-')
# axs[1].plot(TJ_tfil_B.TIME, TJ_tfil_B.fgco2_reg[:,0], color = 'y', label = '2023 GEB0 B', linestyle = '-')
# axs[1].plot(TJ_tfil_C.TIME, TJ_tfil_C.fgco2_reg[:,0], color = 'b', label = '2023 GEC0 C', linestyle = '-')
# axs[1].plot(TJ_tfil_D.TIME, TJ_tfil_D.fgco2_reg[:,0], color = 'g', label = '2023 GED0 D', linestyle = '-')
# axs[1].set_title('south (-90 - -30), pG/yr')

# axs[2].plot(TJ_tfil_A.TIME, TJ_tfil_A.fgco2_reg[:,1], color = 'r', label = '2023 GEA0 A', linestyle = '-')
# axs[2].plot(TJ_tfil_B.TIME, TJ_tfil_B.fgco2_reg[:,1], color = 'y', label = '2023 GEB0 B', linestyle = '-')
# axs[2].plot(TJ_tfil_C.TIME, TJ_tfil_C.fgco2_reg[:,1], color = 'b', label = '2023 GEC0 C', linestyle = '-')
# axs[2].plot(TJ_tfil_D.TIME, TJ_tfil_D.fgco2_reg[:,1], color = 'g', label = '2023 GED0 D', linestyle = '-')
# axs[2].set_title('tropics (-30 - 30), pG/yr')

# axs[3].plot(TJ_tfil_A.TIME, TJ_tfil_A.fgco2_reg[:,2], color = 'r', label = '2023 GEA0 A', linestyle = '-')
# axs[3].plot(TJ_tfil_B.TIME, TJ_tfil_B.fgco2_reg[:,2], color = 'y', label = '2023 GEB0 B', linestyle = '-')
# axs[3].plot(TJ_tfil_C.TIME, TJ_tfil_C.fgco2_reg[:,2], color = 'b', label = '2023 GEC0 C', linestyle = '-')
# axs[3].plot(TJ_tfil_D.TIME, TJ_tfil_D.fgco2_reg[:,2], color = 'g', label = '2023 GED0 D', linestyle = '-')
# axs[3].set_title('north (30 - 90), pG/yr')

# axs[0].legend(ncol = 2, loc = 'best', fontsize = 11)
# Out:
# Text(0.5, 1.0, 'full globe, pG/yr')

# %%
fact = 1.1
fig, axs = plt.subplots(1,4, figsize=(16*fact, 4*fact), facecolor='w', edgecolor='k')
axs = axs.ravel()
axs[0].plot(1994,TJ_tfil_A.intDIC_1994_glob,'r*', label = '2023 GEA0')
axs[0].plot(1994,TJ_tfil_B.intDIC_1994_glob,'y*', label = '2023 GEB0')
axs[0].plot(1994,TJ_tfil_C.intDIC_1994_glob,'b*', label = '2023 GEC0')
axs[0].plot(1994,TJ_tfil_D.intDIC_1994_glob,'g*', label = '2023 GED0')
axs[0].plot(2007,TJ_tfil_A.intDIC_2007_glob,'r*')
axs[0].plot(2007,TJ_tfil_B.intDIC_2007_glob,'y*')
axs[0].plot(2007,TJ_tfil_C.intDIC_2007_glob,'b*')
axs[0].plot(2007,TJ_tfil_D.intDIC_2007_glob,'g*')

axs[0].plot(1994,DW_tfil_A.intDIC_1994_glob,'r+', label = '2022 A')
axs[0].plot(1994,DW_tfil_B.intDIC_1994_glob,'y+', label = '2022 B')
axs[0].plot(1994,DW_tfil_C.intDIC_1994_glob,'b+', label = '2022 C')
axs[0].plot(1994,DW_tfil_D.intDIC_1994_glob,'g+', label = '2022 D')
axs[0].plot(2007,DW_tfil_A.intDIC_2007_glob,'r+')
axs[0].plot(2007,DW_tfil_B.intDIC_2007_glob,'y+')
axs[0].plot(2007,DW_tfil_C.intDIC_2007_glob,'b+')
axs[0].plot(2007,DW_tfil_D.intDIC_2007_glob,'g+')

axs[1].plot(1994,TJ_tfil_A.intDIC_1994_reg[0],'r*')
axs[1].plot(1994,TJ_tfil_B.intDIC_1994_reg[0],'y*')
axs[1].plot(1994,TJ_tfil_C.intDIC_1994_reg[0],'b*')
axs[1].plot(1994,TJ_tfil_D.intDIC_1994_reg[0],'g*')
axs[1].plot(2007,TJ_tfil_A.intDIC_2007_reg[0],'r*')
axs[1].plot(2007,TJ_tfil_B.intDIC_2007_reg[0],'y*')
axs[1].plot(2007,TJ_tfil_C.intDIC_2007_reg[0],'b*')
axs[1].plot(2007,TJ_tfil_D.intDIC_2007_reg[0],'g*')

axs[1].plot(1994,DW_tfil_A.intDIC_1994_reg[0],'r+')
axs[1].plot(1994,DW_tfil_B.intDIC_1994_reg[0],'y+')
axs[1].plot(1994,DW_tfil_C.intDIC_1994_reg[0],'b+')
axs[1].plot(1994,DW_tfil_D.intDIC_1994_reg[0],'g+')
axs[1].plot(2007,DW_tfil_A.intDIC_2007_reg[0],'r+')
axs[1].plot(2007,DW_tfil_B.intDIC_2007_reg[0],'y+')
axs[1].plot(2007,DW_tfil_C.intDIC_2007_reg[0],'b+')
axs[1].plot(2007,DW_tfil_D.intDIC_2007_reg[0],'g+')

axs[2].plot(1994,TJ_tfil_A.intDIC_1994_reg[1],'r*')
axs[2].plot(1994,TJ_tfil_B.intDIC_1994_reg[1],'y*')
axs[2].plot(1994,TJ_tfil_C.intDIC_1994_reg[1],'b*')
axs[2].plot(1994,TJ_tfil_D.intDIC_1994_reg[1],'g*')
axs[2].plot(2007,TJ_tfil_A.intDIC_2007_reg[1],'r*')
axs[2].plot(2007,TJ_tfil_B.intDIC_2007_reg[1],'y*')
axs[2].plot(2007,TJ_tfil_C.intDIC_2007_reg[1],'b*')
axs[2].plot(2007,TJ_tfil_D.intDIC_2007_reg[1],'g*')

axs[2].plot(1994,DW_tfil_A.intDIC_1994_reg[1],'r+')
axs[2].plot(1994,DW_tfil_B.intDIC_1994_reg[1],'y+')
axs[2].plot(1994,DW_tfil_C.intDIC_1994_reg[1],'b+')
axs[2].plot(1994,DW_tfil_D.intDIC_1994_reg[1],'g+')
axs[2].plot(2007,DW_tfil_A.intDIC_2007_reg[1],'r+')
axs[2].plot(2007,DW_tfil_B.intDIC_2007_reg[1],'y+')
axs[2].plot(2007,DW_tfil_C.intDIC_2007_reg[1],'b+')
axs[2].plot(2007,DW_tfil_D.intDIC_2007_reg[1],'g+')

axs[3].plot(1994,TJ_tfil_A.intDIC_1994_reg[2],'r*')
axs[3].plot(1994,TJ_tfil_B.intDIC_1994_reg[2],'y*')
axs[3].plot(1994,TJ_tfil_C.intDIC_1994_reg[2],'b*')
axs[3].plot(1994,TJ_tfil_D.intDIC_1994_reg[2],'g*')
axs[3].plot(2007,TJ_tfil_A.intDIC_2007_reg[2],'r*')
axs[3].plot(2007,TJ_tfil_B.intDIC_2007_reg[2],'y*')
axs[3].plot(2007,TJ_tfil_C.intDIC_2007_reg[2],'b*')
axs[3].plot(2007,TJ_tfil_D.intDIC_2007_reg[2],'g*')

axs[3].plot(1994,DW_tfil_A.intDIC_1994_reg[2],'r+')
axs[3].plot(1994,DW_tfil_B.intDIC_1994_reg[2],'y+')
axs[3].plot(1994,DW_tfil_C.intDIC_1994_reg[2],'b+')
axs[3].plot(1994,DW_tfil_D.intDIC_1994_reg[2],'g+')
axs[3].plot(2007,DW_tfil_A.intDIC_2007_reg[2],'r+')
axs[3].plot(2007,DW_tfil_B.intDIC_2007_reg[2],'y+')
axs[3].plot(2007,DW_tfil_C.intDIC_2007_reg[2],'b+')
axs[3].plot(2007,DW_tfil_D.intDIC_2007_reg[2],'g+')


tits = ['full globe', 'south -90 - -30', 'tropics -30 - 30 ', 'north 30 - 90']

for i in range(0,4):
    axs[i].grid()
    axs[i].set_title(tits[i])
    
plt.suptitle('carbon inventory pG C')
plt.tight_layout()

# %%
def plot_2007(fig, axs, i, tfil,ttit,tvmin,tvmax,tcmap = 'Spectral', checkamts = False):
    tdat = np.nanmean(tfil[tvar][576:576+12,:,:].values, axis = 0)
    if checkamts:
        print(np.nanmax(tdat))
        print(np.nanmin(tdat))
    tun =(tfil[tvar].units)
    w = axs[i].pcolormesh(tdat, cmap = tcmap, vmin = tvmin, vmax= tvmax)
    axs[i].set_title(ttit)
    plt.colorbar(w, ax = axs[i], label = tun)
    axs[i].set_xticks([])
    axs[i].set_yticks([])

def checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam = True ):
    TJ_tfil_A = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_A_1_gr_1959-2022_*')[0])
    TJ_tfil_B = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_B_1_gr_1959-2022_*')[0])
    TJ_tfil_C = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_C_1_gr_1959-2022_*')[0])
    TJ_tfil_D = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_D_1_gr_1959-2022_*')[0])

    DW_tfil_A = xr.open_dataset(glob.glob(f'{DWdir}/PlankTOM_Sim_2022_A_{tvar}.nc')[0])
    DW_tfil_B = xr.open_dataset(glob.glob(f'{DWdir}/PlankTOM_Sim_2022_B_{tvar}.nc')[0])
    DW_tfil_C = xr.open_dataset(glob.glob(f'{DWdir}/PlankTOM_Sim_2022_C_{tvar}.nc')[0])
    DW_tfil_D = xr.open_dataset(glob.glob(f'{DWdir}/PlankTOM_Sim_2022_D_{tvar}.nc')[0])

    #year 2007
    tsuptit = f'{tvar}, year 2007'
    fact = 1.1
    fig, axs = plt.subplots(2,4, figsize=(16*fact, 8*fact), facecolor='w', edgecolor='k')
    axs = axs.ravel()

    fils = [DW_tfil_A, DW_tfil_B, DW_tfil_C, DW_tfil_D, TJ_tfil_A, TJ_tfil_B, TJ_tfil_C, TJ_tfil_D, ]
    tits = ['GCB 2022, A','GCB 2022, B', 'GCB 2022, C', 'GCB 2022, D',\
           '2023 GEA0','2023 GEB0','2023 GEC0','2023 GED0']

    for i in range(0,8):
        plot_2007(fig, axs, i, fils[i],tits[i],tvmin,tvmax,tcmap = tcmap, checkamts = checkam)

    plt.suptitle(tsuptit)

# %% [markdown]
# ### VarID 7 (key flag 0): fgco2

# %%
tvar = 'fgco2'
tcmap = cm.balance_r
tvmin = -2e-7; tvmax = 2e-7
checkam = False

checkvis_2007(tvar, tcmap, tvmin, tvmax, False)

# %% [markdown]
# ### VarID 8 (key flag 23): sfco2

# %%
tvar = 'sfco2'
tcmap = cm.balance
tvmin = 0+100; tvmax = 382.99+382.99-100
checkam = False

checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)

# %% [markdown]
# ### VarID 9 (key flag 2): fice

# %%
tvar = 'fice'
tcmap = cm.ice
tvmin = 0; tvmax = 1
checkam = False

checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)

# %% [markdown]
# ### VarID 10 (key flag 10): dissicos

# %%
tvar = 'dissicos'
tcmap = 'Spectral'
tvmin = 1.8; tvmax = 2.5
checkam = False

checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)

# %% [markdown]
# ### VarID 11 (key flag 11): talkos

# %%
tvar = 'talkos'
tcmap = 'Spectral'
tvmin = 1.8; tvmax = 2.5
checkam = False

checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)

# %% [markdown]
# ### VarID 12 (key flag 8): tos

# %%
# tvar = 'tos'
# tcmap = 'Spectral'
# tvmin = 0; tvmax = 20
# checkam = False

# checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_60286/103551663.py in <module>
#       4 checkam = False
#       5
# ----> 6 checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)
#
# /tmp/ipykernel_60286/813084813.py in checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)
#      13 def checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam = True ):
#      14     TJ_tfil_A = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_A_1_gr_1959-2022_*')[0])
# ---> 15     TJ_tfil_B = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_B_1_gr_1959-2022_*')[0])
#      16     TJ_tfil_C = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_C_1_gr_1959-2022_*')[0])
#      17     TJ_tfil_D = xr.open_dataset(glob.glob(f'{TJdir}/{tvar}_PlankTOM_D_1_gr_1959-2022_*')[0])
#
# IndexError: list index out of range

# %% [markdown]
# ### VarID 13 (key flag 9): sos

# %%
# tvar = 'tos'
# tcmap = 'Spectral'
# tvmin = 0; tvmax = 20
# checkam = False

# checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)

# %% [markdown]
# ### VarID 14 (key flag 24): intdic

# %%
# tvar = 'tos'
# tcmap = 'Spectral'
# tvmin = 0; tvmax = 20
# checkam = False

# checkvis_2007(tvar, tcmap, tvmin, tvmax, checkam)
