# %% [markdown]
# ### aim: víš, co tu máš? check MEDUSA transfered data for holes
#
# ### date: 2023-04-12
#
# data downloaded to:
#
# `/gpfs/data/greenocean/software/resources/MEDUSA`
#
#
#     drwxr-xr-x  4 mep22dku greenocean   1048576 Feb 13 19:50 ukesm_allscen_gridT_mld/
#     drwxr-xr-x  2 mep22dku greenocean   1048576 Feb 25 00:09 ukesm_allscen_diadT_aux/
#     drwxr-xr-x  2 mep22dku greenocean   1048576 Mar 20 09:55 ukesm_allscen_ptrcT_TADIC/
#     drwxr-sr-x  3 mep22dku greenocean   1048576 Mar 24 16:17 ukesm_allscen_gridT_TS/
#     drwxr-xr-x  2 mep22dku greenocean    524288 Mar 27 10:45 ukesm_allscen_gridV_vo/

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import glob
import numpy as np
import xarray as xr

# %%
def check_filetype_present(tdir, yr,runname,rtype):

    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/{tdir}/*_{runname}*1m_{yr}*{rtype}*nc'

    tw = glob.glob(savenam)
    #print(tw)
    ### need 12 monthly files
    if len(tw) != 12:
        print(f'{yr}, {runname} {rtype} missing')
    else:
        pass
    
def check_full_scenario(tdir, rtype):
    print(tdir)
    #1h
    runname = 'bc370'
    print(f'checking {runname}')
    yrs = np.arange(1950,2015,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)    
    #1a
    runname = 'be682'
    print(f'checking {runname}')
    yrs = np.arange(2015,2100,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)
    print()
    #1b
    runname= 'ce417'
    print(f'checking {runname}')
    yrs = np.arange(2015,2100,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)
    print()
    # #2h
    runname = 'cj198'
    print(f'checking {runname}')
    yrs = np.arange(1950,2015,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)    
    print()
    # #2a
    runname = 'cj880'
    print(f'checking {runname}')
    yrs = np.arange(2015,2100,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)
    print()    
    # #2b
    runname= 'cj881'
    print(f'checking {runname}')
    yrs = np.arange(2015,2100,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)

    print()    
    # #3h
    runname = 'cj200'
    print(f'checking {runname}')
    yrs = np.arange(1990,2015,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)    
    print()
    # #3a
    runname = 'cj484'
    print(f'checking {runname}')
    yrs = np.arange(2015,2100,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)    
    print()    
    # #3a
    runname = 'cj504'
    print(f'checking {runname}')
    yrs = np.arange(2015,2100,1)
    for y in yrs:
        check_filetype_present(tdir, y,runname,rtype)

# %% [markdown]
# ## mld - all ok.
#
# [mep22dku@c0006 /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld]$ ncdump -h nemo_cj881o_1m_20431201-20440101_grid-T.nc
# netcdf nemo_cj881o_1m_20431201-20440101_grid-T {
# dimensions:
# 	y = 332 ;
# 	x = 362 ;
# 	time_counter = UNLIMITED ; // (1 currently)
# variables:
# 	float nav_lat(y, x) ;
# 		nav_lat:standard_name = "latitude" ;
# 		nav_lat:long_name = "Latitude" ;
# 		nav_lat:units = "degrees_north" ;
# 		nav_lat:nav_model = "grid_T" ;
# 		nav_lat:bounds = "bounds_lat" ;
# 	float nav_lon(y, x) ;
# 		nav_lon:standard_name = "longitude" ;
# 		nav_lon:long_name = "Longitude" ;
# 		nav_lon:units = "degrees_east" ;
# 		nav_lon:nav_model = "grid_T" ;
# 		nav_lon:bounds = "bounds_lon" ;
# 	float somxl010(time_counter, y, x) ;
# 		somxl010:standard_name = "ocean_mixed_layer_thickness_defined_by_sigma_theta" ;
# 		somxl010:long_name = "Mixed Layer Depth (dsigma = 0.01 wrt 10m)" ;
# 		somxl010:units = "m" ;
# 		somxl010:online_operation = "average" ;
# 		somxl010:interval_operation = "2700 s" ;
# 		somxl010:interval_write = "1 month" ;
# 		somxl010:cell_methods = "time: mean (interval: 2700 s)" ;
# 		somxl010:cell_measures = "area: area" ;
# 		somxl010:_FillValue = 1.e+20f ;
# 		somxl010:missing_value = 1.e+20f ;
# 		somxl010:coordinates = "time_centered nav_lat nav_lon" ;
# 	double time_centered(time_counter) ;
# 		time_centered:standard_name = "time" ;
# 		time_centered:long_name = "Time axis" ;
# 		time_centered:calendar = "360_day" ;
# 		time_centered:units = "seconds since 1900-01-01 00:00:00" ;
# 		time_centered:time_origin = "1900-01-01 00:00:00" ;
# 		time_centered:bounds = "time_centered_bounds" ;
# 	double time_counter(time_counter) ;
# 		time_counter:axis = "T" ;
#
# // global attributes:
# 		:name = "cj881o_1m_20431001_20431230" ;
# 		:description = "ocean T grid variables" ;
# 		:title = "ocean T grid variables" ;
# 		:Conventions = "CF-1.5" ;
# 		:production = "An IPSL model" ;
# 		:timeStamp = "2021-Dec-09 23:32:32 UTC" ;
# 		:ibegin = 0 ;
# 		:ni = 362 ;
# 		:jbegin = 0 ;
# 		:nj = 56 ;
# 		:file_name = "nemo_cj881o_1m_20431201-20440101_grid-T.nc" ;
# 		:TimeStamp = "10/12/2021 01:28:35 +0000" ;
# 		:history = "Mon Feb 13 19:48:00 2023: /opt/moose/moose-netcdf/bin/ncks -v somxl010 -4 --cnk_map rd1 /hpss/subsys2/moose/crum/u-cj881/onm.nc.file/nemo_cj881o_1m_20431201-20440101_grid-T.nc /data/cache/netcdf/output/dummy_output_1617613455_11" ;
# 		:NCO = "4.4.5" ;
# }

# %%
check_full_scenario('ukesm_allscen_gridT_mld','grid-T')
# Out:
# ukesm_allscen_gridT_mld
# checking bc370
# checking be682
#
# checking ce417
#
# checking cj198
#
# checking cj880
#
# checking cj881
#
# checking cj200
#
# checking cj484
#
# checking cj504

# %% [markdown]
# # diad-T all ok
#
# [mep22dku@c0006 /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_diadT_aux]$ ncdump -h medusa_cj198o_1m_19591201-19600101_diad-T.nc
# netcdf medusa_cj198o_1m_19591201-19600101_diad-T {
# dimensions:
# 	time_counter = UNLIMITED ; // (1 currently)
# 	y = 332 ;
# 	x = 362 ;
# variables:
# 	float CHL_MLD(time_counter, y, x) ;
# 		CHL_MLD:long_name = "MLD averaged Chlorophyll" ;
# 		CHL_MLD:units = "mg-Chl/m3" ;
# 		CHL_MLD:online_operation = "average" ;
# 		CHL_MLD:interval_operation = "2700 s" ;
# 		CHL_MLD:interval_write = "1 month" ;
# 		CHL_MLD:cell_methods = "time: mean (interval: 2700 s)" ;
# 		CHL_MLD:cell_measures = "area: area" ;
# 		CHL_MLD:_FillValue = 1.e+20f ;
# 		CHL_MLD:missing_value = 1.e+20f ;
# 		CHL_MLD:coordinates = "time_centered nav_lat nav_lon" ;
# 	float CO2FLUX(time_counter, y, x) ;
# 		CO2FLUX:long_name = "Air-sea CO2 flux" ;
# 		CO2FLUX:units = "mmol-C/m2/d" ;
# 		CO2FLUX:online_operation = "average" ;
# 		CO2FLUX:interval_operation = "2700 s" ;
# 		CO2FLUX:interval_write = "1 month" ;
# 		CO2FLUX:cell_methods = "time: mean (interval: 2700 s)" ;
# 		CO2FLUX:cell_measures = "area: area" ;
# 		CO2FLUX:_FillValue = 1.e+20f ;
# 		CO2FLUX:missing_value = 1.e+20f ;
# 		CO2FLUX:coordinates = "time_centered nav_lat nav_lon" ;
# 	float ML_PRD(time_counter, y, x) ;
# 		ML_PRD:long_name = "Diatom mixed layer PP" ;
# 		ML_PRD:units = "mmol-N/m2/d" ;
# 		ML_PRD:online_operation = "average" ;
# 		ML_PRD:interval_operation = "2700 s" ;
# 		ML_PRD:interval_write = "1 month" ;
# 		ML_PRD:cell_methods = "time: mean (interval: 2700 s)" ;
# 		ML_PRD:cell_measures = "area: area" ;
# 		ML_PRD:_FillValue = 1.e+20f ;
# 		ML_PRD:missing_value = 1.e+20f ;
# 		ML_PRD:coordinates = "time_centered nav_lat nav_lon" ;
# 	float ML_PRN(time_counter, y, x) ;
# 		ML_PRN:long_name = "Non-diatom mixed layer PP" ;
# 		ML_PRN:units = "mmol-N/m2/d" ;
# 		ML_PRN:online_operation = "average" ;
# 		ML_PRN:interval_operation = "2700 s" ;
# 		ML_PRN:interval_write = "1 month" ;
# 		ML_PRN:cell_methods = "time: mean (interval: 2700 s)" ;
# 		ML_PRN:cell_measures = "area: area" ;
# 		ML_PRN:_FillValue = 1.e+20f ;
# 		ML_PRN:missing_value = 1.e+20f ;
# 		ML_PRN:coordinates = "time_centered nav_lat nav_lon" ;
# 	float OCN_DPCO2(time_counter, y, x) ;
# 		OCN_DPCO2:long_name = "MOCSY delta pCO2" ;
# 		OCN_DPCO2:units = "uatm" ;
# 		OCN_DPCO2:online_operation = "average" ;
# 		OCN_DPCO2:interval_operation = "2700 s" ;
# 		OCN_DPCO2:interval_write = "1 month" ;
# 		OCN_DPCO2:cell_methods = "time: mean (interval: 2700 s)" ;
# 		OCN_DPCO2:cell_measures = "area: area" ;
# 		OCN_DPCO2:_FillValue = 1.e+20f ;
# 		OCN_DPCO2:missing_value = 1.e+20f ;
# 		OCN_DPCO2:coordinates = "time_centered nav_lat nav_lon" ;
# 	float OCN_PCO2(time_counter, y, x) ;
# 		OCN_PCO2:long_name = "Surface ocean pCO2" ;
# 		OCN_PCO2:units = "uatm" ;
# 		OCN_PCO2:online_operation = "average" ;
# 		OCN_PCO2:interval_operation = "2700 s" ;
# 		OCN_PCO2:interval_write = "1 month" ;
# 		OCN_PCO2:cell_methods = "time: mean (interval: 2700 s)" ;
# 		OCN_PCO2:cell_measures = "area: area" ;
# 		OCN_PCO2:_FillValue = 1.e+20f ;
# 		OCN_PCO2:missing_value = 1.e+20f ;
# 		OCN_PCO2:coordinates = "time_centered nav_lat nav_lon" ;
# 	float WIND(time_counter, y, x) ;
# 		WIND:long_name = "Surface scalar wind" ;
# 		WIND:units = "m/s" ;
# 		WIND:online_operation = "average" ;
# 		WIND:interval_operation = "2700 s" ;
# 		WIND:interval_write = "1 month" ;
# 		WIND:cell_methods = "time: mean (interval: 2700 s)" ;
# 		WIND:cell_measures = "area: area" ;
# 		WIND:_FillValue = 1.e+20f ;
# 		WIND:missing_value = 1.e+20f ;
# 		WIND:coordinates = "time_centered nav_lat nav_lon" ;
# 	float nav_lat(y, x) ;
# 		nav_lat:standard_name = "latitude" ;
# 		nav_lat:long_name = "Latitude" ;
# 		nav_lat:units = "degrees_north" ;
# 		nav_lat:nav_model = "grid_T" ;
# 		nav_lat:bounds = "bounds_lat" ;
# 	float nav_lon(y, x) ;
# 		nav_lon:standard_name = "longitude" ;
# 		nav_lon:long_name = "Longitude" ;
# 		nav_lon:units = "degrees_east" ;
# 		nav_lon:nav_model = "grid_T" ;
# 		nav_lon:bounds = "bounds_lon" ;
# 	double time_centered(time_counter) ;
# 		time_centered:standard_name = "time" ;
# 		time_centered:long_name = "Time axis" ;
# 		time_centered:calendar = "360_day" ;
# 		time_centered:units = "seconds since 1900-01-01 00:00:00" ;
# 		time_centered:time_origin = "1900-01-01 00:00:00" ;
# 		time_centered:bounds = "time_centered_bounds" ;
# 	double time_counter(time_counter) ;
# 		time_counter:axis = "T" ;
#
# // global attributes:
# 		:name = "cj198o_1m_19591001_19591230" ;
# 		:description = "Medusa diagnostic variables" ;
# 		:title = "Medusa diagnostic variables" ;
# 		:Conventions = "CF-1.5" ;
# 		:production = "An IPSL model" ;
# 		:timeStamp = "2021-Nov-10 02:47:37 UTC" ;
# 		:ibegin = 0 ;
# 		:ni = 362 ;
# 		:jbegin = 0 ;
# 		:nj = 56 ;
# 		:file_name = "medusa_cj198o_1m_19591201-19600101_diad-T.nc" ;
# 		:TimeStamp = "10/11/2021 04:43:29 +0000" ;
# 		:history = "Thu Feb 16 04:04:07 2023: /opt/moose/moose-netcdf/bin/ncks -v OCN_PCO2,CO2FLUX,OCN_DPCO2,ML_PRN,ML_PRD,WIND,CHL_MLD -4 --cnk_map rd1 /hpss/subsys2/moose/crum/u-cj198/onm.nc.file/medusa_cj198o_1m_19591201-19600101_diad-T.nc /data/cache/netcdf/output/dummy_output_1619075331_11" ;
# 		:NCO = "4.4.5" ;

# %%
check_full_scenario('ukesm_allscen_diadT_aux','diad-T')
# Out:
# ukesm_allscen_diadT_aux
# checking bc370
# checking be682
#
# checking ce417
#
# checking cj198
#
# checking cj880
#
# checking cj881
#
# checking cj200
#
# checking cj484
#
# checking cj504

# %% [markdown]
# ## ptrc T TA-DIC - all ok
#
# [mep22dku@c0006 /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_ptrcT_TADIC]$ ncdump -h medusa_cj484o_1m_20630101-20630201_ptrc-T.nc
# netcdf medusa_cj484o_1m_20630101-20630201_ptrc-T {
# dimensions:
# 	time_counter = UNLIMITED ; // (1 currently)
# 	deptht = 75 ;
# 	y = 332 ;
# 	x = 362 ;
# 	axis_nbounds = 2 ;
# variables:
# 	float ALK(time_counter, deptht, y, x) ;
# 		ALK:long_name = "alkalinity" ;
# 		ALK:units = "meq/m3" ;
# 		ALK:online_operation = "average" ;
# 		ALK:interval_operation = "2700 s" ;
# 		ALK:interval_write = "1 month" ;
# 		ALK:cell_methods = "time: mean (interval: 2700 s)" ;
# 		ALK:cell_measures = "area: area" ;
# 		ALK:_FillValue = 1.e+20f ;
# 		ALK:missing_value = 1.e+20f ;
# 		ALK:coordinates = "time_centered deptht nav_lat nav_lon" ;
# 	float CHD(time_counter, deptht, y, x) ;
# 		CHD:long_name = "Chl-a concentration in     diatom phytoplankton" ;
# 		CHD:units = "mg-Chl/m3" ;
# 		CHD:online_operation = "average" ;
# 		CHD:interval_operation = "2700 s" ;
# 		CHD:interval_write = "1 month" ;
# 		CHD:cell_methods = "time: mean (interval: 2700 s)" ;
# 		CHD:cell_measures = "area: area" ;
# 		CHD:_FillValue = 1.e+20f ;
# 		CHD:missing_value = 1.e+20f ;
# 		CHD:coordinates = "time_centered deptht nav_lat nav_lon" ;
# 	float CHN(time_counter, deptht, y, x) ;
# 		CHN:long_name = "Chl-a concentration in non-diatom phytoplankton" ;
# 		CHN:units = "mg-Chl/m3" ;
# 		CHN:online_operation = "average" ;
# 		CHN:interval_operation = "2700 s" ;
# 		CHN:interval_write = "1 month" ;
# 		CHN:cell_methods = "time: mean (interval: 2700 s)" ;
# 		CHN:cell_measures = "area: area" ;
# 		CHN:_FillValue = 1.e+20f ;
# 		CHN:missing_value = 1.e+20f ;
# 		CHN:coordinates = "time_centered deptht nav_lat nav_lon" ;
# 	float DIC(time_counter, deptht, y, x) ;
# 		DIC:long_name = "dissolved inorganic carbon" ;
# 		DIC:units = "mmol-C/m3" ;
# 		DIC:online_operation = "average" ;
# 		DIC:interval_operation = "2700 s" ;
# 		DIC:interval_write = "1 month" ;
# 		DIC:cell_methods = "time: mean (interval: 2700 s)" ;
# 		DIC:cell_measures = "area: area" ;
# 		DIC:_FillValue = 1.e+20f ;
# 		DIC:missing_value = 1.e+20f ;
# 		DIC:coordinates = "time_centered deptht nav_lat nav_lon" ;
# 	float deptht(deptht) ;
# 		deptht:standard_name = "depth" ;
# 		deptht:long_name = "Vertical T levels" ;
# 		deptht:units = "m" ;
# 		deptht:axis = "Z" ;
# 		deptht:positive = "down" ;
# 		deptht:bounds = "deptht_bounds" ;
# 	float deptht_bounds(deptht, axis_nbounds) ;
# 	float nav_lat(y, x) ;
# 		nav_lat:standard_name = "latitude" ;
# 		nav_lat:long_name = "Latitude" ;
# 		nav_lat:units = "degrees_north" ;
# 		nav_lat:nav_model = "grid_T" ;
# 		nav_lat:bounds = "bounds_lat" ;
# 	float nav_lon(y, x) ;
# 		nav_lon:standard_name = "longitude" ;
# 		nav_lon:long_name = "Longitude" ;
# 		nav_lon:units = "degrees_east" ;
# 		nav_lon:nav_model = "grid_T" ;
# 		nav_lon:bounds = "bounds_lon" ;
# 	double time_centered(time_counter) ;
# 		time_centered:standard_name = "time" ;
# 		time_centered:long_name = "Time axis" ;
# 		time_centered:calendar = "360_day" ;
# 		time_centered:units = "seconds since 1900-01-01 00:00:00" ;
# 		time_centered:time_origin = "1900-01-01 00:00:00" ;
# 		time_centered:bounds = "time_centered_bounds" ;
# 	double time_counter(time_counter) ;
# 		time_counter:axis = "T" ;
#
# // global attributes:
# 		:name = "cj484o_1m_20630101_20630330" ;
# 		:description = "Medusa sms variables" ;
# 		:title = "Medusa sms variables" ;
# 		:Conventions = "CF-1.5" ;
# 		:production = "An IPSL model" ;
# 		:timeStamp = "2021-Dec-07 04:21:59 UTC" ;
# 		:ibegin = 0 ;
# 		:ni = 362 ;
# 		:jbegin = 0 ;
# 		:nj = 56 ;
# 		:file_name = "medusa_cj484o_1m_20630101-20630201_ptrc-T.nc" ;
# 		:TimeStamp = "07/12/2021 05:37:41 +0000" ;
# 		:history = "Mon Mar 20 09:48:30 2023: /opt/moose/moose-netcdf/bin/ncks -v DIC,ALK,CHN,CHD -4 --cnk_map rd1 /hpss/subsys2/moose/crum/u-cj484/onm.nc.file/medusa_cj484o_1m_20630101-20630201_ptrc-T.nc /data/cache/netcdf/output/dummy_output_1634368083_5" ;
# 		:NCO = "4.4.5" ;
# }

# %%
check_full_scenario('ukesm_allscen_ptrcT_TADIC','ptrc-T')
# Out:
# ukesm_allscen_ptrcT_TADIC
# checking bc370
# checking be682
#
# checking ce417
#
# checking cj198
#
# checking cj880
#
# checking cj881
#
# checking cj200
#
# checking cj484
#
# checking cj504

# %% [markdown]
# ## T, S
#
# ncdump -h nemo_cj484o_1m_20350101-20350201_grid-T.nc
# netcdf nemo_cj484o_1m_20350101-20350201_grid-T {
# dimensions:
# 	deptht = 75 ;
# 	axis_nbounds = 2 ;
# 	y = 332 ;
# 	x = 362 ;
# 	time_counter = UNLIMITED ; // (1 currently)
# variables:
# 	float deptht(deptht) ;
# 		deptht:standard_name = "depth" ;
# 		deptht:long_name = "Vertical T levels" ;
# 		deptht:units = "m" ;
# 		deptht:axis = "Z" ;
# 		deptht:positive = "down" ;
# 		deptht:bounds = "deptht_bounds" ;
# 	float deptht_bounds(deptht, axis_nbounds) ;
# 	float nav_lat(y, x) ;
# 		nav_lat:standard_name = "latitude" ;
# 		nav_lat:long_name = "Latitude" ;
# 		nav_lat:units = "degrees_north" ;
# 		nav_lat:nav_model = "grid_T" ;
# 		nav_lat:bounds = "bounds_lat" ;
# 	float nav_lon(y, x) ;
# 		nav_lon:standard_name = "longitude" ;
# 		nav_lon:long_name = "Longitude" ;
# 		nav_lon:units = "degrees_east" ;
# 		nav_lon:nav_model = "grid_T" ;
# 		nav_lon:bounds = "bounds_lon" ;
# 	float so(time_counter, deptht, y, x) ;
# 		so:standard_name = "sea_water_salinity" ;
# 		so:long_name = "Sea Water Salinity" ;
# 		so:units = "0.001" ;
# 		so:online_operation = "average" ;
# 		so:interval_operation = "1 month" ;
# 		so:interval_write = "1 month" ;
# 		so:cell_measures = "area: area" ;
# 		so:_FillValue = 1.e+20f ;
# 		so:missing_value = 1.e+20f ;
# 		so:coordinates = "time_centered deptht nav_lat nav_lon" ;
# 		so:cell_methods = "time: mean (thickness weighted)" ;
# 	float thetao(time_counter, deptht, y, x) ;
# 		thetao:standard_name = "sea_water_potential_temperature" ;
# 		thetao:long_name = "Sea Water Potential Temperature" ;
# 		thetao:units = "degree_C" ;
# 		thetao:online_operation = "average" ;
# 		thetao:interval_operation = "1 month" ;
# 		thetao:interval_write = "1 month" ;
# 		thetao:cell_measures = "area: area" ;
# 		thetao:_FillValue = 1.e+20f ;
# 		thetao:missing_value = 1.e+20f ;
# 		thetao:coordinates = "time_centered deptht nav_lat nav_lon" ;
# 		thetao:cell_methods = "time: mean (thickness weighted)" ;
# 	double time_centered(time_counter) ;
# 		time_centered:standard_name = "time" ;
# 		time_centered:long_name = "Time axis" ;
# 		time_centered:calendar = "360_day" ;
# 		time_centered:units = "seconds since 1900-01-01 00:00:00" ;
# 		time_centered:time_origin = "1900-01-01 00:00:00" ;
# 		time_centered:bounds = "time_centered_bounds" ;
# 	double time_counter(time_counter) ;
# 		time_counter:axis = "T" ;
#
# // global attributes:
# 		:name = "cj484o_1m_20350101_20350330" ;
# 		:description = "ocean T grid variables" ;
# 		:title = "ocean T grid variables" ;
# 		:Conventions = "CF-1.5" ;
# 		:production = "An IPSL model" ;
# 		:timeStamp = "2021-Nov-23 18:08:29 UTC" ;
# 		:ibegin = 0 ;
# 		:ni = 362 ;
# 		:jbegin = 0 ;
# 		:nj = 56 ;
# 		:file_name = "nemo_cj484o_1m_20350101-20350201_grid-T.nc" ;
# 		:TimeStamp = "23/11/2021 19:24:20 +0000" ;
# 		:history = "Sat Feb 25 00:31:33 2023: /opt/moose/moose-netcdf/bin/ncks -v thetao,so -4 --cnk_map rd1 /hpss/subsys2/moose/crum/u-cj484/onm.nc.file/nemo_cj484o_1m_20350101-20350201_grid-T.nc /data/cache/netcdf/output/dummy_output_1623665665_1" ;
# 		:NCO = "4.4.5" ;
# }

# %%
check_full_scenario('ukesm_allscen_gridT_TS','grid-T')
# Out:
# ukesm_allscen_gridT_TS
# checking bc370
# checking be682
#
# checking ce417
#
# checking cj198
#
# checking cj880
#
# checking cj881
#
# checking cj200
#
# checking cj484
#
# checking cj504

# %% [markdown]
# ## vomecrty
#
# [mep22dku@c0006 /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridV_vo]$ ncdump -h nemo_cj881o_1m_20810401-20810501_grid-V.nc
# netcdf nemo_cj881o_1m_20810401-20810501_grid-V {
# dimensions:
# 	depthv = 75 ;
# 	axis_nbounds = 2 ;
# 	y = 332 ;
# 	x = 362 ;
# 	time_counter = UNLIMITED ; // (1 currently)
# variables:
# 	float depthv(depthv) ;
# 		depthv:standard_name = "depth" ;
# 		depthv:long_name = "Vertical V levels" ;
# 		depthv:units = "m" ;
# 		depthv:axis = "Z" ;
# 		depthv:positive = "down" ;
# 		depthv:bounds = "depthv_bounds" ;
# 	float depthv_bounds(depthv, axis_nbounds) ;
# 	float nav_lat(y, x) ;
# 		nav_lat:standard_name = "latitude" ;
# 		nav_lat:long_name = "Latitude" ;
# 		nav_lat:units = "degrees_north" ;
# 		nav_lat:nav_model = "grid_V" ;
# 		nav_lat:bounds = "bounds_lat" ;
# 	float nav_lon(y, x) ;
# 		nav_lon:standard_name = "longitude" ;
# 		nav_lon:long_name = "Longitude" ;
# 		nav_lon:units = "degrees_east" ;
# 		nav_lon:nav_model = "grid_V" ;
# 		nav_lon:bounds = "bounds_lon" ;
# 	double time_centered(time_counter) ;
# 		time_centered:standard_name = "time" ;
# 		time_centered:long_name = "Time axis" ;
# 		time_centered:calendar = "360_day" ;
# 		time_centered:units = "seconds since 1900-01-01 00:00:00" ;
# 		time_centered:time_origin = "1900-01-01 00:00:00" ;
# 		time_centered:bounds = "time_centered_bounds" ;
# 	double time_counter(time_counter) ;
# 		time_counter:axis = "T" ;
# 	float vo(time_counter, depthv, y, x) ;
# 		vo:standard_name = "sea_water_y_velocity" ;
# 		vo:long_name = "Sea Water Y Velocity" ;
# 		vo:units = "m/s" ;
# 		vo:online_operation = "average" ;
# 		vo:interval_operation = "1 month" ;
# 		vo:interval_write = "1 month" ;
# 		vo:cell_measures = "area: area" ;
# 		vo:_FillValue = 1.e+20f ;
# 		vo:missing_value = 1.e+20f ;
# 		vo:coordinates = "time_centered depthv nav_lat nav_lon" ;
# 		vo:cell_methods = "time: mean (thickness weighted)" ;
#
# // global attributes:
# 		:name = "cj881o_1m_20810401_20810630" ;
# 		:description = "ocean V grid variables" ;
# 		:title = "ocean V grid variables" ;
# 		:Conventions = "CF-1.5" ;
# 		:production = "An IPSL model" ;
# 		:timeStamp = "2021-Dec-22 09:43:59 UTC" ;
# 		:ibegin = 0 ;
# 		:ni = 362 ;
# 		:jbegin = 0 ;
# 		:nj = 56 ;
# 		:file_name = "nemo_cj881o_1m_20810401-20810501_grid-V.nc" ;
# 		:TimeStamp = "22/12/2021 11:49:45 +0000" ;
# 		:history = "Sun Mar 26 18:13:31 2023: /opt/moose/moose-netcdf/bin/ncks -v vo -4 --cnk_map rd1 /hpss/subsys2/moose/crum/u-cj881/onm.nc.file/nemo_cj881o_1m_20810401-20810501_grid-V.nc /data/cache/netcdf/output/dummy_output_1636964941_5" ;
# 		:NCO = "4.4.5" ;
# }

# %%
check_full_scenario('ukesm_allscen_gridV_vo','grid-V')
# Out:
# ukesm_allscen_gridV_vo
# checking bc370
# 1962, bc370 grid-V missing
# 1991, bc370 grid-V missing
# 2012, bc370 grid-V missing
# checking be682
# 2082, be682 grid-V missing
# 2083, be682 grid-V missing
# 2084, be682 grid-V missing
# 2085, be682 grid-V missing
# 2086, be682 grid-V missing
# 2087, be682 grid-V missing
# 2088, be682 grid-V missing
# 2089, be682 grid-V missing
# 2090, be682 grid-V missing
# 2091, be682 grid-V missing
# 2092, be682 grid-V missing
# 2093, be682 grid-V missing
# 2094, be682 grid-V missing
# 2095, be682 grid-V missing
# 2096, be682 grid-V missing
# 2097, be682 grid-V missing
# 2098, be682 grid-V missing
# 2099, be682 grid-V missing
#
# checking ce417
# 2082, ce417 grid-V missing
# 2083, ce417 grid-V missing
# 2084, ce417 grid-V missing
# 2085, ce417 grid-V missing
# 2086, ce417 grid-V missing
# 2087, ce417 grid-V missing
# 2088, ce417 grid-V missing
# 2089, ce417 grid-V missing
# 2090, ce417 grid-V missing
# 2091, ce417 grid-V missing
# ...
