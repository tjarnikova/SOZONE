# %% [markdown]
# ### aim: make yearly medusa subset files
#
# ### date: Jan 5, 2023

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE' )
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %% [markdown]
# ## temperature and salinity, historic 1A

# %%
def make_yearly_subset_gridV(yr,runname,pref = 'nemo', dtype = 'grid-V', tdir = 'ukesm_1A_gridT_TS'):

    #what is new file going to be called:
    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/{pref}_{runname}_1y_{yr}_{dtype}-vomecrty.nc'
    print(savenam)
    
    #get by-month dimension for this year:
    times = pd.date_range(f"{yr}/01/01",f"{yr+1}/01/01",freq='M',closed='left')
    #get the spatial dimensions from a variable


    #get the files we are converting
    td = f'/gpfs/data/greenocean/software/resources/MEDUSA/{tdir}/{pref}_{runname}*_1m_{yr}*01-*{dtype}.nc'
    fils = glob.glob(td)
    fils.sort()
    
    if len(fils) != 12:
        print(f'missing files for year {yr} in {runname}: we have {len(fils)}')
        return

    else:
        ## define variables that we are saving
        
        q = xr.open_dataset(fils[0])
        nav_lat = q['nav_lat'].values
        nav_lon = q['nav_lon'].values
        deptht = q['deptht'].values
        
        vo = np.zeros([12,75,332,362])
        thetao = np.zeros([12,75,332,362])
        
        for i in range(0,12):
            tfil = xr.open_dataset(fils[i])
            vo[i,:,:,:] = tfil['vo'][:,:,:].values

        # define data with variable attributes
        data_vars = {'vomecrty':(['time_counter', 'deptht','y', 'x'], vo,
                                 {'units': 'm/s',
                                  'long_name':'vomecrty'}),

                    }

        # define coordinates
        coords = {'time_counter': (['time_counter'], times),
            'nav_lat': (['y','x'], nav_lat),
            'nav_lon': (['y','x'], nav_lon),
            'deptht': (['deptht'], deptht)}

        # define global attributes
        attrs = {'made in':'SOZONE/MEDUSA/makeYearlyMEDUSAsubsetfiles.ipynb',
                'desc': 'yearly medusa files, saving only variables of interest'
                }

        ds = xr.Dataset(data_vars=data_vars,
                        coords=coords,
                        attrs=attrs)

        try:
            ds.to_netcdf(savenam)
        except:
            print(f'seems like {savenam} exists already')
    
#make_yearly_subset_nc(1954,'cj198')

# %%
#1h
runname = 'bc370'
yrs = np.arange(1950,2015,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)

#1b
runname = 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)

#2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)    

#2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)
    
#2b
runname = 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)
    
    
#3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)    
    
#3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)    
    
#3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridV(y,runname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29856/638169535.py in <module>
#       3 yrs = np.arange(1950,2015,1)
#       4 for y in yrs:
# ----> 5     make_yearly_subset_gridV(y,runname)
#       6
#       7 #1a
#
# NameError: name 'make_yearly_subset_gridV' is not defined

# %%
def make_yearly_subset_gridT(yr,runname,pref = 'nemo', dtype = 'grid-T', tdir = 'ukesm_1A_gridT_TS'):

    #what is new file going to be called:
    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/{pref}_{runname}_1y_{yr}_{dtype}-TS.nc'
    print(savenam)
    
    #get by-month dimension for this year:
    times = pd.date_range(f"{yr}/01/01",f"{yr+1}/01/01",freq='M',closed='left')
    #get the spatial dimensions from a variable


    #get the files we are converting
    td = f'/gpfs/data/greenocean/software/resources/MEDUSA/{tdir}/{pref}_{runname}*_1m_{yr}*01-*{dtype}.nc'
    fils = glob.glob(td)
    fils.sort()
    
    if len(fils) != 12:
        print(f'missing files for year {yr} in {runname}: we have {len(fils)}')
        return

    else:
        ## define variables that we are saving
        
        q = xr.open_dataset(fils[0])
        nav_lat = q['nav_lat'].values
        nav_lon = q['nav_lon'].values
        deptht = q['deptht'].values
        
        so = np.zeros([12,75,332,362])
        thetao = np.zeros([12,75,332,362])
        
        for i in range(0,12):
            tfil = xr.open_dataset(fils[i])
            so[i,:,:,:] = tfil['so'][:,:,:].values
            thetao[i,:,:,:] = tfil['thetao'][:,:,:].values
        # define data with variable attributes
        data_vars = {'vosaline':(['time_counter', 'deptht','y', 'x'], so,
                                 {'units': 'g/kg',
                                  'long_name':'salinity'}),
                     'votemper':(['time_counter', 'deptht', 'y', 'x'], thetao,
                                 {'units': '',
                                  'long_name':'temperature'}),   
                    }

        # define coordinates
        coords = {'time_counter': (['time_counter'], times),
            'nav_lat': (['y','x'], nav_lat),
            'nav_lon': (['y','x'], nav_lon),
            'deptht': (['deptht'], deptht)}

        # define global attributes
        attrs = {'made in':'SOZONE/MEDUSA/makeYearlyMEDUSAsubsetfiles.ipynb',
                'desc': 'yearly medusa files, saving only variables of interest'
                }

        ds = xr.Dataset(data_vars=data_vars,
                        coords=coords,
                        attrs=attrs)

        try:
            ds.to_netcdf(savenam)
        except:
            print(f'seems like {savenam} exists already')
    
#make_yearly_subset_nc(1954,'cj198')

# %%
#1h
runname = 'bc370'
yrs = np.arange(1950,2100,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)

#1b
runname = 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)

#2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)    

#2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)
    
#2b
runname = 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)
    
    
#3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)    
    
#3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)    
    
#3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_gridT(y,runname)
# Out:
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1950_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1951_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1952_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1953_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1954_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1955_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1956_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1957_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1958_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1959_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1960_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1961_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1962_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1963_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1964_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1965_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1966_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1967_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1968_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1969_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1970_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1971_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1972_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1973_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1974_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1975_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1976_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1977_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1978_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1979_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1980_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1981_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1982_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1983_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1984_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1985_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1986_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1987_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1988_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1989_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1990_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1991_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1992_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1993_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1994_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1995_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1996_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1997_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1998_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_1999_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2000_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2001_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2002_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2003_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2004_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2005_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2006_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2007_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2008_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2009_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2010_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2011_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2012_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2013_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2014_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2015_grid-T-TS.nc
# missing files for year 2015 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2016_grid-T-TS.nc
# missing files for year 2016 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2017_grid-T-TS.nc
# missing files for year 2017 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2018_grid-T-TS.nc
# missing files for year 2018 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2019_grid-T-TS.nc
# missing files for year 2019 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2020_grid-T-TS.nc
# missing files for year 2020 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2021_grid-T-TS.nc
# missing files for year 2021 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2022_grid-T-TS.nc
# missing files for year 2022 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2023_grid-T-TS.nc
# missing files for year 2023 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2024_grid-T-TS.nc
# missing files for year 2024 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2025_grid-T-TS.nc
# missing files for year 2025 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2026_grid-T-TS.nc
# missing files for year 2026 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2027_grid-T-TS.nc
# missing files for year 2027 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2028_grid-T-TS.nc
# missing files for year 2028 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2029_grid-T-TS.nc
# missing files for year 2029 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2030_grid-T-TS.nc
# missing files for year 2030 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2031_grid-T-TS.nc
# missing files for year 2031 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2032_grid-T-TS.nc
# missing files for year 2032 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2033_grid-T-TS.nc
# missing files for year 2033 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2034_grid-T-TS.nc
# missing files for year 2034 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2035_grid-T-TS.nc
# missing files for year 2035 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2036_grid-T-TS.nc
# missing files for year 2036 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2037_grid-T-TS.nc
# missing files for year 2037 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2038_grid-T-TS.nc
# missing files for year 2038 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2039_grid-T-TS.nc
# missing files for year 2039 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2040_grid-T-TS.nc
# missing files for year 2040 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2041_grid-T-TS.nc
# missing files for year 2041 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2042_grid-T-TS.nc
# missing files for year 2042 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2043_grid-T-TS.nc
# missing files for year 2043 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2044_grid-T-TS.nc
# missing files for year 2044 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2045_grid-T-TS.nc
# missing files for year 2045 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2046_grid-T-TS.nc
# missing files for year 2046 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2047_grid-T-TS.nc
# missing files for year 2047 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2048_grid-T-TS.nc
# missing files for year 2048 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2049_grid-T-TS.nc
# missing files for year 2049 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2050_grid-T-TS.nc
# missing files for year 2050 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2051_grid-T-TS.nc
# missing files for year 2051 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2052_grid-T-TS.nc
# missing files for year 2052 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2053_grid-T-TS.nc
# missing files for year 2053 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2054_grid-T-TS.nc
# missing files for year 2054 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2055_grid-T-TS.nc
# missing files for year 2055 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2056_grid-T-TS.nc
# missing files for year 2056 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2057_grid-T-TS.nc
# missing files for year 2057 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2058_grid-T-TS.nc
# missing files for year 2058 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2059_grid-T-TS.nc
# missing files for year 2059 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2060_grid-T-TS.nc
# missing files for year 2060 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2061_grid-T-TS.nc
# missing files for year 2061 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2062_grid-T-TS.nc
# missing files for year 2062 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2063_grid-T-TS.nc
# missing files for year 2063 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2064_grid-T-TS.nc
# missing files for year 2064 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2065_grid-T-TS.nc
# missing files for year 2065 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2066_grid-T-TS.nc
# missing files for year 2066 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2067_grid-T-TS.nc
# missing files for year 2067 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2068_grid-T-TS.nc
# missing files for year 2068 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2069_grid-T-TS.nc
# missing files for year 2069 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2070_grid-T-TS.nc
# missing files for year 2070 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2071_grid-T-TS.nc
# missing files for year 2071 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2072_grid-T-TS.nc
# missing files for year 2072 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2073_grid-T-TS.nc
# missing files for year 2073 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2074_grid-T-TS.nc
# missing files for year 2074 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2075_grid-T-TS.nc
# missing files for year 2075 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2076_grid-T-TS.nc
# missing files for year 2076 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2077_grid-T-TS.nc
# missing files for year 2077 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2078_grid-T-TS.nc
# missing files for year 2078 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2079_grid-T-TS.nc
# missing files for year 2079 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2080_grid-T-TS.nc
# missing files for year 2080 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2081_grid-T-TS.nc
# missing files for year 2081 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2082_grid-T-TS.nc
# missing files for year 2082 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2083_grid-T-TS.nc
# missing files for year 2083 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2084_grid-T-TS.nc
# missing files for year 2084 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2085_grid-T-TS.nc
# missing files for year 2085 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2086_grid-T-TS.nc
# missing files for year 2086 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2087_grid-T-TS.nc
# missing files for year 2087 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2088_grid-T-TS.nc
# missing files for year 2088 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2089_grid-T-TS.nc
# missing files for year 2089 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2090_grid-T-TS.nc
# missing files for year 2090 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2091_grid-T-TS.nc
# missing files for year 2091 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2092_grid-T-TS.nc
# missing files for year 2092 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2093_grid-T-TS.nc
# missing files for year 2093 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2094_grid-T-TS.nc
# missing files for year 2094 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2095_grid-T-TS.nc
# missing files for year 2095 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2096_grid-T-TS.nc
# missing files for year 2096 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2097_grid-T-TS.nc
# missing files for year 2097 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2098_grid-T-TS.nc
# missing files for year 2098 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_bc370_1y_2099_grid-T-TS.nc
# missing files for year 2099 in bc370: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2015_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2016_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2017_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2018_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2019_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2020_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2021_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2022_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2023_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2024_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2025_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2026_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2027_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2028_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2029_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2030_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2031_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2032_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2033_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2034_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2035_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2036_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2037_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2038_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2039_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2040_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2041_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2042_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2043_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2044_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2045_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2046_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2047_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2048_grid-T-TS.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo
we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2026_grid-T-TS.nc
# missing files for year 2026 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2027_grid-T-TS.nc
# missing files for year 2027 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2028_grid-T-TS.nc
# missing files for year 2028 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2029_grid-T-TS.nc
# missing files for year 2029 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2030_grid-T-TS.nc
# missing files for year 2030 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2031_grid-T-TS.nc
# missing files for year 2031 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2032_grid-T-TS.nc
# missing files for year 2032 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2033_grid-T-TS.nc
# missing files for year 2033 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2034_grid-T-TS.nc
# missing files for year 2034 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2035_grid-T-TS.nc
# missing files for year 2035 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2036_grid-T-TS.nc
# missing files for year 2036 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2037_grid-T-TS.nc
# missing files for year 2037 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2038_grid-T-TS.nc
# missing files for year 2038 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2039_grid-T-TS.nc
# missing files for year 2039 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2040_grid-T-TS.nc
# missing files for year 2040 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2041_grid-T-TS.nc
# missing files for year 2041 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2042_grid-T-TS.nc
# missing files for year 2042 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2043_grid-T-TS.nc
# missing files for year 2043 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2044_grid-T-TS.nc
# missing files for year 2044 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2045_grid-T-TS.nc
# missing files for year 2045 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2046_grid-T-TS.nc
# missing files for year 2046 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2047_grid-T-TS.nc
# missing files for year 2047 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2048_grid-T-TS.nc
# missing files for year 2048 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2049_grid-T-TS.nc
# missing files for year 2049 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2050_grid-T-TS.nc
# missing files for year 2050 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2051_grid-T-TS.nc
# missing files for year 2051 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2052_grid-T-TS.nc
# missing files for year 2052 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2053_grid-T-TS.nc
# missing files for year 2053 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2054_grid-T-TS.nc
# missing files for year 2054 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2055_grid-T-TS.nc
# missing files for year 2055 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2056_grid-T-TS.nc
# missing files for year 2056 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2057_grid-T-TS.nc
# missing files for year 2057 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2058_grid-T-TS.nc
# missing files for year 2058 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2059_grid-T-TS.nc
# missing files for year 2059 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2060_grid-T-TS.nc
# missing files for year 2060 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2061_grid-T-TS.nc
# missing files for year 2061 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2062_grid-T-TS.nc
# missing files for year 2062 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2063_grid-T-TS.nc
# missing files for year 2063 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2064_grid-T-TS.nc
# missing files for year 2064 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2065_grid-T-TS.nc
# missing files for year 2065 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2066_grid-T-TS.nc
# missing files for year 2066 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2067_grid-T-TS.nc
# missing files for year 2067 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2068_grid-T-TS.nc
# missing files for year 2068 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2069_grid-T-TS.nc
# missing files for year 2069 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2070_grid-T-TS.nc
# missing files for year 2070 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2071_grid-T-TS.nc
# missing files for year 2071 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2072_grid-T-TS.nc
# missing files for year 2072 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2073_grid-T-TS.nc
# missing files for year 2073 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2074_grid-T-TS.nc
# missing files for year 2074 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2075_grid-T-TS.nc
# missing files for year 2075 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2076_grid-T-TS.nc
# missing files for year 2076 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2077_grid-T-TS.nc
# missing files for year 2077 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2078_grid-T-TS.nc
# missing files for year 2078 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2079_grid-T-TS.nc
# missing files for year 2079 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2080_grid-T-TS.nc
# missing files for year 2080 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2081_grid-T-TS.nc
# missing files for year 2081 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2082_grid-T-TS.nc
# missing files for year 2082 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2083_grid-T-TS.nc
# missing files for year 2083 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2084_grid-T-TS.nc
# missing files for year 2084 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2085_grid-T-TS.nc
# missing files for year 2085 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2086_grid-T-TS.nc
# missing files for year 2086 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2087_grid-T-TS.nc
# missing files for year 2087 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2088_grid-T-TS.nc
# missing files for year 2088 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2089_grid-T-TS.nc
# missing files for year 2089 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2090_grid-T-TS.nc
# missing files for year 2090 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2091_grid-T-TS.nc
# missing files for year 2091 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2092_grid-T-TS.nc
# missing files for year 2092 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2093_grid-T-TS.nc
# missing files for year 2093 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2094_grid-T-TS.nc
# missing files for year 2094 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2095_grid-T-TS.nc
# missing files for year 2095 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2096_grid-T-TS.nc
# missing files for year 2096 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2097_grid-T-TS.nc
# missing files for year 2097 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2098_grid-T-TS.nc
# missing files for year 2098 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_ce417_1y_2099_grid-T-TS.nc
# missing files for year 2099 in ce417: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1950_grid-T-TS.nc
# missing files for year 1950 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1951_grid-T-TS.nc
# missing files for year 1951 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1952_grid-T-TS.nc
# missing files for year 1952 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1953_grid-T-TS.nc
# missing files for year 1953 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1954_grid-T-TS.nc
# missing files for year 1954 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1955_grid-T-TS.nc
# missing files for year 1955 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1956_grid-T-TS.nc
# missing files for year 1956 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1957_grid-T-TS.nc
# missing files for year 1957 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1958_grid-T-TS.nc
# missing files for year 1958 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1959_grid-T-TS.nc
# missing files for year 1959 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1960_grid-T-TS.nc
# missing files for year 1960 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1961_grid-T-TS.nc
# missing files for year 1961 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1962_grid-T-TS.nc
# missing files for year 1962 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1963_grid-T-TS.nc
# missing files for year 1963 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1964_grid-T-TS.nc
# missing files for year 1964 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1965_grid-T-TS.nc
# missing files for year 1965 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1966_grid-T-TS.nc
# missing files for year 1966 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1967_grid-T-TS.nc
# missing files for year 1967 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1968_grid-T-TS.nc
# missing files for year 1968 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1969_grid-T-TS.nc
# missing files for year 1969 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1970_grid-T-TS.nc
# missing files for year 1970 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1971_grid-T-TS.nc
# missing files for year 1971 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1972_grid-T-TS.nc
# missing files for year 1972 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1973_grid-T-TS.nc
# missing files for year 1973 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1974_grid-T-TS.nc
# missing files for year 1974 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1975_grid-T-TS.nc
# missing files for year 1975 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1976_grid-T-TS.nc
# missing files for year 1976 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1977_grid-T-TS.nc
# missing files for year 1977 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1978_grid-T-TS.nc
# missing files for year 1978 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1979_grid-T-TS.nc
# missing files for year 1979 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1980_grid-T-TS.nc
# missing files for year 1980 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1981_grid-T-TS.nc
# missing files for year 1981 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1982_grid-T-TS.nc
# missing files for year 1982 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1983_grid-T-TS.nc
# missing files for year 1983 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1984_grid-T-TS.nc
# missing files for year 1984 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1985_grid-T-TS.nc
# missing files for year 1985 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1986_grid-T-TS.nc
# missing files for year 1986 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1987_grid-T-TS.nc
# missing files for year 1987 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1988_grid-T-TS.nc
# missing files for year 1988 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1989_grid-T-TS.nc
# missing files for year 1989 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1990_grid-T-TS.nc
# missing files for year 1990 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1991_grid-T-TS.nc
# missing files for year 1991 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1992_grid-T-TS.nc
# missing files for year 1992 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1993_grid-T-TS.nc
# missing files for year 1993 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1994_grid-T-TS.nc
# missing files for year 1994 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1995_grid-T-TS.nc
# missing files for year 1995 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1996_grid-T-TS.nc
# missing files for year 1996 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1997_grid-T-TS.nc
# missing files for year 1997 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1998_grid-T-TS.nc
# missing files for year 1998 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_1999_grid-T-TS.nc
# missing files for year 1999 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2000_grid-T-TS.nc
# missing files for year 2000 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2001_grid-T-TS.nc
# missing files for year 2001 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2002_grid-T-TS.nc
# missing files for year 2002 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2003_grid-T-TS.nc
# missing files for year 2003 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2004_grid-T-TS.nc
# missing files for year 2004 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2005_grid-T-TS.nc
# missing files for year 2005 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2006_grid-T-TS.nc
# missing files for year 2006 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2007_grid-T-TS.nc
# missing files for year 2007 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2008_grid-T-TS.nc
# missing files for year 2008 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2009_grid-T-TS.nc
# missing files for year 2009 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2010_grid-T-TS.nc
# missing files for year 2010 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2011_grid-T-TS.nc
# missing files for year 2011 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2012_grid-T-TS.nc
# missing files for year 2012 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2013_grid-T-TS.nc
# missing files for year 2013 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj198_1y_2014_grid-T-TS.nc
# missing files for year 2014 in cj198: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2015_grid-T-TS.nc
# missing files for year 2015 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2016_grid-T-TS.nc
# missing files for year 2016 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2017_grid-T-TS.nc
# missing files for year 2017 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2018_grid-T-TS.nc
# missing files for year 2018 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2019_grid-T-TS.nc
# missing files for year 2019 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2020_grid-T-TS.nc
# missing files for year 2020 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2021_grid-T-TS.nc
# missing files for year 2021 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2022_grid-T-TS.nc
# missing files for year 2022 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2023_grid-T-TS.nc
# missing files for year 2023 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2024_grid-T-TS.nc
# missing files for year 2024 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2025_grid-T-TS.nc
# missing files for year 2025 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2026_grid-T-TS.nc
# missing files for year 2026 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2027_grid-T-TS.nc
# missing files for year 2027 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2028_grid-T-TS.nc
# missing files for year 2028 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2029_grid-T-TS.nc
# missing files for year 2029 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2030_grid-T-TS.nc
# missing files for year 2030 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2031_grid-T-TS.nc
# missing files for year 2031 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2032_grid-T-TS.nc
# missing files for year 2032 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2033_grid-T-TS.nc
# missing files for year 2033 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2034_grid-T-TS.nc
# missing files for year 2034 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2035_grid-T-TS.nc
# missing files for year 2035 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2036_grid-T-TS.nc
# missing files for year 2036 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2037_grid-T-TS.nc
# missing files for year 2037 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2038_grid-T-TS.nc
# missing files for year 2038 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2039_grid-T-TS.nc
# missing files for year 2039 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2040_grid-T-TS.nc
# missing files for year 2040 in cj880: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj880_1y_2041_grid-T-TS.nc
# ...
# missing files for year 2065 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2066_grid-T-TS.nc
# missing files for year 2066 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2067_grid-T-TS.nc
# missing files for year 2067 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2068_grid-T-TS.nc
# missing files for year 2068 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2069_grid-T-TS.nc
# missing files for year 2069 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2070_grid-T-TS.nc
# missing files for year 2070 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2071_grid-T-TS.nc
# missing files for year 2071 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2072_grid-T-TS.nc
# missing files for year 2072 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2073_grid-T-TS.nc
# missing files for year 2073 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2074_grid-T-TS.nc
# missing files for year 2074 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2075_grid-T-TS.nc
# missing files for year 2075 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2076_grid-T-TS.nc
# missing files for year 2076 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2077_grid-T-TS.nc
# missing files for year 2077 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2078_grid-T-TS.nc
# missing files for year 2078 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2079_grid-T-TS.nc
# missing files for year 2079 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2080_grid-T-TS.nc
# missing files for year 2080 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2081_grid-T-TS.nc
# missing files for year 2081 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2082_grid-T-TS.nc
# missing files for year 2082 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2083_grid-T-TS.nc
# missing files for year 2083 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2084_grid-T-TS.nc
# missing files for year 2084 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2085_grid-T-TS.nc
# missing files for year 2085 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2086_grid-T-TS.nc
# missing files for year 2086 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2087_grid-T-TS.nc
# missing files for year 2087 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2088_grid-T-TS.nc
# missing files for year 2088 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2089_grid-T-TS.nc
# missing files for year 2089 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2090_grid-T-TS.nc
# missing files for year 2090 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2091_grid-T-TS.nc
# missing files for year 2091 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2092_grid-T-TS.nc
# missing files for year 2092 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2093_grid-T-TS.nc
# missing files for year 2093 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2094_grid-T-TS.nc
# missing files for year 2094 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2095_grid-T-TS.nc
# missing files for year 2095 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2096_grid-T-TS.nc
# missing files for year 2096 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2097_grid-T-TS.nc
# missing files for year 2097 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2098_grid-T-TS.nc
# missing files for year 2098 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj484_1y_2099_grid-T-TS.nc
# missing files for year 2099 in cj484: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2015_grid-T-TS.nc
# missing files for year 2015 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2016_grid-T-TS.nc
# missing files for year 2016 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2017_grid-T-TS.nc
# missing files for year 2017 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2018_grid-T-TS.nc
# missing files for year 2018 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2019_grid-T-TS.nc
# missing files for year 2019 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2020_grid-T-TS.nc
# missing files for year 2020 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2021_grid-T-TS.nc
# missing files for year 2021 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2022_grid-T-TS.nc
# missing files for year 2022 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2023_grid-T-TS.nc
# missing files for year 2023 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2024_grid-T-TS.nc
# missing files for year 2024 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2025_grid-T-TS.nc
# missing files for year 2025 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2026_grid-T-TS.nc
# missing files for year 2026 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2027_grid-T-TS.nc
# missing files for year 2027 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2028_grid-T-TS.nc
# missing files for year 2028 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2029_grid-T-TS.nc
# missing files for year 2029 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2030_grid-T-TS.nc
# missing files for year 2030 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2031_grid-T-TS.nc
# missing files for year 2031 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2032_grid-T-TS.nc
# missing files for year 2032 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2033_grid-T-TS.nc
# missing files for year 2033 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2034_grid-T-TS.nc
# missing files for year 2034 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2035_grid-T-TS.nc
# missing files for year 2035 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2036_grid-T-TS.nc
# missing files for year 2036 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2037_grid-T-TS.nc
# missing files for year 2037 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2038_grid-T-TS.nc
# missing files for year 2038 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2039_grid-T-TS.nc
# missing files for year 2039 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2040_grid-T-TS.nc
# missing files for year 2040 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2041_grid-T-TS.nc
# missing files for year 2041 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2042_grid-T-TS.nc
# missing files for year 2042 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2043_grid-T-TS.nc
# missing files for year 2043 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2044_grid-T-TS.nc
# missing files for year 2044 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2045_grid-T-TS.nc
# missing files for year 2045 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2046_grid-T-TS.nc
# missing files for year 2046 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2047_grid-T-TS.nc
# missing files for year 2047 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2048_grid-T-TS.nc
# missing files for year 2048 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2049_grid-T-TS.nc
# missing files for year 2049 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2050_grid-T-TS.nc
# missing files for year 2050 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2051_grid-T-TS.nc
# missing files for year 2051 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2052_grid-T-TS.nc
# missing files for year 2052 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2053_grid-T-TS.nc
# missing files for year 2053 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2054_grid-T-TS.nc
# missing files for year 2054 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2055_grid-T-TS.nc
# missing files for year 2055 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2056_grid-T-TS.nc
# missing files for year 2056 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2057_grid-T-TS.nc
# missing files for year 2057 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2058_grid-T-TS.nc
# missing files for year 2058 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2059_grid-T-TS.nc
# missing files for year 2059 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2060_grid-T-TS.nc
# missing files for year 2060 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2061_grid-T-TS.nc
# missing files for year 2061 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2062_grid-T-TS.nc
# missing files for year 2062 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2063_grid-T-TS.nc
# missing files for year 2063 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2064_grid-T-TS.nc
# missing files for year 2064 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2065_grid-T-TS.nc
# missing files for year 2065 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2066_grid-T-TS.nc
# missing files for year 2066 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2067_grid-T-TS.nc
# missing files for year 2067 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2068_grid-T-TS.nc
# missing files for year 2068 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2069_grid-T-TS.nc
# missing files for year 2069 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2070_grid-T-TS.nc
# missing files for year 2070 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2071_grid-T-TS.nc
# missing files for year 2071 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2072_grid-T-TS.nc
# missing files for year 2072 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2073_grid-T-TS.nc
# missing files for year 2073 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2074_grid-T-TS.nc
# missing files for year 2074 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2075_grid-T-TS.nc
# missing files for year 2075 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2076_grid-T-TS.nc
# missing files for year 2076 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2077_grid-T-TS.nc
# missing files for year 2077 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2078_grid-T-TS.nc
# missing files for year 2078 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2079_grid-T-TS.nc
# missing files for year 2079 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2080_grid-T-TS.nc
# missing files for year 2080 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2081_grid-T-TS.nc
# missing files for year 2081 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2082_grid-T-TS.nc
# missing files for year 2082 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2083_grid-T-TS.nc
# missing files for year 2083 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2084_grid-T-TS.nc
# missing files for year 2084 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2085_grid-T-TS.nc
# missing files for year 2085 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2086_grid-T-TS.nc
# missing files for year 2086 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2087_grid-T-TS.nc
# missing files for year 2087 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2088_grid-T-TS.nc
# missing files for year 2088 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2089_grid-T-TS.nc
# missing files for year 2089 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2090_grid-T-TS.nc
# missing files for year 2090 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2091_grid-T-TS.nc
# missing files for year 2091 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2092_grid-T-TS.nc
# missing files for year 2092 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2093_grid-T-TS.nc
# missing files for year 2093 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2094_grid-T-TS.nc
# missing files for year 2094 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2095_grid-T-TS.nc
# missing files for year 2095 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2096_grid-T-TS.nc
# missing files for year 2096 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2097_grid-T-TS.nc
# missing files for year 2097 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2098_grid-T-TS.nc
# missing files for year 2098 in cj504: we have 0
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_cj504_1y_2099_grid-T-TS.nc
# missing files for year 2099 in cj504: we have 0

# %% [markdown]
# ## co2 and flux

# %%
def check_filetype_present_TADIC(yr,runname,rtype):

    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS/nemo_{runname}*1m_{yr}*{rtype}*nc'

    tw = glob.glob(savenam)
    #print(tw)
    if len(tw) != 12:
        print(f'{yr}, {runname} {rtype} missing')
    else:
        print(f'{yr} OKOKOKOKOKOKOK {runname}')
    
#1h OK
rtype = 'grid-T'
runname = 'bc370'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
print()
#1b
runname= 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
print()
# #2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    
print()
# #2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
print()    
# #2b
runname= 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)

print()    
# #3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    
print()
# #3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    
print()    
# #3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
# Out:
# 1950 OKOKOKOKOKOKOK bc370
# 1951 OKOKOKOKOKOKOK bc370
# 1952 OKOKOKOKOKOKOK bc370
# 1953 OKOKOKOKOKOKOK bc370
# 1954 OKOKOKOKOKOKOK bc370
# 1955 OKOKOKOKOKOKOK bc370
# 1956 OKOKOKOKOKOKOK bc370
# 1957 OKOKOKOKOKOKOK bc370
# 1958 OKOKOKOKOKOKOK bc370
# 1959 OKOKOKOKOKOKOK bc370
# 1960 OKOKOKOKOKOKOK bc370
# 1961 OKOKOKOKOKOKOK bc370
# 1962 OKOKOKOKOKOKOK bc370
# 1963 OKOKOKOKOKOKOK bc370
# 1964 OKOKOKOKOKOKOK bc370
# 1965 OKOKOKOKOKOKOK bc370
# 1966 OKOKOKOKOKOKOK bc370
# 1967 OKOKOKOKOKOKOK bc370
# 1968 OKOKOKOKOKOKOK bc370
# 1969 OKOKOKOKOKOKOK bc370
# 2052 OKOKOKOKOKOKOK cj504
# 2053 OKOKOKOKOKOKOK cj504
# 2054 OKOKOKOKOKOKOK cj504
# 2055 OKOKOKOKOKOKOK cj504
# 2056 OKOKOKOKOKOKOK cj504
# 2057 OKOKOKOKOKOKOK cj504
# 2058 OKOKOKOKOKOKOK cj504
# 2059 OKOKOKOKOKOKOK cj504
# 2060 OKOKOKOKOKOKOK cj504
# 2061 OKOKOKOKOKOKOK cj504
# 2062 OKOKOKOKOKOKOK cj504
# 2063 OKOKOKOKOKOKOK cj504
# 2064 OKOKOKOKOKOKOK cj504
# 2065 OKOKOKOKOKOKOK cj504
# 2066 OKOKOKOKOKOKOK cj504
# 2067 OKOKOKOKOKOKOK cj504
# 2068 OKOKOKOKOKOKOK cj504
# 2069 OKOKOKOKOKOKOK cj504
# 2070 OKOKOKOKOKOKOK cj504
# 2071 OKOKOKOKOKOKOK cj504
# 2072 OKOKOKOKOKOKOK cj504
# 2073 OKOKOKOKOKOKOK cj504
# 2074 OKOKOKOKOKOKOK cj504
# 2075 OKOKOKOKOKOKOK cj504
# 2076 OKOKOKOKOKOKOK cj504
# 2077 OKOKOKOKOKOKOK cj504
# 2078 OKOKOKOKOKOKOK cj504
# 2079 OKOKOKOKOKOKOK cj504
# 2080 OKOKOKOKOKOKOK cj504
# 2081 OKOKOKOKOKOKOK cj504
# 2082 OKOKOKOKOKOKOK cj504
# 2083 OKOKOKOKOKOKOK cj504
# 2084 OKOKOKOKOKOKOK cj504
# 2085 OKOKOKOKOKOKOK cj504
# 2086 OKOKOKOKOKOKOK cj504
# 2087 OKOKOKOKOKOKOK cj504
# 2088 OKOKOKOKOKOKOK cj504
# 2089 OKOKOKOKOKOKOK cj504
# 2090 OKOKOKOKOKOKOK cj504
# 2091 OKOKOKOKOKOKOK cj504
# 2092 OKOKOKOKOKOKOK cj504
# 2093 OKOKOKOKOKOKOK cj504
# 2094 OKOKOKOKOKOKOK cj504
# 2095 OKOKOKOKOKOKOK cj504
# 2096 OKOKOKOKOKOKOK cj504
# 2097 OKOKOKOKOKOKOK cj504
# 2098 OKOKOKOKOKOKOK cj504
# 2099 OKOKOKOKOKOKOK cj504

# %%
def make_yearly_subset_diadT_co2(yr,runname):

    #what is new file going to be called:
    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_{runname}_1y_{yr}_diad-T-co2.nc'
    print(savenam)
    
    #get by-month dimension for this year:
    times = pd.date_range(f"{yr}/01/01",f"{yr+1}/01/01",freq='M',closed='left')
    #get the spatial dimensions from a variable


    #get the files we are converting
    td = f'/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_diadT_co2/*/medusa_{runname}*_1m_{yr}*01-*diad-T.nc'
    fils = glob.glob(td)
    fils.sort()
    
    if len(fils) != 12:
        print(f'missing files for year {yr} in {runname}: we have {len(fils)}')
        return

    else:
        ## define variables that we are saving
        
        q = xr.open_dataset(fils[0])
        #print(q)
        nav_lat = q['nav_lat'].values
        nav_lon = q['nav_lon'].values

        OCN_PCO2 = np.zeros([12,332,362])
        CO2FLUX = np.zeros([12,332,362])
        
        for i in range(0,12):
            tfil = xr.open_dataset(fils[i])
            OCN_PCO2[i,:,:] = tfil['OCN_PCO2'][:,:].values
            CO2FLUX[i,:,:] = tfil['CO2FLUX'][:,:].values
            
        # define data with variable attributes
        print(np.nanmax(OCN_PCO2))
        
        data_vars = {'OCN_PCO2':(['time_counter','y', 'x'], OCN_PCO2,
                                 {'units': 'µatm',
                                  'long_name':'Surface ocean pCO2'}),
                     'CO2FLUX':(['time_counter', 'y', 'x'], CO2FLUX,
                                 {'units': 'mmol-C/m2/d',
                                  'long_name':'Air-sea CO2 flux'}),   
                    }

        # define coordinates
        coords = {'time_counter': (['time_counter'], times),
            'nav_lat': (['y','x'], nav_lat),
            'nav_lon': (['y','x'], nav_lon)}

        # define global attributes
        attrs = {'made in':'SOZONE/MEDUSA/makeYearlyMEDUSAsubsetfiles.ipynb',
                'desc': 'yearly medusa files, saving only variables of interest'
                }

        ds = xr.Dataset(data_vars=data_vars,
                        coords=coords,
                        attrs=attrs)

        try:
            ds.to_netcdf(savenam)
        except:
            print(f'seems like {savenam} exists already')
    
#make_yearly_subset_nc(1954,'cj198')

# %% [markdown]
# ## pco2 yearly files

# %%
#1h
# runname = 'bc370'
# yrs = np.arange(1950,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)    

#1a
# runname = 'be682'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)

# #1b
# runname = 'ce417'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)

# #2h
# runname = 'cj198'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)    

# #2a
# runname = 'cj880'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)
    
# #2b
# runname = 'cj881'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)
    
    
# #3h
# runname = 'cj200'
# yrs = np.arange(1990,2015,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)    
    
# #3a
# runname = 'cj484'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)    
    
# #3a
# runname = 'cj504'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_co2(y,runname)

# %%
def make_yearly_subset_gridT_mld(yr,runname):

    #what is new file going to be called:
    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_{runname}_1y_{yr}_grid-T-MLD.nc'
    print(savenam)
    
    #get by-month dimension for this year:
    times = pd.date_range(f"{yr}/01/01",f"{yr+1}/01/01",freq='M',closed='left')
    #get the spatial dimensions from a variable


    #get the files we are converting
    td = f'/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_mld/nemo_{runname}*_1m_{yr}*01-*grid-T.nc'
    fils = glob.glob(td)
    fils.sort()
    
    if len(fils) != 12:
        print(f'missing files for year {yr} in {runname}: we have {len(fils)}')
        return

    else:
        ## define variables that we are saving
        
        q = xr.open_dataset(fils[0])
        #print(q)
        nav_lat = q['nav_lat'].values
        nav_lon = q['nav_lon'].values

        somxl010 = np.zeros([12,332,362])
        #CO2FLUX = np.zeros([12,332,362])
        
        for i in range(0,12):
            tfil = xr.open_dataset(fils[i])
            somxl010[i,:,:] = tfil['somxl010'][:,:].values
            #CO2FLUX[i,:,:] = tfil['CO2FLUX'][:,:].values
        # define data with variable attributes
        data_vars = {'somxl010':(['time_counter','y', 'x'], somxl010,
                                 {'units': 'µatm',
                                  'long_name':'MLD'}),   
                    }

        # define coordinates
        coords = {'time_counter': (['time_counter'], times),
            'nav_lat': (['y','x'], nav_lat),
            'nav_lon': (['y','x'], nav_lon)}

        # define global attributes
        attrs = {'made in':'SOZONE/MEDUSA/makeYearlyMEDUSAsubsetfiles.ipynb',
                'desc': 'yearly medusa files, saving only variables of interest'
                }

        ds = xr.Dataset(data_vars=data_vars,
                        coords=coords,
                        attrs=attrs)

        try:
            ds.to_netcdf(savenam)
        except:
            print(f'seems like {savenam} exists already')
    
#make_yearly_subset_nc(1954,'cj198')

# %%
# #1h
# runname = 'bc370'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)    

# #1a
# runname = 'be682'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)

# #1b
# runname = 'ce417'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)

# #2h
# runname = 'cj198'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)    

# #2a
# runname = 'cj880'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)
    
# #2b
# runname = 'cj881'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)
    
    
# #3h
# runname = 'cj200'
# yrs = np.arange(1990,2015,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)    
    
# #3a
# runname = 'cj484'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)    
    
# #3a
# runname = 'cj504'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT_mld(y,runname)

# %% [markdown]
# ### diadT auxillary variables

# %%
v = xr.open_dataset('/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_diadT_aux/medusa_cj484o_1m_20991201-21000101_diad-T.nc')
v
# Out:
# <xarray.Dataset>
# Dimensions:        (time_counter: 1, x: 362, y: 332)
# Coordinates:
#     nav_lat        (y, x) float32 ...
#     nav_lon        (y, x) float32 ...
#     time_centered  (time_counter) object ...
#   * time_counter   (time_counter) float64 0.0
# Dimensions without coordinates: x, y
# Data variables:
#     CHL_MLD        (time_counter, y, x) float32 ...
#     CO2FLUX        (time_counter, y, x) float32 ...
#     ML_PRD         (time_counter, y, x) float32 ...
#     ML_PRN         (time_counter, y, x) float32 ...
#     OCN_DPCO2      (time_counter, y, x) float32 ...
#     OCN_PCO2       (time_counter, y, x) float32 ...
#     WIND           (time_counter, y, x) float32 ...
# Attributes:
#     name:         cj484o_1m_20991001_20991230
#     description:  Medusa diagnostic variables
#     title:        Medusa diagnostic variables
#     Conventions:  CF-1.5
#     production:   An IPSL model
#     timeStamp:    2022-Jan-09 02:44:44 UTC
#     ibegin:       0
#     ni:           362
#     jbegin:       0
#     nj:           56
#     file_name:    medusa_cj484o_1m_20991201-21000101_diad-T.nc
#     TimeStamp:    09/01/2022 04:44:51 +0000
#     history:      Thu Feb 23 17:38:35 2023: /opt/moose/moose-netcdf/bin/ncks ...
#     NCO:          4.4.5

# %%
def make_yearly_subset_diadT_aux(yr,runname):

    #what is new file going to be called:
    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_{runname}_1y_{yr}_diad-T-aux.nc'
    print(savenam)
    
    #get by-month dimension for this year:
    times = pd.date_range(f"{yr}/01/01",f"{yr+1}/01/01",freq='M',closed='left')
    #get the spatial dimensions from a variable


    #get the files we are converting
    td = f'/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_diadT_aux/*_{runname}*_1m_{yr}*01-*diad-T.nc'
    fils = glob.glob(td)
    fils.sort()
    
    if len(fils) != 12:
        print(f'missing files for year {yr} in {runname}: we have {len(fils)}')
        return

    else:
        ## define variables that we are saving
        
        q = xr.open_dataset(fils[0])
        #print(q)
        nav_lat = q['nav_lat'].values
        nav_lon = q['nav_lon'].values

        CHL_MLD = np.zeros([12,332,362])
        CO2FLUX = np.zeros([12,332,362])
        ML_PRD = np.zeros([12,332,362])
        ML_PRN = np.zeros([12,332,362])
        OCN_DPCO2 = np.zeros([12,332,362])
        OCN_PCO2 = np.zeros([12,332,362])
        WIND = np.zeros([12,332,362])
        #CO2FLUX = np.zeros([12,332,362])
        
        for i in range(0,12):
            tfil = xr.open_dataset(fils[i])
            CHL_MLD[i,:,:] = tfil['CHL_MLD'][:,:].values
            CO2FLUX[i,:,:] = tfil['CO2FLUX'][:,:].values
            ML_PRD[i,:,:] = tfil['ML_PRD'][:,:].values
            ML_PRN[i,:,:] = tfil['ML_PRN'][:,:].values
            OCN_DPCO2[i,:,:] = tfil['OCN_DPCO2'][:,:].values
            OCN_PCO2[i,:,:] = tfil['OCN_PCO2'][:,:].values
            WIND[i,:,:] = tfil['WIND'][:,:].values
            #CO2FLUX[i,:,:] = tfil['CO2FLUX'][:,:].values
        # define data with variable attributes
        data_vars = {'CHL_MLD':(['time_counter','y', 'x'], CHL_MLD,
                                 {'units': '',
                                  'long_name':''}),   
                    'CO2FLUX':(['time_counter','y', 'x'], CO2FLUX,
                                 {'units': '',
                                  'long_name':''}), 
                     'ML_PRD':(['time_counter','y', 'x'], ML_PRD,
                                 {'units': '',
                                  'long_name':''}), 
                     'ML_PRN':(['time_counter','y', 'x'], ML_PRN,
                                 {'units': '',
                                  'long_name':''}), 
                     'OCN_DPCO2':(['time_counter','y', 'x'], OCN_DPCO2,
                                 {'units': '',
                                  'long_name':''}), 
                     'OCN_PCO2':(['time_counter','y', 'x'], OCN_PCO2,
                                 {'units': '',
                                  'long_name':''}), 
                     'WIND':(['time_counter','y', 'x'], WIND,
                                 {'units': '',
                                  'long_name':''}), 
                    }

        # define coordinates
        coords = {'time_counter': (['time_counter'], times),
            'nav_lat': (['y','x'], nav_lat),
            'nav_lon': (['y','x'], nav_lon)}

        # define global attributes
        attrs = {'made in':'SOZONE/MEDUSA/makeYearlyMEDUSAsubsetfiles.ipynb',
                'desc': 'yearly medusa files, saving only variables of interest'
                }

        ds = xr.Dataset(data_vars=data_vars,
                        coords=coords,
                        attrs=attrs)

        try:
            ds.to_netcdf(savenam)
        except:
            print(f'----------------seems like {savenam} exists already')
    
#make_yearly_subset_nc(1954,'cj198')

# %%
# #1h
# runname = 'bc370'
# yrs = np.arange(1950,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)    

# #1a
# runname = 'be682'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)

# #1b
# runname = 'ce417'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)

# #2h
# runname = 'cj198'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)    

# #2a
# runname = 'cj880'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)
    
# #2b
# runname = 'cj881'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)
    
    
# #3h
# runname = 'cj200'
# yrs = np.arange(1990,2015,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)    
    
# #3a
# runname = 'cj484'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)    
    
# #3a
# runname = 'cj504'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_gridT(y,runname)

# %%
# #1h
# runname = 'bc370'
# yrs = np.arange(1950,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)    

# #1a
# runname = 'be682'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)

# #1b
# runname = 'ce417'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)

# #2h
# runname = 'cj198'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)    

# #2a
# runname = 'cj880'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)
    
# #2b
# runname = 'cj881'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)
    
    
# #3h
# runname = 'cj200'
# yrs = np.arange(1990,2015,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)    
    
# #3a
# runname = 'cj484'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)    
    
# #3a
# runname = 'cj504'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     make_yearly_subset_diadT_aux(y,runname)

# %% [markdown]
# ## check for files?

# %%
def check_filetype_present(yr,runname,rtype):

    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_{runname}_1y_{yr}_*{rtype}*.nc'

    tw = glob.glob(savenam)
    if len(tw) != 1:
        print(f'{yr}, {runname} {rtype} missing')
    
#make_yearly_subset_nc(1954,'cj198')

# %%
def check_filetype_present_TADIC(yr,runname,rtype):

    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_ptrcT_TADIC/medusa_{runname}*1m_{yr}*{rtype}*nc'

    tw = glob.glob(savenam)
    #print(tw)
    if len(tw) != 12:
        print(f'{yr}, {runname} {rtype} missing')
    else:
        print(f'{yr} OKOKOKOKOKOKOK {runname}')
    
#1h OK
rtype = 'ptrc-T'
runname = 'bc370'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
print()
#1b
runname= 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
print()
# #2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    
print()
# #2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
print()    
# #2b
runname= 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)

print()    
# #3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    
print()
# #3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)    
print()    
# #3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_TADIC(y,runname,rtype)
# Out:
# 1950 OKOKOKOKOKOKOK bc370
# 1951 OKOKOKOKOKOKOK bc370
# 1952 OKOKOKOKOKOKOK bc370
# 1953 OKOKOKOKOKOKOK bc370
# 1954 OKOKOKOKOKOKOK bc370
# 1955 OKOKOKOKOKOKOK bc370
# 1956 OKOKOKOKOKOKOK bc370
# 1957 OKOKOKOKOKOKOK bc370
# 1958 OKOKOKOKOKOKOK bc370
# 1959 OKOKOKOKOKOKOK bc370
# 2043 OKOKOKOKOKOKOK cj504
# 2044 OKOKOKOKOKOKOK cj504
# 2045 OKOKOKOKOKOKOK cj504
# 2046 OKOKOKOKOKOKOK cj504
# 2047 OKOKOKOKOKOKOK cj504
# 2048 OKOKOKOKOKOKOK cj504
# 2049 OKOKOKOKOKOKOK cj504
# 2050 OKOKOKOKOKOKOK cj504
# 2051 OKOKOKOKOKOKOK cj504
# 2052 OKOKOKOKOKOKOK cj504
# 2053 OKOKOKOKOKOKOK cj504
# 2054 OKOKOKOKOKOKOK cj504
# 2055 OKOKOKOKOKOKOK cj504
# 2056 OKOKOKOKOKOKOK cj504
# 2057 OKOKOKOKOKOKOK cj504
# 2058 OKOKOKOKOKOKOK cj504
# 2059 OKOKOKOKOKOKOK cj504
# 2060 OKOKOKOKOKOKOK cj504
# 2061 OKOKOKOKOKOKOK cj504
# 2062 OKOKOKOKOKOKOK cj504
# 2063 OKOKOKOKOKOKOK cj504
# 2064 OKOKOKOKOKOKOK cj504
# 2065 OKOKOKOKOKOKOK cj504
# 2066 OKOKOKOKOKOKOK cj504
# 2067 OKOKOKOKOKOKOK cj504
# 2068 OKOKOKOKOKOKOK cj504
# 2069 OKOKOKOKOKOKOK cj504
# 2070 OKOKOKOKOKOKOK cj504
# 2071 OKOKOKOKOKOKOK cj504
# 2072 OKOKOKOKOKOKOK cj504
# 2073 OKOKOKOKOKOKOK cj504
# 2074 OKOKOKOKOKOKOK cj504
# 2075 OKOKOKOKOKOKOK cj504
# 2076 OKOKOKOKOKOKOK cj504
# 2077 OKOKOKOKOKOKOK cj504
# 2078 OKOKOKOKOKOKOK cj504
# 2079 OKOKOKOKOKOKOK cj504
# 2080 OKOKOKOKOKOKOK cj504
# 2081 OKOKOKOKOKOKOK cj504
# 2082 OKOKOKOKOKOKOK cj504
# 2083 OKOKOKOKOKOKOK cj504
# 2084 OKOKOKOKOKOKOK cj504
# 2085 OKOKOKOKOKOKOK cj504
# 2086 OKOKOKOKOKOKOK cj504
# 2087 OKOKOKOKOKOKOK cj504
# 2088 OKOKOKOKOKOKOK cj504
# 2089 OKOKOKOKOKOKOK cj504
# 2090 OKOKOKOKOKOKOK cj504
# 2091 OKOKOKOKOKOKOK cj504
# 2092 OKOKOKOKOKOKOK cj504
# 2093 OKOKOKOKOKOKOK cj504
# 2094 OKOKOKOKOKOKOK cj504
# 2095 OKOKOKOKOKOKOK cj504
# 2096 OKOKOKOKOKOKOK cj504
# 2097 OKOKOKOKOKOKOK cj504
# 2098 OKOKOKOKOKOKOK cj504
# 2099 OKOKOKOKOKOKOK cj504

# %% [markdown]
# ### checking that certain file types are present
#
# ok:
# T-co2
# MLD
#
# missing

# %%
# #1h
# rtype = 'aux'
# runname = 'bc370'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)    

# #1a
# runname = 'be682'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)

# #1b
# runname= 'ce417'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)

# #2h
# runname = 'cj198'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)    

# #2a
# runname = 'cj880'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)
    
# #2b
# runname= 'cj881'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)
    
    
# #3h
# runname = 'cj200'
# yrs = np.arange(1990,2015,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)    
    
# #3a
# runname = 'cj484'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)    
    
# #3a
# runname = 'cj504'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present(y,runname,rtype)

# %% [markdown]
# ## make yearly wind files

# %%
scen = '1A'
ts = f'/gpfs/home/mep22dku/scratch/SOZONE/MO_pipeline/EXTRACT/ncs/scen_{scen}_monthly_wspd.nc'
tw = xr.open_dataset(ts)

# %%
def make_yearly_subset_ptrc_TADICCHL(yr,runname):

    #what is new file going to be called:
    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_{runname}_1y_{yr}_diad-T-co2.nc'
    print(savenam)
    
    #get by-month dimension for this year:
    times = pd.date_range(f"{yr}/01/01",f"{yr+1}/01/01",freq='M',closed='left')
    #get the spatial dimensions from a variable


    #get the files we are converting
    td = f'/gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_ptrcT_TADIC/medusa_{runname}*_1m_{yr}*01-*ptrc-T.nc'
    fils = glob.glob(td)
    fils.sort()
    
    if len(fils) != 12:
        print(f'missing files for year {yr} in {runname}: we have {len(fils)}')
        return

    else:
        ## define variables that we are saving
        
        q = xr.open_dataset(fils[0])
        #print(q)
        nav_lat = q['nav_lat'].values
        nav_lon = q['nav_lon'].values
        deptht = q['deptht'].values

        ALK = np.zeros([12,75,332,362])
        DIC = np.zeros([12,75,332,362])
        CHD = np.zeros([12,75,332,362])
        CHN = np.zeros([12,75,332,362])
        
        for i in range(0,12):
            tfil = xr.open_dataset(fils[i])
            ALK[i,:,:,:] = tfil['ALK'][:,:,:].values
            DIC[i,:,:,:] = tfil['DIC'][:,:,:].values
            CHD[i,:,:,:] = tfil['CHD'][:,:,:].values
            CHN[i,:,:,:] = tfil['CHN'][:,:,:].values
            
        # define data with variable attributes

        
        data_vars = {'ALK':(['time_counter','deptht','y', 'x'], ALK,
                                 {'units': 'mmol/m3',
                                  'long_name':''}),
                     'DIC':(['time_counter','deptht', 'y', 'x'], DIC,
                                 {'units': 'mmol/m3',
                                  'long_name':''}),   
                     'CHD':(['time_counter','deptht', 'y', 'x'], CHD,
                                 {'units': 'mg-Chl/m3',
                                  'long_name':''}), 
                     'CHN':(['time_counter','deptht', 'y', 'x'], CHN,
                                 {'units': 'mg-Chl/m3',
                                  'long_name':''}), 
                    }

        # define coordinates
        coords = {'time_counter': (['time_counter'], times),
            'nav_lat': (['y','x'], nav_lat),
            'nav_lon': (['y','x'], nav_lon),
            'deptht': (['deptht'], deptht)}


        # define global attributes
        attrs = {'made in':'SOZONE/MEDUSA/makeYearlyMEDUSAsubsetfiles.ipynb',
                'desc': 'yearly medusa files, saving only variables of interest'
                }

        ds = xr.Dataset(data_vars=data_vars,
                        coords=coords,
                        attrs=attrs)

        try:
            ds.to_netcdf(savenam)
        except:
            print(f'seems like {savenam} exists already')
    
#make_yearly_subset_nc(1954,'cj198')

# %%
#1h
runname = 'bc370'
yrs = np.arange(1950,2100,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)

#1b
runname = 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)

#2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)    

#2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)
    
#2b
runname = 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)
    
    
#3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)    
    
#3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)    
    
#3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    make_yearly_subset_ptrc_TADICCHL(y,runname)
# Out:
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1950_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1951_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1952_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1953_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1954_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1955_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1956_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1957_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1958_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1959_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1960_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1961_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1962_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1963_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1964_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1965_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1966_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1967_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1968_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1969_diad-T-co2.nc
# /gpfs/data/greenocean/software/resources/MEDUSA/PROC2/medusa_bc370_1y_1970_diad-T-co2.nc
