# %% [markdown]
# ### aim:
#
# ### date:

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %%
tdir = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/'

for y in range(1940,2020):
    print(y)
    for b in range(8,15):
        try:
            dst = f'{tdir}era5_bulk_{b}_y{y}.nc'
            tfil = xr.open_dataset(dst, decode_times=False)
            noday = (tfil.time_counter.shape[0])
            nox = (tfil.x.shape[0])
            noy = (tfil.y.shape[0])
            if ((noday != 365) & (noday != 366)):
                print(f'processing problem year {y} bulk variable {b}')
            if ((nox != 182)):
                print(f'processing problem year {y} bulk variable {b}')
            if ((noy != 149)):
                print(f'processing problem year {y} bulk variable {b}')            
            # print(f'year {y} bulk variable (noday != 365) {b} GO!')
        except:
            print(f'failed to find for year {y} bulk variable {b}')
    try: 
        dst = f'{tdir}taux_1d_y{y}.nc'
        tfil = xr.open_dataset(dst, decode_times=False)
        noday = (tfil.time_counter.shape[0])
        nox = (tfil.x.shape[0])
        noy = (tfil.y.shape[0])
        if ((noday != 365) & (noday != 366)):
            print(f'processing problem year {y} taux')
        if ((nox != 182)):
            print(f'processing problem year {y} taux')
        if ((noy != 149)):
            print(f'processing problem year {y} taux')     
    except:
        print(f'failed to find for year {y} taux')

    try: 
        dst = f'{tdir}tauy_1d_y{y}.nc'
        tfil = xr.open_dataset(dst, decode_times=False)
        noday = (tfil.time_counter.shape[0])
        nox = (tfil.x.shape[0])
        noy = (tfil.y.shape[0])
        if ((noday != 365) & (noday != 366)):
            print(f'processing problem year {y} tauy')
        if ((nox != 182)):
            print(f'processing problem year {y} tauy')
        if ((noy != 149)):
            print(f'processing problem year {y} tauy')     
    except:
        print(f'failed to find for year {y} tauy')
        


print('we have shutdown')
# Out:
# 1940
# processing problem year 1940 bulk variable 9
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# processing problem year 1949 bulk variable 9
# 1950
# 1951
# 1952
# 1953
# processing problem year 1953 bulk variable 9
# 1954
# 1955
# 1956
# 1957
# 1958
# processing problem year 1958 bulk variable 9
# 1959
# processing problem year 1959 bulk variable 9
# 1960
# processing problem year 1960 bulk variable 9
# 1961
# 1962
# processing problem year 1962 bulk variable 9
# 1963
# processing problem year 1963 bulk variable 9
# 1964
# processing problem year 1964 bulk variable 9
# 1965
# 1966
# 1967
# 1968
# processing problem year 1968 bulk variable 9
# failed to find for year 1996 bulk variable 11
# failed to find for year 1996 bulk variable 12
# failed to find for year 1996 bulk variable 13
# failed to find for year 1996 bulk variable 14
# failed to find for year 1996 taux
# failed to find for year 1996 tauy
# 1997
# failed to find for year 1997 bulk variable 8
# failed to find for year 1997 bulk variable 9
# failed to find for year 1997 bulk variable 10
# failed to find for year 1997 bulk variable 11
# failed to find for year 1997 bulk variable 12
# failed to find for year 1997 bulk variable 13
# failed to find for year 1997 bulk variable 14
# failed to find for year 1997 taux
# failed to find for year 1997 tauy
# 1998
# failed to find for year 1998 bulk variable 8
# failed to find for year 1998 bulk variable 9
# failed to find for year 1998 bulk variable 10
# failed to find for year 1998 bulk variable 11
# failed to find for year 1998 bulk variable 12
# failed to find for year 1998 bulk variable 13
# failed to find for year 1998 bulk variable 14
# failed to find for year 1998 taux
# failed to find for year 1998 tauy
# 1999
# failed to find for year 1999 bulk variable 8
# failed to find for year 1999 bulk variable 9
# failed to find for year 1999 bulk variable 10
# failed to find for year 1999 bulk variable 11
# failed to find for year 1999 bulk variable 12
# failed to find for year 1999 bulk variable 13
# failed to find for year 1999 bulk variable 14
# failed to find for year 1999 taux
# failed to find for year 1999 tauy
# 2000
# failed to find for year 2000 bulk variable 8
# failed to find for year 2000 bulk variable 9
# failed to find for year 2000 bulk variable 10
# failed to find for year 2000 bulk variable 11
# failed to find for year 2000 bulk variable 12
# failed to find for year 2000 bulk variable 13
# failed to find for year 2000 bulk variable 14
# failed to find for year 2000 taux
# failed to find for year 2000 tauy
# 2001
# failed to find for year 2001 bulk variable 8
# failed to find for year 2001 bulk variable 9
# failed to find for year 2001 bulk variable 10
# failed to find for year 2001 bulk variable 11
# failed to find for year 2001 bulk variable 12
# failed to find for year 2001 bulk variable 13
# failed to find for year 2001 bulk variable 14
# failed to find for year 2001 taux
# failed to find for year 2001 tauy
# 2002
# failed to find for year 2002 bulk variable 8
# failed to find for year 2002 bulk variable 9
# failed to find for year 2002 bulk variable 10
# failed to find for year 2002 bulk variable 11
# failed to find for year 2002 bulk variable 12
# failed to find for year 2002 bulk variable 13
# failed to find for year 2002 bulk variable 14
# failed to find for year 2002 taux
# failed to find for year 2002 tauy
# 2003
# failed to find for year 2003 bulk variable 8
# failed to find for year 2003 bulk variable 9
# failed to find for year 2003 bulk variable 10
# failed to find for year 2003 bulk variable 11
# failed to find for year 2003 bulk variable 12
# failed to find for year 2003 bulk variable 13
# failed to find for year 2003 bulk variable 14
# failed to find for year 2003 taux
# failed to find for year 2003 tauy
# 2004
# failed to find for year 2004 bulk variable 8
# failed to find for year 2004 bulk variable 9
# failed to find for year 2004 bulk variable 10
# failed to find for year 2004 bulk variable 11
# failed to find for year 2004 bulk variable 12
# failed to find for year 2004 bulk variable 13
# failed to find for year 2004 bulk variable 14
# failed to find for year 2004 taux
# failed to find for year 2004 tauy
# 2005
# failed to find for year 2005 bulk variable 8
# failed to find for year 2005 bulk variable 9
# failed to find for year 2005 bulk variable 10
# failed to find for year 2005 bulk variable 11
# failed to find for year 2005 bulk variable 12
# failed to find for year 2005 bulk variable 13
# failed to find for year 2005 bulk variable 14
# failed to find for year 2005 taux
# failed to find for year 2005 tauy
# 2006
# failed to find for year 2006 bulk variable 8
# failed to find for year 2006 bulk variable 9
# failed to find for year 2006 bulk variable 10
# failed to find for year 2006 bulk variable 11
# failed to find for year 2006 bulk variable 12
# failed to find for year 2006 bulk variable 13
# failed to find for year 2006 bulk variable 14
# failed to find for year 2006 taux
# failed to find for year 2006 tauy
# 2007
# failed to find for year 2007 bulk variable 8
# failed to find for year 2007 bulk variable 9
# failed to find for year 2007 bulk variable 10
# failed to find for year 2007 bulk variable 11
# failed to find for year 2007 bulk variable 12
# failed to find for year 2007 bulk variable 13
# failed to find for year 2007 bulk variable 14
# failed to find for year 2007 taux
# failed to find for year 2007 tauy
# 2008
# failed to find for year 2008 bulk variable 8
# failed to find for year 2008 bulk variable 9
# failed to find for year 2008 bulk variable 10
# failed to find for year 2008 bulk variable 11
# failed to find for year 2008 bulk variable 12
# failed to find for year 2008 bulk variable 13
# failed to find for year 2008 bulk variable 14
# failed to find for year 2008 taux
# failed to find for year 2008 tauy
# 2009
# failed to find for year 2009 bulk variable 8
# failed to find for year 2009 bulk variable 9
# failed to find for year 2009 bulk variable 10
# failed to find for year 2009 bulk variable 11
# failed to find for year 2009 bulk variable 12
# failed to find for year 2009 bulk variable 13
# failed to find for year 2009 bulk variable 14
# failed to find for year 2009 taux
# failed to find for year 2009 tauy
# 2010
# failed to find for year 2010 bulk variable 8
# failed to find for year 2010 bulk variable 9
# failed to find for year 2010 bulk variable 10
# failed to find for year 2010 bulk variable 11
# failed to find for year 2010 bulk variable 12
# failed to find for year 2010 bulk variable 13
# failed to find for year 2010 bulk variable 14
# failed to find for year 2010 taux
# failed to find for year 2010 tauy
# 2011
# failed to find for year 2011 bulk variable 8
# failed to find for year 2011 bulk variable 9
# failed to find for year 2011 bulk variable 10
# failed to find for year 2011 bulk variable 11
# failed to find for year 2011 bulk variable 12
# failed to find for year 2011 bulk variable 13
# failed to find for year 2011 bulk variable 14
# failed to find for year 2011 taux
# failed to find for year 2011 tauy
# 2012
# failed to find for year 2012 bulk variable 8
# failed to find for year 2012 bulk variable 9
# failed to find for year 2012 bulk variable 10
# failed to find for year 2012 bulk variable 11
# failed to find for year 2012 bulk variable 12
# failed to find for year 2012 bulk variable 13
# failed to find for year 2012 bulk variable 14
# failed to find for year 2012 taux
# failed to find for year 2012 tauy
# 2013
# failed to find for year 2013 bulk variable 8
# failed to find for year 2013 bulk variable 9
# failed to find for year 2013 bulk variable 10
# failed to find for year 2013 bulk variable 11
# failed to find for year 2013 bulk variable 12
# failed to find for year 2013 bulk variable 13
# failed to find for year 2013 bulk variable 14
# failed to find for year 2013 taux
# failed to find for year 2013 tauy
# 2014
# failed to find for year 2014 bulk variable 8
# failed to find for year 2014 bulk variable 9
# failed to find for year 2014 bulk variable 10
# failed to find for year 2014 bulk variable 11
# failed to find for year 2014 bulk variable 12
# failed to find for year 2014 bulk variable 13
# failed to find for year 2014 bulk variable 14
# failed to find for year 2014 taux
# failed to find for year 2014 tauy
# 2015
# failed to find for year 2015 bulk variable 8
# failed to find for year 2015 bulk variable 9
# failed to find for year 2015 bulk variable 10
# failed to find for year 2015 bulk variable 11
# failed to find for year 2015 bulk variable 12
# failed to find for year 2015 bulk variable 13
# failed to find for year 2015 bulk variable 14
# failed to find for year 2015 taux
# failed to find for year 2015 tauy
# 2016
# failed to find for year 2016 bulk variable 8
# failed to find for year 2016 bulk variable 9
# failed to find for year 2016 bulk variable 10
# failed to find for year 2016 bulk variable 11
# failed to find for year 2016 bulk variable 12
# failed to find for year 2016 bulk variable 13
# failed to find for year 2016 bulk variable 14
# failed to find for year 2016 taux
# failed to find for year 2016 tauy
# 2017
# failed to find for year 2017 bulk variable 8
# failed to find for year 2017 bulk variable 9
# failed to find for year 2017 bulk variable 10
# failed to find for year 2017 bulk variable 11
# failed to find for year 2017 bulk variable 12
# failed to find for year 2017 bulk variable 13
# failed to find for year 2017 bulk variable 14
# failed to find for year 2017 taux
# failed to find for year 2017 tauy
# 2018
# failed to find for year 2018 bulk variable 8
# failed to find for year 2018 bulk variable 9
# failed to find for year 2018 bulk variable 10
# failed to find for year 2018 bulk variable 11
# failed to find for year 2018 bulk variable 12
# failed to find for year 2018 bulk variable 13
# failed to find for year 2018 bulk variable 14
# failed to find for year 2018 taux
# failed to find for year 2018 tauy
# 2019
# failed to find for year 2019 bulk variable 8
# failed to find for year 2019 bulk variable 9
# failed to find for year 2019 bulk variable 10
# failed to find for year 2019 bulk variable 11
# failed to find for year 2019 bulk variable 12
# failed to find for year 2019 bulk variable 13
# failed to find for year 2019 bulk variable 14
# failed to find for year 2019 taux
# failed to find for year 2019 tauy
# we have shutdown

# %%
w = xr.open_dataset('/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/era5_bulk_8_y1940.nc')
w
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1367     else:
# -> 1368         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1369
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650         except ValueError as e:
# --> 651             six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     652
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: month must be in 1..12: 0-01-01 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     111     try:
# --> 112         ref_date = pd.Timestamp(ref_date)
#     113     except ValueError:
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/pandas/_libs/tslibs/timestamps.pyx in pandas._libs.tslibs.timestamps.Timestamp.__new__()
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_to_tsobject()
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion._convert_str_to_tsobject()
#
# ValueError: could not convert string to Timestamp
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     157         try:
# --> 158             dates = _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     159         except (KeyError, OutOfBoundsDatetime, OverflowError):
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in _decode_datetime_with_pandas(flat_num_dates, units, calendar)
#     115         # strings, in which case we fall back to using cftime
# --> 116         raise OutOfBoundsDatetime
#     117
#
# OutOfBoundsDatetime:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in _decode_cf_datetime_dtype(data, units, calendar, use_cftime)
#      76     try:
# ---> 77         result = decode_cf_datetime(example_value, units, calendar, use_cftime)
#      78     except Exception:
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in decode_cf_datetime(num_dates, units, calendar, use_cftime)
#     160             dates = _decode_datetime_with_cftime(
# --> 161                 flat_num_dates.astype(float), units, calendar
#     162             )
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in _decode_datetime_with_cftime(num_dates, units, calendar)
#      97     return np.asarray(
# ---> 98         cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
#      99     )
#
# src/cftime/_cftime.pyx in cftime._cftime.num2date()
#
# src/cftime/_cftime.pyx in cftime._cftime._dateparse()
#
# ValueError: zero not allowed as a reference year when has_year_zero=False
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_91533/2403237287.py in <module>
# ----> 1 w = xr.open_dataset('/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/era5_bulk_8_y1940.nc')
#       2 w
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     543
#     544     with close_on_error(store):
# --> 545         ds = maybe_decode_store(store)
#     546
#     547     # Ensure source filename always stored in dataset object (GH issue #2550)
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/backends/api.py in maybe_decode_store(store, lock)
#     457             drop_variables=drop_variables,
#     458             use_cftime=use_cftime,
# --> 459             decode_timedelta=decode_timedelta,
#     460         )
#     461
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/conventions.py in decode_cf(obj, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     596         drop_variables=drop_variables,
#     597         use_cftime=use_cftime,
# --> 598         decode_timedelta=decode_timedelta,
#     599     )
#     600     ds = Dataset(vars, attrs=attrs)
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/conventions.py in decode_cf_variables(variables, attributes, concat_characters, mask_and_scale, decode_times, decode_coords, drop_variables, use_cftime, decode_timedelta)
#     498             stack_char_dim=stack_char_dim,
#     499             use_cftime=use_cftime,
# --> 500             decode_timedelta=decode_timedelta,
#     501         )
#     502         if decode_coords:
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/conventions.py in decode_cf_variable(name, var, concat_characters, mask_and_scale, decode_times, decode_endianness, stack_char_dim, use_cftime, decode_timedelta)
#     338         var = times.CFTimedeltaCoder().decode(var, name=name)
#     339     if decode_times:
# --> 340         var = times.CFDatetimeCoder(use_cftime=use_cftime).decode(var, name=name)
#     341
#     342     dimensions, data, attributes, encoding = variables.unpack_for_decoding(var)
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in decode(self, variable, name)
#     425             units = pop_to(attrs, encoding, "units")
#     426             calendar = pop_to(attrs, encoding, "calendar")
# --> 427             dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
#     428             transform = partial(
#     429                 decode_cf_datetime,
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/coding/times.py in _decode_cf_datetime_dtype(data, units, calendar, use_cftime)
#      85             "if it is not installed."
#      86         )
# ---> 87         raise ValueError(msg)
#      88     else:
#      89         dtype = getattr(result, "dtype", np.dtype("object"))
#
# ValueError: unable to decode time units 'seconds since    0-01-01 00:00:00' with "calendar 'gregorian'". Try opening your dataset with decode_times=False or installing cftime if it is not installed.
