# %% [markdown]
# ### aim:  make GCB format output
#
# ### date:

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %% [markdown]
# Using DW scripts to make GCB output, originals here: `/gpfs/data/greenocean/GCB/GCB_RECCAP`
#
# I copied them here:
# `/gpfs/data/greenocean/GCB/GCB2023-TJ`

# %% [markdown]
# # -1:
#
# `python createGCB_RECCAP.py -1`

# %%
import arrow
utc = arrow.utcnow()
utc.format('YYYYMMDD')
# utc.format('yyyymmdd')
# Out:
# '20230619'

# %%
w = xr.open_dataset('//gpfs/data/greenocean/GCB/GCB2023-TJ/recreateDW2022_GCB/PlankTOM_Simulation_2022_A_integrated_timelines.nc')
w2 = xr.open_dataset('/gpfs/data/greenocean/GCB/GCB_RECCAP/PlankTOM_Simulation_2022_A.nc')

# %%
plt.figure()
plt.plot(w2.TIME,w2.fgco2_glob)
plt.plot(w.TIME,w.fgco2_glob)

plt.plot(w2.TIME,w2.fgco2_glob-w.fgco2_glob)
#plt.plot(w.TIME,w.fgco2_glob)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
w.fgco2_glob
