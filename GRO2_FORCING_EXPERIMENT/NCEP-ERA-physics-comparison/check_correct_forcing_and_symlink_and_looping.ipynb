# %% [markdown]
# ### aim:
#
# ### date:

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %% [markdown]
# ## symlink 1967 pre 1940, standard  after (NCEP)

# %%
import os

tdir_src = '/gpfs/data/greenocean/software/products/NCEPForcingData/allyears/'
tdir_dst = '/gpfs/data/greenocean/software/products/NCEPForcingData_1967pre1948/'

for y in range(1750,1948):
    print(y)
    
    src = f'{tdir_src}ncep_bulk_y1967.nc'
    dst = f'{tdir_dst}ncep_bulk_y{y}.nc'
    os.symlink(src,dst)
    
    src = f'{tdir_src}ncep_kelvin_y1967.nc'
    dst = f'{tdir_dst}ncep_kelvin_y{y}.nc'
    os.symlink(src,dst)
    
    src = f'{tdir_src}taux_1d_y1967.nc'
    dst = f'{tdir_dst}taux_1d_y{y}.nc'
    os.symlink(src,dst)
    src = f'{tdir_src}tauy_1d_y1967.nc'
    dst = f'{tdir_dst}tauy_1d_y{y}.nc'
    os.symlink(src,dst)
    
#     for b in range(8,16):
#         try:
#             src = f'{tdir}bulk_1967_{b}_era5_daily.nc'
#             print(src)
#             dst = f'{tdir_loop}era5_bulk_{b}_y{y}.nc' ## format that we need to read into era
#             os.symlink(src,dst)
#             print(f'year {y} bulk variable {b} GO!')
#         except:
#             print(f'didnt work for year {y} bulk variable {b}')
#         try: 
#             src = f'{tdir}taux_1d_1967_daily.nc'
#             dst = f'{tdir_loop}taux_1d_y{y}.nc'
#             os.symlink(src,dst)
#         except:
#             print('year {y} taux is off')
#         try:
#             src = f'{tdir}tauy_1d_1967_daily.nc'
#             dst = f'{tdir_loop}tauy_1d_y{y}.nc'
#             os.symlink(src,dst)
#         except:
#             print('year {y} tauy is off')
# Out:
# 1750
# 1751
# 1752
# 1753
# 1754
# 1755
# 1756
# 1757
# 1758
# 1759
# 1760
# 1761
# 1762
# 1763
# 1764
# 1765
# 1766
# 1767
# 1768
# 1769
# 1770
# 1771
# 1772
# 1773
# 1774
# 1775
# 1776
# 1777
# 1778
# 1779
# 1780
# 1781
# 1782
# 1783
# 1784
# 1785
# 1786
# 1787
# 1788
# 1789
# 1790
# 1791
# 1792
# 1793
# 1794
# 1795
# 1796
# 1797
# 1798
# 1799
# 1800
# 1801
# 1802
# 1803
# 1804
# 1805
# 1806
# 1807
# 1808
# 1809
# 1810
# 1811
# 1812
# 1813
# 1814
# 1815
# 1816
# 1817
# 1818
# 1819
# 1820
# 1821
# 1822
# 1823
# 1824
# 1825
# 1826
# 1827
# 1828
# 1829
# 1830
# 1831
# 1832
# 1833
# 1834
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# 1844
# 1845
# 1846
# 1847
# 1848
# 1849
# 1850
# 1851
# 1852
# 1853
# 1854
# 1855
# 1856
# 1857
# 1858
# 1859
# 1860
# 1861
# 1862
# 1863
# 1864
# 1865
# 1866
# 1867
# 1868
# 1869
# 1870
# 1871
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1879
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# ...

# %%
import os

tdir_src = '/gpfs/data/greenocean/software/products/NCEPForcingData/allyears/'
tdir_dst = '/gpfs/data/greenocean/software/products/NCEPForcingData_1967pre1948/'

for y in range(1948,2023):
    print(y)
    
    src = f'{tdir_src}ncep_bulk_y{y}.nc'
    dst = f'{tdir_dst}ncep_bulk_y{y}.nc'
    os.symlink(src,dst)
    
    src = f'{tdir_src}ncep_kelvin_y{y}.nc'
    dst = f'{tdir_dst}ncep_kelvin_y{y}.nc'
    os.symlink(src,dst)
    
    src = f'{tdir_src}taux_1d_y{y}.nc'
    dst = f'{tdir_dst}taux_1d_y{y}.nc'
    os.symlink(src,dst)
    
    src = f'{tdir_src}tauy_1d_y{y}.nc'
    dst = f'{tdir_dst}tauy_1d_y{y}.nc'
    os.symlink(src,dst)
# Out:
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
