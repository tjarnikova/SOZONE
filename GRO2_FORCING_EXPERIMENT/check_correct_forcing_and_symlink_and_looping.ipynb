# %% [markdown]
# ### aim:
#
# ### date:

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %%
tdir = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/'

for y in range(2019,2023):
    print(y)
    for b in range(8,15):
        try:
            dst = f'{tdir}era5_bulk_{b}_y{y}.nc'
            tfil = xr.open_dataset(dst, decode_times=False)
            noday = (tfil.time_counter.shape[0])
            nox = (tfil.x.shape[0])
            noy = (tfil.y.shape[0])
            if ((noday != 365) & (noday != 366)):
                print(f'processing problem year {y} bulk variable {b}')
            if ((nox != 182)):
                print(f'processing problem year {y} bulk variable {b}')
            if ((noy != 149)):
                print(f'processing problem year {y} bulk variable {b}')            
            # print(f'year {y} bulk variable (noday != 365) {b} GO!')
        except:
            print(f'failed to find for year {y} bulk variable {b}')
    try: 
        dst = f'{tdir}taux_1d_y{y}.nc'
        tfil = xr.open_dataset(dst, decode_times=False)
        noday = (tfil.time_counter.shape[0])
        nox = (tfil.x.shape[0])
        noy = (tfil.y.shape[0])
        if ((noday != 365) & (noday != 366)):
            print(f'processing problem year {y} taux')
        if ((nox != 182)):
            print(f'processing problem year {y} taux')
        if ((noy != 149)):
            print(f'processing problem year {y} taux')     
    except:
        print(f'failed to find for year {y} taux')

    try: 
        dst = f'{tdir}tauy_1d_y{y}.nc'
        tfil = xr.open_dataset(dst, decode_times=False)
        noday = (tfil.time_counter.shape[0])
        nox = (tfil.x.shape[0])
        noy = (tfil.y.shape[0])
        if ((noday != 365) & (noday != 366)):
            print(f'processing problem year {y} tauy')
        if ((nox != 182)):
            print(f'processing problem year {y} tauy')
        if ((noy != 149)):
            print(f'processing problem year {y} tauy')     
    except:
        print(f'failed to find for year {y} tauy')
        


print('we have shutdown')
# Out:
# 2019
# 2020
# 2021
# 2022
# we have shutdown

# %%
# tdir = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk9proc/'

# for y in range(1940,2023):

#     try:
#         dst = f'{tdir}surface_pressure_ERA5_{y}.nc'
#         tfil = xr.open_dataset(dst, decode_times=False)
#     except:
#         print(f'surface_pressure_ERA5_ file missing {y}')
#     try:
#         dst2 = f'{tdir}2m_dewpoint_temperature_ERA5_{y}.nc'
#         tfil = xr.open_dataset(dst2, decode_times=False)
#     except:
#         print(f'2m_dewpoint_temperature_ERA5_ file missing {y}')
# #2m_dewpoint_temperature_

# %% [markdown]
# ## symlinking

# %%
import os 
tdir = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/'

print('testing tym socialne divergentni')


for y in range(2019,2023):
    print(y)
    for b in range(8,16):
        try:
            src = f'{tdir}bulk_{y}_{b}_era5_daily.nc'
            print(src)
            dst = f'{tdir}era5_bulk_{b}_y{y}.nc' ## format that we need to read into era
            os.symlink(src,dst)
            print(f'year {y} bulk variable {b} GO!')
        except:
            print(f'didnt work for year {y} bulk variable {b}')
        try: 
            src = f'{tdir}taux_1d_{y}_daily.nc'
            dst = f'{tdir}taux_1d_y{y}.nc'
            os.symlink(src,dst)
        except:
            print('year {y} taux is off')
        try:
            src = f'{tdir}tauy_1d_{y}_daily.nc'
            dst = f'{tdir}tauy_1d_y{y}.nc'
            os.symlink(src,dst)
        except:
            print('year {y} tauy is off')
# Out:
# testing tym socialne divergentni
# 2019
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_2019_8_era5_daily.nc
# didnt work for year 2019 bulk variable 8
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_2019_9_era5_daily.nc
# didnt work for year 2019 bulk variable 9
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_2019_10_era5_daily.nc
# didnt work for year 2019 bulk variable 10
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_2019_11_era5_daily.nc
# didnt work for year 2019 bulk variable 11
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_2019_12_era5_daily.nc
# didnt work for year 2019 bulk variable 12
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_2019_13_era5_daily.nc
# ...

# %% [markdown]
# ## symlink 1990 loop

# %%
tdir_loop = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/looping1990/'
tdir = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/'

for y in range(1750,2023):
    print(y)
    for b in range(8,16):
        try:
            src = f'{tdir}bulk_1990_{b}_era5_daily.nc'
            print(src)
            dst = f'{tdir_loop}era5_bulk_{b}_y{y}.nc' ## format that we need to read into era
            os.symlink(src,dst)
            print(f'year {y} bulk variable {b} GO!')
        except:
            print(f'didnt work for year {y} bulk variable {b}')
        try: 
            src = f'{tdir}taux_1d_1990_daily.nc'
            dst = f'{tdir_loop}taux_1d_y{y}.nc'
            os.symlink(src,dst)
        except:
            print('year {y} taux is off')
        try:
            src = f'{tdir}tauy_1d_1990_daily.nc'
            dst = f'{tdir_loop}tauy_1d_y{y}.nc'
            os.symlink(src,dst)
        except:
            print('year {y} tauy is off')
# Out:
# 1750
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_8_era5_daily.nc
# didnt work for year 1750 bulk variable 8
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_9_era5_daily.nc
# didnt work for year 1750 bulk variable 9
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_10_era5_daily.nc
# didnt work for year 1750 bulk variable 10
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_11_era5_daily.nc
# didnt work for year 1750 bulk variable 11
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_12_era5_daily.nc
# didnt work for year 1750 bulk variable 12
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_13_era5_daily.nc
# ...

# %%
tdir_loop = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/'
tdir = '/gpfs/data/greenocean/software/products/ERA5_v202303_TJ/'

for y in range(1750,1940):
    print(y)
    for b in range(8,16):
        try:
            src = f'{tdir}bulk_1990_{b}_era5_daily.nc'
            print(src)
            dst = f'{tdir_loop}era5_bulk_{b}_y{y}.nc' ## format that we need to read into era
            os.symlink(src,dst)
            print(f'year {y} bulk variable {b} GO!')
        except:
            print(f'didnt work for year {y} bulk variable {b}')
        try: 
            src = f'{tdir}taux_1d_1990_daily.nc'
            dst = f'{tdir_loop}taux_1d_y{y}.nc'
            os.symlink(src,dst)
        except:
            print('year {y} taux is off')
        try:
            src = f'{tdir}tauy_1d_1990_daily.nc'
            dst = f'{tdir_loop}tauy_1d_y{y}.nc'
            os.symlink(src,dst)
        except:
            print('year {y} tauy is off')
# Out:
# 1750
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_8_era5_daily.nc
# year 1750 bulk variable 8 GO!
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_9_era5_daily.nc
# year 1750 bulk variable 9 GO!
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_10_era5_daily.nc
# year 1750 bulk variable 10 GO!
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_11_era5_daily.nc
# year 1750 bulk variable 11 GO!
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_12_era5_daily.nc
# year 1750 bulk variable 12 GO!
# year {y} taux is off
# year {y} tauy is off
# /gpfs/data/greenocean/software/products/ERA5_v202303_TJ/bulk_1990_13_era5_daily.nc
# year 1750 bulk variable 13 GO!
# year {y} taux is off
# year {y} tauy is off
# ...
