# %% [markdown]
# ### aim:
#
# ### date:

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import numpy as np
from cmocean import cm
import cartopy as cp
import cartopy.crs as ccrs
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE')
#list of models
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/UTILS')
import lom
import utils as ut

# %matplotlib inline
import warnings
from datetime import datetime
warnings.filterwarnings('ignore')
import cartopy.feature as cfeature
from importlib import reload
import matplotlib.path as mpath
import glob
import pickle
import pandas as pd
import seawater
import time
plt.rcParams.update({'font.size': 12})
font = {'family' : 'normal',
'weight' : 'normal',
'size'   : 12}

plt.rc('font', **font)

# %% [markdown]
# - need temperature and salinity in votemper, vosaline format
#
#     - raw medusa data is here: /gpfs/data/greenocean/software/resources/MEDUSA/ukesm_allscen_gridT_TS
#     - yearly processed files are here:
# - need vomec

# %% [markdown]
# ## check that we have the following raw files:
#
# - votemper, vosaline
# - vomecrty

# %%
def check_filetype_present(yr,runname,\
                           subfolder = 'ukesm_allscen_gridT_TS',\
                           rtype = 'grid-T'):

    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/{subfolder}/nemo_{runname}*1m_{yr}*{rtype}.nc'
    # print(savenam)
    
    tw = glob.glob(savenam)
    # print(tw)
    #print(tw)
    if len(tw) != 12:
        print(f'{yr}, {runname} {rtype} missing')
    else:
        pass
        #print(f'{yr} OKOKOKOKOKOKOK {runname}')

# %%
    
#1h OK
print('checking for temperature')
subfolder = 'ukesm_allscen_gridT_TS'
rtype = 'grid-T'
runname = 'bc370'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()
#1b
runname= 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()
# #2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()
# #2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()    
# #2b
runname= 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    

print()    
# #3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()
# #3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()    
# #3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)
    
print('if it didnt print anything you have all yr raw files')
# Out:
# checking for temperature
#
#
#
#
#
#
#
# if it didnt print anything you have all yr raw files

# %%
#1h OK
print('checking for vomecrty')
subfolder = 'ukesm_allscen_gridV_vo'
rtype = 'grid-V'
# runname = 'bc370'
# yrs = np.arange(1950,2015,1)
# for y in yrs:
#     check_filetype_present(y,runname,subfolder, rtype)    

# #1a
# runname = 'be682'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present(y,runname,subfolder, rtype)    
# print()
#1b
runname= 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()
#2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()
#2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()    
#2b
runname= 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    

print()    
#3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()
#3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)    
print()    
#3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present(y,runname,subfolder, rtype)
    
print('if it didnt print anything you have all yr raw files')
# Out:
# checking for vomecrty
#
#
#
#
#
#
#
# if it didnt print anything you have all yr raw files

# %%
def check_filetype_present_processed(yr,runname,\
                           subfolder = '',\
                           rtype = 'grid-T-TS'):

    savenam = f'/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_{runname}*1y_{yr}*{rtype}.nc'
    # print(savenam)
    
    tw = glob.glob(savenam)
    # print(tw)
    #print(tw)
    if len(tw) != 1:
        print(f'{yr}, {runname} {rtype} missing')
    else:
        pass

# %%
    
#1h OK
print('checking for temperature')

rtype = 'grid-T-TS'
runname = 'bc370'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
#1b
runname= 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
# #2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
# #2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()    
# #2b
runname= 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    

print()    
# #3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
# #3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()    
# #3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)
    
print('if it didnt print anything you have all yr processed files')
# Out:
# checking for temperature
#
#
#
#
#
#
#
# if it didnt print anything you have all yr processed files

# %%
    
#1h OK
print('checking for vomecrty')

rtype = 'grid-V-vomecrty'
runname = 'bc370'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    

#1a
runname = 'be682'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
#1b
runname= 'ce417'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
# #2h
runname = 'cj198'
yrs = np.arange(1950,2015,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
# #2a
runname = 'cj880'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()    
# #2b
runname= 'cj881'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    

print()    
# #3h
runname = 'cj200'
yrs = np.arange(1990,2015,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()
# #3a
runname = 'cj484'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)    
print()    
# #3a
runname = 'cj504'
yrs = np.arange(2015,2100,1)
for y in yrs:
    check_filetype_present_processed(y,runname,subfolder, rtype)
    
print('if it didnt print anything you have all yr processed files')
# Out:
# checking for vomecrty
#
#
#
#
#
#
#
# if it didnt print anything you have all yr processed files

# %%
w = xr.open_dataset('/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2099_grid-T-TS.nc')
w
# Out:
# <xarray.Dataset>
# Dimensions:       (deptht: 75, time_counter: 12, x: 362, y: 332)
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2099-01-31 ... 2099-12-31
#     nav_lat       (y, x) float32 ...
#     nav_lon       (y, x) float32 ...
#   * deptht        (deptht) float32 0.50576 1.5558553 ... 5698.0605 5902.0576
# Dimensions without coordinates: x, y
# Data variables:
#     vosaline      (time_counter, deptht, y, x) float64 ...
#     votemper      (time_counter, deptht, y, x) float64 ...
# Attributes:
#     made in:  SOZONE/MEDUSA/runner_gridT-TS.py
#     desc:     yearly medusa files, saving only variables of interest

# %%
w.zomsfglo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_121893/270701398.py in <module>
# ----> 1 w.zomsfglo
#
# ~/.conda/envs/swamp2/lib/python3.7/site-packages/xarray/core/common.py in __getattr__(self, name)
#     227                     return source[name]
#     228         raise AttributeError(
# --> 229             "{!r} object has no attribute {!r}".format(type(self).__name__, name)
#     230         )
#     231
#
# AttributeError: 'Dataset' object has no attribute 'zomsfglo'

# %%
import numpy as np
print(np.nanmax(w.zomsfglo.values))

# %%
import cmocean as cm
tv = xr.open_dataset('//gpfs/data/greenocean/software/resources/MEDUSA/PROC2/nemo_be682_1y_2019_grid-V-vomecrty.nc')
tv

xr.plot.pcolormesh(tv.vomecrty.isel(x= 200).mean(dim = 'time_counter'), vmin = -0.05, vmax = 0.05, cmap = cm.cm.balance)

# %%
import xarray as xr
w = xr.open_dataset('/gpfs/home/mep22dku/cdftools/moc.nc')

print(w.zomsfglo.max())
xr.plot.pcolormesh(w.zomsfglo.mean(dim = ['time_counter','x']))

# %%
w = xr.open_dataset('/gpfs/data/greenocean/software/resources/MEDUSA/PROC2//nemo_bc370_1y_1950_grid-T-TS.nc')
w

# %% [markdown]
# ## process annotation
#
# `module add gcc/10.3.0`
#
# `module add netcdf/4.7.4/gcc`
#
# `cd /gpfs/home/mep22dku/cdftools`
#
# `cp /gpfs/data/greenocean/software/runs/TOM12_RW_M90C/ORCA2_1m_19980101_19981231_grid_V.nc ./`
#
# #### meshmask
# `ln -sf mesh_mask3_6.nc mesh_hgr.nc`
#
# `ln -sf mesh_mask3_6.nc mesh_zgr.nc`
#
# `ln -sf mesh_mask3_6.nc mask.nc`
#
# `./cdfmoc -v ORCA2_1m_19980101_19981231_grid_V.nc`
#
# produces moc .nc

# %% [markdown]
# #1h OK
#
# tdir = '/gpfs/data/greenocean/software/resources/MEDUSA/PROC2/'
#
# runname = 'bc370'
# yrs = np.arange(1950,2015,1)
#
# echo $tdir
#
# for ((i=1950; i<2015; i++))
# do
#
#     echo "$i ${runname} hej to bude dobry vis"
#
#     #./cdfmoc -v /gpfs/data/greenocean/software/runs/${tdir}/ORCA2_1m_${i}0101_${i}1231_grid_V.nc
#     ./cdfmocsig -v ${tdir}/nemo_${runname}$_1y_${i}_grid-V-vomecrty.nc -t ${tdir}/nemo_${runname}$_1y_${i}_grid-T-TS.nc -r 1000
#
#     mv mocsig.nc ./mocsig_UKESM/nemo${runname}_1m_${i}0101_${i}1231_MOCSIG_ref1000.nc
#
# done
#
#
# runname = 'be682'
# yrs = np.arange(2015,2100,1)
#
# runname= 'ce417'
# yrs = np.arange(2015,2100,1)
#
# # #2h
# runname = 'cj198'
# yrs = np.arange(1950,2015,1)
#
# # #2a
# runname = 'cj880'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present_processed(y,runname,subfolder, rtype)
# print()
# # #2b
# runname= 'cj881'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present_processed(y,runname,subfolder, rtype)
#
# print()
# # #3h
# runname = 'cj200'
# yrs = np.arange(1990,2015,1)
# for y in yrs:
#     check_filetype_present_processed(y,runname,subfolder, rtype)
# print()
# # #3a
# runname = 'cj484'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present_processed(y,runname,subfolder, rtype)
# print()
# # #3a
# runname = 'cj504'
# yrs = np.arange(2015,2100,1)
# for y in yrs:
#     check_filetype_present_processed(y,runname,subfolder, rtype)
#
# print('if it didnt print anything you have all yr processed files')
