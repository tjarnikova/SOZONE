# %%
# %reset
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import glob
import xarray as xr
import sys
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/MO_pipeline/')
import scendict as sc
import numpy as np
sys.path.append('/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/WORK_SCRIPTS')
import bio_sanity as bs
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ## short illustration of sanity checker.
#
# this utility just plots non-weighted mean and maximum values for each month of each year in a runset of several biological model fields that may be prone to instability:
#
#     ['GOC', 'POC', 'EXP', 'PPT', 'TChl']
#
# The code that I'm calling here is in:
#
#     /gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/WORK_SCRIPTS
#
# And it's called
#
#     bio_sanity.py
#
# (It could be refactored to be more elegant/faster with xarray but it does the job).
#
# Here I am running it on Dave's we see that the GOC and consequently the EXP have gone unstable in around year 2010 (10 years before the end of the run). This instability *will likely not be visible in the conventional model metrics for another 30 years!*.

# %%
from importlib import reload
reload(bs)

tr = 'TOM12_DW_WE43'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run TOM12_DW_WE43: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %% [markdown]
# Here is the same exact run, but with the GOC brake on - preventing that instability:

# %%
tr = 'TOM12_TJ_WE43'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run TOM12_TJ_WE43: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %%
print('done')
# Out:
# done

# %%
tr = 'RIV12_PT_ER17'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run RIV12_PT_ER17: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %%
tr = 'RIV12_PT_ER18'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run RIV12_PT_ER18: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %%
tr = 'RIV12_PT_ER19'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run RIV12_PT_ER19: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %%
tr = 'RIV12_PT_ER17'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run RIV12_PT_ER17: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %%
tr = 'RIV12_PT_NC01'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run RIV12_PT_NC01: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %%
tr = 'RIV12_PT_NC02'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run RIV12_PT_NC02: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60

# %%
tr = 'RIV12_PT_NC03'
baseDir = '/gpfs/afm/greenocean/software/runs/'

bs.get_sanity(tr, baseDir, startyear = 1948, sdir = '/gpfs/home/mep22dku/scratch/SOZONE/MODPROC_ROBOT/MultiModelMonitor/OUTPUT/')
# Out:
# making sanity for run RIV12_PT_NC03: 1948-2020
# GOC
# 0
# 30
# 60
# POC
# 0
# 30
# 60
# EXP
# 0
# 30
# 60
# PPT
# 0
# 30
# 60
# TChl
# 0
# 30
# 60
